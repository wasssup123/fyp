# %%
# Reading the uploaded FASTA file and modifying the headers to only retain the second string

input_file_path = 'data/fungi_ITS_sorted90.fasta'
output_file_path = 'data/fungi_ITS_cleaned.fasta'

# Open the input file and create the output file
with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
    for line in infile:
        if line.startswith('>'):
            # Splitting the line and keeping only the second string
            header_parts = line.strip().split()
            if len(header_parts) > 1:
                modified_header = '>' + header_parts[1] + '\n'
                outfile.write(modified_header)
            else:
                outfile.write(line)
        else:
            outfile.write(line)

output_file_path
# Out:
# 'data/fungi_ITS_cleaned.fasta'

# %% [markdown]
# # vectorization

# %%
import itertools

def generate_all_kmers(k):
    return [''.join(p) for p in itertools.product('ACGT', repeat=k)]

def kmer_vector(sequence, k):
    # gen all possible k-mers comb
    all_kmers = generate_all_kmers(k)
    vector = [0] * len(all_kmers)
    kmer_to_index = {kmer: idx for idx, kmer in enumerate(all_kmers)}
    for i in range(len(sequence) - k + 1):
        kmer = sequence[i:i+k]
        if kmer in kmer_to_index:
            vector[kmer_to_index[kmer]] += 1
    return vector

input_file_path = 'data/fungi_ITS_cleaned.fasta'
output_file_path = 'data/fungi_ITS_kmer_vector.txt'

############################# k
k = 4


with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
    current_sequence = ""
    current_header = ""
    
    for line in infile:
        if line.startswith('>'):
            if current_sequence:
                vector = kmer_vector(current_sequence, k)
                vector_str = ' '.join(map(str, vector))
                outfile.write(f"{current_header}\t{vector_str}\n")
            current_header = line.strip()
            current_sequence = ""
        else:
            current_sequence += line.strip()
    
    if current_sequence:
        vector = kmer_vector(current_sequence, k)
        vector_str = ' '.join(map(str, vector))
        outfile.write(f"{current_header}\t{vector_str}\n")

output_file_path
# Out:
# 'data/fungi_ITS_kmer_vector.txt'

# %%
from collections import defaultdict


input_file = 'data/fungi_ITS_kmer_vector.txt'
output_file = 'data/fungi_ITS_kmer_vector_filtered.txt'

genera_count = defaultdict(int)
with open(input_file, 'r') as f:
    for line in f:
        if line.startswith('>'):
            genus = line.split()[0][1:]
            genera_count[genus] += 1

# Filtering the sequences and saving to a new file
with open(input_file, 'r') as f, open(output_file, 'w') as out:
    write_line = False
    for line in f:
        if line.startswith('>'):
            genus = line.split()[0][1:]
            write_line = genera_count[genus] >= 10
        if write_line:
            out.write(line)

print("Filtering complete. The results are saved in 'fungi_ITS_kmer_vector_filtered.txt'.")
# Out:
# Filtering complete. The results are saved in 'fungi_ITS_kmer_vector_filtered.txt'.

# %%
# File paths
input_file_path = 'data/fungi_ITS_kmer_vector.txt'
output_file_path = 'data/fungi_ITS_kmer_vector_with_header.txt'

# k value to consider
k = 4

# Generate all possible k-mers for the header row
all_kmers = generate_all_kmers(k)
header_row = "ID\t" + "\t".join(all_kmers) + "\n"

# Open the input file and create the output file with the header row
with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
    # Write the header row to the output file
    outfile.write(header_row)
    # Write the rest of the content from the input file
    for line in infile:
        outfile.write(line)

output_file_path
# Out:
# 'data/fungi_ITS_kmer_vector_with_header.txt'

# %%
# Importing necessary libraries
import pandas as pd

# Load the file into a DataFrame
file_path = 'data/fungi_ITS_kmer_vector_with_header.txt'
df = pd.read_csv(file_path, sep='\t')

# Filter out genera with fewer than 10 sequences
filtered_df = df.groupby('ID').filter(lambda x: len(x) >= 10)

# Save the filtered DataFrame to a new file
filtered_file_path = 'data/fungi_ITS_kmer_vector_filtered.txt'
filtered_df.to_csv(filtered_file_path, sep='\t', index=False)

print("Filtering complete. The results are saved in 'filtered_fungi_ITS_kmer_vector.txt'.")
# Out:
# Filtering complete. The results are saved in 'filtered_fungi_ITS_kmer_vector.txt'.

# %% [markdown]
# # train test split

# %%
import random

input_file_path = 'data/fungi_ITS_kmer_vector_filtered.txt'
train_file_path = 'data/fungi_ITS_train.txt'
test_file_path = 'data/fungi_ITS_test.txt'

data_by_class = {}

with open(input_file_path, 'r') as infile:
    for line in infile:
        line = line.strip()
        if line.startswith('>'):
            parts = line.split('\t')
            if len(parts) == 2:
                label = parts[0][1:]  # remove '>'
                vector_str = parts[1]
                
                if label not in data_by_class:
                    data_by_class[label] = []
                data_by_class[label].append(line)

test_data = []
train_data = []

for label, samples in data_by_class.items():
    if len(samples) > 1:
        test_sample = random.choice(samples)
        test_data.append(test_sample)
        train_data.extend([sample for sample in samples if sample != test_sample])
    else:
        train_data.extend(samples)

with open(train_file_path, 'w') as train_file:
    for line in train_data:
        train_file.write(line + '\n')

with open(test_file_path, 'w') as test_file:
    for line in test_data:
        test_file.write(line + '\n')


train_file_path, test_file_path
# Out:
# ('data/fungi_ITS_train.txt', 'data/fungi_ITS_test.txt')

# %% [markdown]
# # start

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader

# Load data and labels from input file
input_file_path = 'data/fungi_ITS_kmer_vector_filtered.txt'

labels = []
data_vectors = []

with open(input_file_path, 'r') as infile:
    for line in infile:
        line = line.strip()
        if line.startswith('>'):
            parts = line.split('\t')
            if len(parts) == 2:
                label = parts[0][1:]  # remove '>'
                vector_str = parts[1]
                vector = list(map(int, vector_str.split()))
                labels.append(label)
                data_vectors.append(vector)

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

#
data_tensor = torch.tensor(data_vectors, dtype=torch.float32)
labels_tensor = torch.tensor(encoded_labels, dtype=torch.long)

class KmerDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Create the DataLoader
kmer_dataset = KmerDataset(data_tensor, labels_tensor)
dataloader = DataLoader(kmer_dataset, batch_size=32, shuffle=True)

# Create a dictionary to map class indices to class names
class_mapping = {index: label for index, label in enumerate(label_encoder.classes_)}

# Print dataset information
print(len(kmer_dataset))
print(set(labels))
print(len(label_encoder.classes_))

for batch_idx, (data, labels) in enumerate(dataloader):
    print(f"Batch {batch_idx + 1}:")
    print("Data:", data)
    print("Labels:", labels)
    # Map label indices to class names for each batch
    label_names = [class_mapping[idx.item()] for idx in labels]
    print("Label Names:", label_names)
    print("print len of label names:", len(label_names))
    print()
# Out:
# 1693
#         [ 1.,  1.,  5.,  ...,  4., 14., 15.],
#         [ 9.,  3.,  0.,  ...,  2.,  6.,  3.],
#         ...,
#         [ 4.,  3.,  3.,  ...,  1.,  1.,  0.],
#         [ 6.,  4.,  3.,  ...,  6.,  9.,  7.],
#         [ 2.,  3.,  2.,  ...,  2., 11.,  9.]])
# Labels: tensor([77, 27, 40, 78, 33,  5,  9, 57, 57, 32, 59, 38, 43, 32, 64, 49, 50, 32,
#         15,  2, 68, 33, 21, 28, 39, 52,  9, 50, 32,  3, 32, 32])
# Label Names: ['Wickerhamiella', 'Hydnellum', 'Lipomyces', 'Wickerhamomyces', 'Inosperma', 'Backusella', 'Candida', 'Raffaelea', 'Raffaelea', 'Inocybe', 'Roussoella', 'Lepiota', 'Metschnikowia', 'Inocybe', 'Scytinostroma', 'Orbilia', 'Otidea', 'Inocybe', 'Coprinopsis', 'Apiospora', 'Suhomyces', 'Inosperma', 'Entoloma', 'Hygrocybe', 'Leucoagaricus', 'Phylloporus', 'Candida', 'Otidea', 'Inocybe', 'Arthroderma', 'Inocybe', 'Inocybe']
# print len of label names: 32
#
# Batch 6:
# Data: tensor([[ 2.,  2.,  2.,  ...,  6.,  8.,  6.],
#         [ 5.,  2.,  3.,  ...,  4., 12.,  7.],
#         [ 6.,  6.,  4.,  ...,  3.,  4.,  5.],
#         ...,
#         [ 3.,  3.,  0.,  ...,  5., 12.,  8.],
#         [ 4.,  5.,  2.,  ...,  2., 11., 16.],
#         [ 5.,  3.,  2.,  ...,  2.,  4.,  3.]])
# Labels: tensor([32, 32, 66, 30, 70, 21, 60,  1, 32, 11, 60, 44, 66, 38, 31, 74, 46, 22,
#         21, 75, 74, 62, 31,  5, 63, 79, 49, 32, 32, 39, 40, 11])
# Label Names: ['Inocybe', 'Inocybe', 'Starmerella', 'Hymenochaete', 'Tomentella', 'Entoloma', 'Russula', 'Amanita', 'Inocybe', 'Cladophialophora', 'Russula', 'Mortierella', 'Starmerella', 'Lepiota', 'Hypoxylon', 'Tricholoma', 'Mycena', 'Exophiala', 'Entoloma', 'Tuber', 'Tricholoma', 'Saturnispora', 'Hypoxylon', 'Backusella', 'Scolecobasidium', 'Xylaria', 'Orbilia', 'Inocybe', 'Inocybe', 'Leucoagaricus', 'Lipomyces', 'Cladophialophora']
# print len of label names: 32
#
# Batch 7:
# Data: tensor([[11.,  6.,  4.,  ...,  2.,  3.,  3.],
#         [ 6.,  2.,  1.,  ...,  2.,  5.,  2.],
#         [ 3.,  3.,  2.,  ...,  2.,  4.,  1.],
#         ...,
#         [ 4.,  4.,  2.,  ...,  4.,  3.,  8.],
#         [ 6.,  2.,  4.,  ...,  5.,  6.,  3.],
#         [ 9.,  8.,  3.,  ...,  6.,  6.,  3.]])
# Labels: tensor([54, 16, 76, 73,  1, 52, 43, 32, 68, 60, 32, 49, 61, 49, 43, 20, 43, 60,
#          7, 31, 39, 24, 56, 51, 18,  0, 29, 39, 58,  2,  1,  9])
# Label Names: ['Pichia', 'Cortinarius', 'Verrucaria', 'Trichoderma', 'Amanita', 'Phylloporus', 'Metschnikowia', 'Inocybe', 'Suhomyces', 'Russula', 'Inocybe', 'Orbilia', 'Saccharomycopsis', 'Orbilia', 'Metschnikowia', 'Elsinoe', 'Metschnikowia', 'Russula', 'Blastobotrys', 'Hypoxylon', 'Leucoagaricus', 'Geastrum', 'Pseudosperma', 'Perenniporia', 'Cyberlindnera', 'Absidia', 'Hygrophorus', 'Leucoagaricus', 'Ramaria', 'Apiospora', 'Amanita', 'Candida']
# print len of label names: 32
#
# Batch 8:
# Data: tensor([[ 5.,  5.,  2.,  ...,  4., 10., 10.],
#         [ 2.,  3.,  2.,  ...,  3.,  1.,  2.],
#         [ 4.,  4.,  3.,  ...,  5., 10.,  6.],
#         ...,
#         [ 3.,  3.,  2.,  ...,  6.,  6.,  4.],
#         [ 5.,  3.,  1.,  ...,  4.,  8., 14.],
#         [ 9.,  6.,  4.,  ...,  5.,  8., 10.]])
# Labels: tensor([21, 57,  1,  4, 67, 32, 23,  8, 17, 32, 27, 32, 39, 48,  0,  1, 71, 11,
#         73, 14, 32,  4, 31, 47, 32,  7, 18, 13, 63, 21,  9, 67])
# Label Names: ['Entoloma', 'Raffaelea', 'Amanita', 'Aspergillus', 'Sugiyamaella', 'Inocybe', 'Fomitiporia', 'Boletus', 'Crepidotus', 'Inocybe', 'Hydnellum', 'Inocybe', 'Leucoagaricus', 'Ophiocordyceps', 'Absidia', 'Amanita', 'Trechispora', 'Cladophialophora', 'Trichoderma', 'Colacogloea', 'Inocybe', 'Aspergillus', 'Hypoxylon', 'Ogataea', 'Inocybe', 'Blastobotrys', 'Cyberlindnera', 'Clavulina', 'Scolecobasidium', 'Entoloma', 'Candida', 'Sugiyamaella']
# print len of label names: 32
#
# Batch 9:
# Data: tensor([[ 9.,  1.,  2.,  ...,  3., 10., 14.],
#         [ 2.,  3.,  3.,  ...,  2.,  2.,  0.],
#         [ 7.,  5.,  4.,  ...,  4.,  5.,  4.],
#         ...,
#         [ 0.,  1.,  1.,  ...,  4.,  5.,  1.],
#         [ 1.,  4.,  2.,  ...,  4.,  8.,  7.],
#         [ 6.,  4.,  5.,  ...,  2.,  6.,  5.]])
# Labels: tensor([ 1, 75, 53, 77, 29, 39, 77, 45, 49,  4, 32, 66, 49, 28, 32, 62, 63, 45,
#         21, 16, 64, 32,  1, 21, 31, 34, 56, 32, 32, 15, 32, 63])
# Label Names: ['Amanita', 'Tuber', 'Phyllosticta', 'Wickerhamiella', 'Hygrophorus', 'Leucoagaricus', 'Wickerhamiella', 'Mucor', 'Orbilia', 'Aspergillus', 'Inocybe', 'Starmerella', 'Orbilia', 'Hygrocybe', 'Inocybe', 'Saturnispora', 'Scolecobasidium', 'Mucor', 'Entoloma', 'Cortinarius', 'Scytinostroma', 'Inocybe', 'Amanita', 'Entoloma', 'Hypoxylon', 'Kazachstania', 'Pseudosperma', 'Inocybe', 'Inocybe', 'Coprinopsis', 'Inocybe', 'Scolecobasidium']
# print len of label names: 32
#
# Batch 10:
# Data: tensor([[2., 4., 2.,  ..., 4., 3., 6.],
#         [2., 3., 2.,  ..., 3., 3., 0.],
#         [2., 5., 0.,  ..., 3., 3., 1.],
#         ...,
#         [3., 3., 3.,  ..., 2., 5., 3.],
#         [8., 6., 3.,  ..., 5., 7., 4.],
#         [2., 5., 0.,  ..., 3., 7., 1.]])
# Labels: tensor([22, 20, 20, 79, 34,  9, 68,  2, 27, 53,  0, 32, 40, 36,  1, 48, 21, 63,
#          1, 60, 30,  7, 55, 31, 35, 39, 50,  9, 45,  4, 63, 41])
# Label Names: ['Exophiala', 'Elsinoe', 'Elsinoe', 'Xylaria', 'Kazachstania', 'Candida', 'Suhomyces', 'Apiospora', 'Hydnellum', 'Phyllosticta', 'Absidia', 'Inocybe', 'Lipomyces', 'Lactifluus', 'Amanita', 'Ophiocordyceps', 'Entoloma', 'Scolecobasidium', 'Amanita', 'Russula', 'Hymenochaete', 'Blastobotrys', 'Pluteus', 'Hypoxylon', 'Lactarius', 'Leucoagaricus', 'Otidea', 'Candida', 'Mucor', 'Aspergillus', 'Scolecobasidium', 'Malassezia']
# print len of label names: 32
#
# Batch 11:
# Data: tensor([[ 0.,  1.,  2.,  ...,  2.,  7.,  0.],
#         [ 4.,  1.,  2.,  ...,  5.,  9.,  7.],
#         [ 5.,  5.,  1.,  ...,  1.,  3.,  6.],
#         ...,
#         [ 2.,  1.,  1.,  ...,  4.,  4.,  2.],
#         [10., 11.,  5.,  ...,  6.,  5.,  7.],
#         [ 7.,  3.,  3.,  ...,  4.,  8.,  6.]])
# Labels: tensor([70, 36, 48, 38, 32, 31, 14, 34, 32, 10, 14, 32, 51, 60, 60, 32, 32, 55,
#         23, 54, 74, 46, 50, 70, 80, 63, 17,  1, 52, 69, 49, 32])
# Label Names: ['Tomentella', 'Lactifluus', 'Ophiocordyceps', 'Lepiota', 'Inocybe', 'Hypoxylon', 'Colacogloea', 'Kazachstania', 'Inocybe', 'Cantharellus', 'Colacogloea', 'Inocybe', 'Perenniporia', 'Russula', 'Russula', 'Inocybe', 'Inocybe', 'Pluteus', 'Fomitiporia', 'Pichia', 'Tricholoma', 'Mycena', 'Otidea', 'Tomentella', 'Xylodon', 'Scolecobasidium', 'Crepidotus', 'Amanita', 'Phylloporus', 'Talaromyces', 'Orbilia', 'Inocybe']
# print len of label names: 32
#
# Batch 12:
# Data: tensor([[ 2.,  2.,  2.,  ...,  1.,  2.,  2.],
#         [ 2.,  3.,  2.,  ...,  5.,  6.,  6.],
#         [ 6.,  3.,  5.,  ...,  2.,  2., 10.],
#         ...,
#         [ 9.,  6.,  2.,  ...,  1.,  3.,  3.],
#         [ 2.,  2.,  0.,  ...,  3.,  2.,  2.],
#         [11.,  3.,  5.,  ...,  7.,  8., 12.]])
# Labels: tensor([ 4, 36, 77,  0, 63, 21, 39,  1, 21, 32, 16,  4,  4, 67, 18, 34, 58, 36,
#         60, 38, 30, 15, 15, 63, 49, 15, 51, 48, 67, 63, 57, 21])
# Label Names: ['Aspergillus', 'Lactifluus', 'Wickerhamiella', 'Absidia', 'Scolecobasidium', 'Entoloma', 'Leucoagaricus', 'Amanita', 'Entoloma', 'Inocybe', 'Cortinarius', 'Aspergillus', 'Aspergillus', 'Sugiyamaella', 'Cyberlindnera', 'Kazachstania', 'Ramaria', 'Lactifluus', 'Russula', 'Lepiota', 'Hymenochaete', 'Coprinopsis', 'Coprinopsis', 'Scolecobasidium', 'Orbilia', 'Coprinopsis', 'Perenniporia', 'Ophiocordyceps', 'Sugiyamaella', 'Scolecobasidium', 'Raffaelea', 'Entoloma']
# print len of label names: 32
#
# Batch 13:
# Data: tensor([[ 7.,  7.,  2.,  ...,  4.,  3.,  0.],
#         [ 1.,  3.,  0.,  ...,  5.,  8.,  2.],
#         [ 4.,  2.,  4.,  ...,  3.,  4.,  4.],
#         ...,
#         [ 6.,  4.,  2.,  ...,  3.,  4.,  2.],
#         [ 5.,  4.,  3.,  ...,  4.,  4.,  2.],
#         [ 2.,  1.,  4.,  ...,  4., 11.,  5.]])
# Labels: tensor([20, 23, 11, 21, 32, 47, 27, 21, 77, 11, 21,  4, 70,  4, 32, 37, 21, 78,
#         43, 67, 42,  9,  5,  9, 35, 22, 56,  1, 24, 37, 58, 35])
# Label Names: ['Elsinoe', 'Fomitiporia', 'Cladophialophora', 'Entoloma', 'Inocybe', 'Ogataea', 'Hydnellum', 'Entoloma', 'Wickerhamiella', 'Cladophialophora', 'Entoloma', 'Aspergillus', 'Tomentella', 'Aspergillus', 'Inocybe', 'Lecanora', 'Entoloma', 'Wickerhamomyces', 'Metschnikowia', 'Sugiyamaella', 'Marasmius', 'Candida', 'Backusella', 'Candida', 'Lactarius', 'Exophiala', 'Pseudosperma', 'Amanita', 'Geastrum', 'Lecanora', 'Ramaria', 'Lactarius']
# print len of label names: 32
#
# Batch 14:
# Data: tensor([[ 6.,  3.,  2.,  ...,  3.,  6.,  8.],
#         [ 4.,  2.,  5.,  ...,  5., 12., 11.],
#         [ 0.,  0.,  0.,  ...,  1.,  4.,  1.],
#         ...,
#         [ 1.,  1.,  2.,  ...,  2., 12.,  7.],
#         [11.,  9.,  8.,  ...,  8., 12., 26.],
#         [ 7.,  7.,  3.,  ...,  2.,  2.,  1.]])
# Labels: tensor([12, 32, 72, 24, 54, 68, 70, 22, 32, 33,  3, 31, 24,  4, 20, 22, 75, 47,
#         45,  4, 16, 68, 49, 67, 60, 16, 49, 12, 35, 46, 47, 75])
# Label Names: ['Clavaria', 'Inocybe', 'Tremella', 'Geastrum', 'Pichia', 'Suhomyces', 'Tomentella', 'Exophiala', 'Inocybe', 'Inosperma', 'Arthroderma', 'Hypoxylon', 'Geastrum', 'Aspergillus', 'Elsinoe', 'Exophiala', 'Tuber', 'Ogataea', 'Mucor', 'Aspergillus', 'Cortinarius', 'Suhomyces', 'Orbilia', 'Sugiyamaella', 'Russula', 'Cortinarius', 'Orbilia', 'Clavaria', 'Lactarius', 'Mycena', 'Ogataea', 'Tuber']
# print len of label names: 32
#
# Batch 15:
# Data: tensor([[ 2.,  2.,  3.,  ...,  3.,  3.,  4.],
#         [17.,  4.,  4.,  ...,  6.,  3., 15.],
#         [ 5.,  5.,  5.,  ...,  3.,  5.,  6.],
#         ...,
#         [ 6.,  4.,  1.,  ...,  2.,  4.,  7.],
#         [ 1.,  1.,  0.,  ...,  1., 10.,  4.],
#         [ 1.,  3.,  2.,  ...,  4.,  7.,  2.]])
# Labels: tensor([ 4,  5, 63, 60, 60,  4, 60, 55, 78, 14, 56, 32, 49, 33, 32, 31, 72, 44,
#         72, 73,  6,  9,  8, 32, 38,  4, 21, 32, 24, 62, 39, 35])
# Label Names: ['Aspergillus', 'Backusella', 'Scolecobasidium', 'Russula', 'Russula', 'Aspergillus', 'Russula', 'Pluteus', 'Wickerhamomyces', 'Colacogloea', 'Pseudosperma', 'Inocybe', 'Orbilia', 'Inosperma', 'Inocybe', 'Hypoxylon', 'Tremella', 'Mortierella', 'Tremella', 'Trichoderma', 'Bambusicola', 'Candida', 'Boletus', 'Inocybe', 'Lepiota', 'Aspergillus', 'Entoloma', 'Inocybe', 'Geastrum', 'Saturnispora', 'Leucoagaricus', 'Lactarius']
# print len of label names: 32
#
# Batch 16:
# Data: tensor([[ 2.,  2.,  1.,  ...,  5.,  5.,  0.],
#         [ 2.,  3.,  3.,  ...,  3.,  3.,  4.],
#         [ 2.,  2.,  3.,  ...,  7.,  6.,  7.],
#         ...,
#         [ 4.,  5.,  3.,  ...,  2.,  2.,  3.],
#         [ 2.,  4.,  2.,  ...,  4.,  2.,  1.],
#         [ 4.,  0.,  3.,  ...,  5., 12.,  7.]])
# Labels: tensor([75, 66, 32, 21, 32, 29, 45, 68,  9, 39, 50, 39, 15, 71,  0, 29,  1, 49,
#         80, 45,  1, 71, 25, 72, 14, 32,  4, 44, 44, 79, 66, 32])
# Label Names: ['Tuber', 'Starmerella', 'Inocybe', 'Entoloma', 'Inocybe', 'Hygrophorus', 'Mucor', 'Suhomyces', 'Candida', 'Leucoagaricus', 'Otidea', 'Leucoagaricus', 'Coprinopsis', 'Trechispora', 'Absidia', 'Hygrophorus', 'Amanita', 'Orbilia', 'Xylodon', 'Mucor', 'Amanita', 'Trechispora', 'Genea', 'Tremella', 'Colacogloea', 'Inocybe', 'Aspergillus', 'Mortierella', 'Mortierella', 'Xylaria', 'Starmerella', 'Inocybe']
# print len of label names: 32
#
# Batch 17:
# Data: tensor([[ 7.,  6.,  5.,  ...,  3.,  5.,  9.],
#         [ 9.,  9.,  3.,  ...,  2.,  4., 17.],
#         [ 3.,  4.,  1.,  ...,  3.,  6.,  3.],
#         ...,
#         [ 7.,  4.,  4.,  ...,  5.,  9., 23.],
#         [ 3.,  1.,  1.,  ...,  9.,  6.,  7.],
#         [ 1.,  4.,  1.,  ...,  5.,  5.,  7.]])
# Labels: tensor([45, 41, 59, 61, 54, 79, 32, 23, 61,  1,  1, 13, 45, 71, 46, 22, 11, 32,
#         80, 34, 19, 63, 45, 32, 62, 32,  8, 27, 24, 40, 50, 65])
# Label Names: ['Mucor', 'Malassezia', 'Roussoella', 'Saccharomycopsis', 'Pichia', 'Xylaria', 'Inocybe', 'Fomitiporia', 'Saccharomycopsis', 'Amanita', 'Amanita', 'Clavulina', 'Mucor', 'Trechispora', 'Mycena', 'Exophiala', 'Cladophialophora', 'Inocybe', 'Xylodon', 'Kazachstania', 'Cyphellophora', 'Scolecobasidium', 'Mucor', 'Inocybe', 'Saturnispora', 'Inocybe', 'Boletus', 'Hydnellum', 'Geastrum', 'Lipomyces', 'Otidea', 'Spathaspora']
# print len of label names: 32
#
# Batch 18:
# Data: tensor([[13., 11.,  3.,  ...,  4.,  8.,  4.],
#         [ 5.,  3.,  3.,  ...,  2.,  7.,  6.],
#         [ 1.,  4.,  0.,  ...,  3.,  9., 14.],
#         ...,
#         [ 4.,  3.,  3.,  ...,  5.,  8., 12.],
#         [17.,  5.,  2.,  ...,  6.,  5., 17.],
#         [10.,  3.,  3.,  ...,  2.,  3.,  9.]])
# Labels: tensor([49,  1,  1, 45,  0, 16, 35,  2, 38, 34, 18, 25, 16, 19,  9,  1, 49,  8,
#         62, 32,  8,  7,  9, 32,  1, 76, 58,  9, 32, 32, 43, 45])
# Label Names: ['Orbilia', 'Amanita', 'Amanita', 'Mucor', 'Absidia', 'Cortinarius', 'Lactarius', 'Apiospora', 'Lepiota', 'Kazachstania', 'Cyberlindnera', 'Genea', 'Cortinarius', 'Cyphellophora', 'Candida', 'Amanita', 'Orbilia', 'Boletus', 'Saturnispora', 'Inocybe', 'Boletus', 'Blastobotrys', 'Candida', 'Inocybe', 'Amanita', 'Verrucaria', 'Ramaria', 'Candida', 'Inocybe', 'Inocybe', 'Metschnikowia', 'Mucor']
# print len of label names: 32
#
# Batch 19:
# Data: tensor([[ 0.,  0.,  1.,  ...,  4.,  7., 17.],
#         [ 5.,  4.,  4.,  ...,  5.,  5.,  7.],
#         [ 3.,  1.,  2.,  ...,  5.,  8.,  6.],
#         ...,
#         [ 7.,  9.,  1.,  ...,  5.,  3.,  4.],
#         [ 7.,  5.,  3.,  ...,  7., 10.,  4.],
#         [ 0.,  2.,  1.,  ...,  3.,  9.,  5.]])
# Labels: tensor([56, 11, 33, 35, 12,  1, 13, 19,  9, 42, 80, 49, 45,  8, 17, 74,  1, 27,
#         67, 49, 63,  8, 73, 25, 75, 60, 29, 30, 56, 75, 60, 39])
# Label Names: ['Pseudosperma', 'Cladophialophora', 'Inosperma', 'Lactarius', 'Clavaria', 'Amanita', 'Clavulina', 'Cyphellophora', 'Candida', 'Marasmius', 'Xylodon', 'Orbilia', 'Mucor', 'Boletus', 'Crepidotus', 'Tricholoma', 'Amanita', 'Hydnellum', 'Sugiyamaella', 'Orbilia', 'Scolecobasidium', 'Boletus', 'Trichoderma', 'Genea', 'Tuber', 'Russula', 'Hygrophorus', 'Hymenochaete', 'Pseudosperma', 'Tuber', 'Russula', 'Leucoagaricus']
# print len of label names: 32
#
# Batch 20:
# Label Names: ['Lipomyces', 'Candida', 'Gymnopus', 'Scolecobasidium', 'Geastrum', 'Leucoagaricus', 'Absidia', 'Bambusicola', 'Entoloma', 'Geastrum', 'Inocybe', 'Boletus', 'Tremella', 'Verrucaria', 'Lactifluus', 'Tricholoma', 'Saturnispora', 'Crepidotus', 'Lactifluus', 'Geastrum', 'Boletus', 'Phylloporus', 'Amanita', 'Inocybe', 'Inosperma', 'Inocybe', 'Inocybe', 'Entoloma', 'Wickerhamiella', 'Mucor', 'Lepiota', 'Inocybe']
# print len of label names: 32
#
# Batch 23:
# Data: tensor([[ 5.,  5.,  2.,  ...,  3.,  3.,  6.],
#         [10.,  2.,  3.,  ...,  5.,  2.,  7.],
#         [ 2.,  1.,  2.,  ...,  4.,  7.,  4.],
#         ...,
#         [ 5.,  3.,  1.,  ...,  3.,  7., 12.],
#         [ 2.,  2.,  1.,  ...,  2.,  2.,  0.],
#         [14.,  8.,  3.,  ...,  4.,  1.,  0.]])
# Labels: tensor([66, 31, 38, 31,  0, 14,  2, 32, 28, 21, 72,  1, 49, 55, 75,  1, 68,  9,
#         64,  1, 68, 16, 31, 32, 75, 15, 11, 28, 18, 40,  4, 54])
# Label Names: ['Starmerella', 'Hypoxylon', 'Lepiota', 'Hypoxylon', 'Absidia', 'Colacogloea', 'Apiospora', 'Inocybe', 'Hygrocybe', 'Entoloma', 'Tremella', 'Amanita', 'Orbilia', 'Pluteus', 'Tuber', 'Amanita', 'Suhomyces', 'Candida', 'Scytinostroma', 'Amanita', 'Suhomyces', 'Cortinarius', 'Hypoxylon', 'Inocybe', 'Tuber', 'Coprinopsis', 'Cladophialophora', 'Hygrocybe', 'Cyberlindnera', 'Lipomyces', 'Aspergillus', 'Pichia']
# print len of label names: 32
#
# Batch 24:
# Data: tensor([[ 4.,  7.,  1.,  ...,  2.,  1.,  0.],
#         [ 3.,  3.,  4.,  ...,  3.,  2.,  4.],
#         [ 0.,  1.,  1.,  ...,  8.,  5.,  5.],
#         ...,
#         [ 1.,  2.,  4.,  ...,  3.,  8.,  7.],
#         [ 7.,  4.,  3.,  ...,  5., 10.,  5.],
#         [ 2.,  1.,  1.,  ...,  4., 12.,  9.]])
# Labels: tensor([75, 63,  8, 32, 67, 58, 73, 49,  4, 44, 46, 39, 69,  1, 49, 58, 52, 36,
#         73, 55, 49, 22, 56, 56, 45, 32, 32, 70, 36, 46, 32, 32])
# Label Names: ['Tuber', 'Scolecobasidium', 'Boletus', 'Inocybe', 'Sugiyamaella', 'Ramaria', 'Trichoderma', 'Orbilia', 'Aspergillus', 'Mortierella', 'Mycena', 'Leucoagaricus', 'Talaromyces', 'Amanita', 'Orbilia', 'Ramaria', 'Phylloporus', 'Lactifluus', 'Trichoderma', 'Pluteus', 'Orbilia', 'Exophiala', 'Pseudosperma', 'Pseudosperma', 'Mucor', 'Inocybe', 'Inocybe', 'Tomentella', 'Lactifluus', 'Mycena', 'Inocybe', 'Inocybe']
# print len of label names: 32
#
# Batch 25:
# Data: tensor([[ 2.,  0.,  3.,  ...,  4.,  9.,  4.],
#         [ 6.,  4.,  5.,  ...,  4.,  6.,  8.],
#         [ 5.,  2.,  2.,  ...,  5.,  9.,  2.],
#         ...,
#         [ 0.,  2.,  2.,  ...,  2., 11.,  3.],
#         [ 5.,  4.,  2.,  ...,  8., 10., 10.],
#         [ 2.,  1.,  3.,  ...,  5.,  5.,  4.]])
# Labels: tensor([27, 63, 35, 60, 36, 45, 41, 52, 16, 24,  1,  4, 14, 16,  2, 69,  5, 32,
#          9,  7, 21, 34,  8, 25, 56, 21, 10, 73, 44, 80, 21, 33])
# Label Names: ['Hydnellum', 'Scolecobasidium', 'Lactarius', 'Russula', 'Lactifluus', 'Mucor', 'Malassezia', 'Phylloporus', 'Cortinarius', 'Geastrum', 'Amanita', 'Aspergillus', 'Colacogloea', 'Cortinarius', 'Apiospora', 'Talaromyces', 'Backusella', 'Inocybe', 'Candida', 'Blastobotrys', 'Entoloma', 'Kazachstania', 'Boletus', 'Genea', 'Pseudosperma', 'Entoloma', 'Cantharellus', 'Trichoderma', 'Mortierella', 'Xylodon', 'Entoloma', 'Inosperma']
# print len of label names: 32
#
# Batch 26:
# Data: tensor([[ 4.,  6.,  2.,  ...,  3.,  7.,  7.],
#         [ 3.,  5.,  1.,  ...,  2.,  2.,  0.],
#         [ 4.,  2.,  2.,  ...,  3.,  5., 11.],
#         ...,
#         [11.,  0.,  4.,  ...,  3.,  4.,  1.],
#         [ 2.,  3.,  4.,  ...,  2.,  8.,  8.],
#         [ 4., 10.,  3.,  ...,  3.,  7.,  6.]])
# Labels: tensor([38, 31,  0, 22, 18,  9, 24, 29, 55, 75, 32, 59,  9, 36, 73, 50, 32, 32,
#         60, 70, 34,  8, 17,  8, 32, 21, 36, 45, 59, 80, 77, 41])
# Label Names: ['Lepiota', 'Hypoxylon', 'Absidia', 'Exophiala', 'Cyberlindnera', 'Candida', 'Geastrum', 'Hygrophorus', 'Pluteus', 'Tuber', 'Inocybe', 'Roussoella', 'Candida', 'Lactifluus', 'Trichoderma', 'Otidea', 'Inocybe', 'Inocybe', 'Russula', 'Tomentella', 'Kazachstania', 'Boletus', 'Crepidotus', 'Boletus', 'Inocybe', 'Entoloma', 'Lactifluus', 'Mucor', 'Roussoella', 'Xylodon', 'Wickerhamiella', 'Malassezia']
# print len of label names: 32
#
# Batch 27:
# Data: tensor([[8., 3., 3.,  ..., 6., 6., 6.],
#         [4., 4., 1.,  ..., 4., 7., 7.],
#         [2., 4., 2.,  ..., 4., 8., 6.],
#         ...,
#         [4., 5., 3.,  ..., 5., 4., 4.],
#         [1., 1., 1.,  ..., 2., 2., 0.],
#         [0., 3., 2.,  ..., 3., 6., 4.]])
# Labels: tensor([32, 32, 63, 58, 47, 21, 78, 78, 67, 32, 32, 21, 36, 27,  6, 35, 21,  1,
#         61, 60, 77, 30, 70, 47, 32,  7,  3, 35, 47, 42, 69, 72])
# Label Names: ['Inocybe', 'Inocybe', 'Scolecobasidium', 'Ramaria', 'Ogataea', 'Entoloma', 'Wickerhamomyces', 'Wickerhamomyces', 'Sugiyamaella', 'Inocybe', 'Inocybe', 'Entoloma', 'Lactifluus', 'Hydnellum', 'Bambusicola', 'Lactarius', 'Entoloma', 'Amanita', 'Saccharomycopsis', 'Russula', 'Wickerhamiella', 'Hymenochaete', 'Tomentella', 'Ogataea', 'Inocybe', 'Blastobotrys', 'Arthroderma', 'Lactarius', 'Ogataea', 'Marasmius', 'Talaromyces', 'Tremella']
# print len of label names: 32
#
# Batch 28:
# Data: tensor([[ 4.,  2.,  3.,  ...,  9.,  9.,  5.],
#         [ 5.,  4.,  4.,  ...,  5.,  4.,  6.],
#         [ 8.,  4.,  4.,  ...,  4.,  5.,  4.],
#         ...,
#         [ 4.,  1.,  3.,  ...,  6.,  8.,  8.],
#         [ 6.,  3.,  3.,  ...,  6., 10.,  3.],
#         [ 4.,  9.,  4.,  ...,  2.,  6.,  4.]])
# Labels: tensor([21, 53, 72, 73, 21, 27, 32, 80,  1, 38, 31, 32, 32, 10, 45, 28, 54, 32,
#         27, 71, 43, 42, 36, 38, 42, 64, 24, 54, 36, 33, 74, 49])
# Label Names: ['Entoloma', 'Phyllosticta', 'Tremella', 'Trichoderma', 'Entoloma', 'Hydnellum', 'Inocybe', 'Xylodon', 'Amanita', 'Lepiota', 'Hypoxylon', 'Inocybe', 'Inocybe', 'Cantharellus', 'Mucor', 'Hygrocybe', 'Pichia', 'Inocybe', 'Hydnellum', 'Trechispora', 'Metschnikowia', 'Marasmius', 'Lactifluus', 'Lepiota', 'Marasmius', 'Scytinostroma', 'Geastrum', 'Pichia', 'Lactifluus', 'Inosperma', 'Tricholoma', 'Orbilia']
# print len of label names: 32
#
# Batch 29:
# Data: tensor([[ 9.,  9.,  4.,  ...,  4.,  9.,  6.],
#         [ 5.,  8.,  1.,  ...,  5.,  3.,  5.],
#         [ 1.,  1.,  3.,  ...,  1., 10.,  4.],
#         ...,
#         [ 7.,  5.,  3.,  ...,  2.,  1.,  0.],
#         [ 7.,  3.,  2.,  ...,  4.,  9.,  3.],
#         [ 0.,  2.,  1.,  ...,  1.,  1.,  0.]])
# Labels: tensor([49, 66, 70, 45, 16, 71, 21, 33, 55, 58, 53, 79, 32, 65, 40, 32, 33, 34,
#         71, 69, 78, 10, 45, 32,  1, 66, 17, 13, 43,  3, 32,  6])
# Label Names: ['Orbilia', 'Starmerella', 'Tomentella', 'Mucor', 'Cortinarius', 'Trechispora', 'Entoloma', 'Inosperma', 'Pluteus', 'Ramaria', 'Phyllosticta', 'Xylaria', 'Inocybe', 'Spathaspora', 'Lipomyces', 'Inocybe', 'Inosperma', 'Kazachstania', 'Trechispora', 'Talaromyces', 'Wickerhamomyces', 'Cantharellus', 'Mucor', 'Inocybe', 'Amanita', 'Starmerella', 'Crepidotus', 'Clavulina', 'Metschnikowia', 'Arthroderma', 'Inocybe', 'Bambusicola']
# print len of label names: 32
#
# Batch 30:
# Data: tensor([[ 2.,  2.,  3.,  ...,  2.,  5.,  2.],
#         [ 5.,  3.,  4.,  ...,  4.,  8., 15.],
#         [ 2.,  2.,  2.,  ...,  8.,  8.,  6.],
#         ...,
#         [ 6.,  5.,  1.,  ...,  3.,  3.,  3.],
#         [12.,  8.,  1.,  ...,  3.,  2.,  7.],
#         [19.,  5.,  6.,  ...,  7., 10., 18.]])
# Labels: tensor([ 4, 32, 32, 13,  9, 32, 79,  0,  1, 70, 60,  1, 16,  1, 22, 76, 51, 32,
#         42, 64, 49, 73, 21, 49, 66, 49, 34, 80, 32, 75, 43,  1])
# Label Names: ['Aspergillus', 'Inocybe', 'Inocybe', 'Clavulina', 'Candida', 'Inocybe', 'Xylaria', 'Absidia', 'Amanita', 'Tomentella', 'Russula', 'Amanita', 'Cortinarius', 'Amanita', 'Exophiala', 'Verrucaria', 'Perenniporia', 'Inocybe', 'Marasmius', 'Scytinostroma', 'Orbilia', 'Trichoderma', 'Entoloma', 'Orbilia', 'Starmerella', 'Orbilia', 'Kazachstania', 'Xylodon', 'Inocybe', 'Tuber', 'Metschnikowia', 'Amanita']
# print len of label names: 32
#
# Batch 31:
# Data: tensor([[6., 1., 2.,  ..., 5., 7., 5.],
#         [0., 3., 2.,  ..., 5., 8., 2.],
#         [3., 0., 4.,  ..., 3., 7., 0.],
#         ...,
#         [1., 3., 2.,  ..., 2., 3., 3.],
#         [3., 3., 1.,  ..., 2., 5., 2.],
#         [7., 5., 0.,  ..., 3., 2., 1.]])
# Labels: tensor([32, 58, 24, 21, 60, 21, 49, 18, 36, 49, 21, 45, 44, 45, 32, 52, 68, 18,
#         49, 29,  1, 78, 65, 60,  7, 77, 60, 30, 53, 63, 37, 75])
# Label Names: ['Inocybe', 'Ramaria', 'Geastrum', 'Entoloma', 'Russula', 'Entoloma', 'Orbilia', 'Cyberlindnera', 'Lactifluus', 'Orbilia', 'Entoloma', 'Mucor', 'Mortierella', 'Mucor', 'Inocybe', 'Phylloporus', 'Suhomyces', 'Cyberlindnera', 'Orbilia', 'Hygrophorus', 'Amanita', 'Wickerhamomyces', 'Spathaspora', 'Russula', 'Blastobotrys', 'Wickerhamiella', 'Russula', 'Hymenochaete', 'Phyllosticta', 'Scolecobasidium', 'Lecanora', 'Tuber']
# print len of label names: 32
#
# Batch 32:
# Data: tensor([[ 2.,  1.,  3.,  ...,  6.,  9., 18.],
#         [ 0.,  0.,  3.,  ..., 10.,  5.,  8.],
#         [ 5.,  3.,  4.,  ...,  9.,  6., 12.],
#         ...,
#         [ 4.,  3.,  3.,  ...,  6.,  9., 14.],
#         [ 9.,  5.,  3.,  ...,  4.,  8., 11.],
#         [ 1.,  4.,  2.,  ...,  4.,  9.,  3.]])
# Labels: tensor([13,  8, 32, 60, 26, 19, 41, 42, 32,  4, 49, 52,  1, 43, 13, 75, 36, 44,
#         32, 45, 67, 39, 48, 32, 63, 35, 11, 78, 71, 32, 67, 46])
# Data: tensor([[2., 4., 1.,  ..., 3., 1., 6.],
#         [4., 1., 1.,  ..., 5., 7., 2.],
#         [1., 3., 2.,  ..., 1., 1., 0.],
#         ...,
#         [6., 5., 2.,  ..., 3., 5., 8.],
#         [8., 6., 0.,  ..., 2., 2., 0.],
#         [5., 0., 2.,  ..., 5., 9., 9.]])
# Labels: tensor([73, 35, 75, 65, 39, 36, 32, 32, 21, 34, 67, 60, 32, 25, 22, 34, 80, 52,
#          1, 12, 41, 71, 47, 52,  4, 32, 58, 55, 21, 59, 73, 32])
# Label Names: ['Trichoderma', 'Lactarius', 'Tuber', 'Spathaspora', 'Leucoagaricus', 'Lactifluus', 'Inocybe', 'Inocybe', 'Entoloma', 'Kazachstania', 'Sugiyamaella', 'Russula', 'Inocybe', 'Genea', 'Exophiala', 'Kazachstania', 'Xylodon', 'Phylloporus', 'Amanita', 'Clavaria', 'Malassezia', 'Trechispora', 'Ogataea', 'Phylloporus', 'Aspergillus', 'Inocybe', 'Ramaria', 'Pluteus', 'Entoloma', 'Roussoella', 'Trichoderma', 'Inocybe']
# print len of label names: 32
#
# Batch 41:
# Data: tensor([[ 3.,  2.,  3.,  ...,  6.,  8.,  4.],
#         [ 5.,  3.,  4.,  ...,  7.,  8.,  8.],
#         [20.,  6.,  3.,  ...,  2.,  3., 31.],
#         ...,
#         [11., 10.,  5.,  ...,  6.,  9.,  8.],
#         [ 4.,  3.,  4.,  ...,  5.,  9., 12.],
#         [ 2.,  3.,  3.,  ...,  3.,  5.,  1.]])
# Labels: tensor([32, 32, 45, 71, 68, 74, 16, 32, 56, 32,  2, 64, 54, 69, 42, 75, 32,  0,
#         65, 16, 20, 38, 71, 32, 24, 64,  6, 10, 49, 49, 28, 70])
# Label Names: ['Inocybe', 'Inocybe', 'Mucor', 'Trechispora', 'Suhomyces', 'Tricholoma', 'Cortinarius', 'Inocybe', 'Pseudosperma', 'Inocybe', 'Apiospora', 'Scytinostroma', 'Pichia', 'Talaromyces', 'Marasmius', 'Tuber', 'Inocybe', 'Absidia', 'Spathaspora', 'Cortinarius', 'Elsinoe', 'Lepiota', 'Trechispora', 'Inocybe', 'Geastrum', 'Scytinostroma', 'Bambusicola', 'Cantharellus', 'Orbilia', 'Orbilia', 'Hygrocybe', 'Tomentella']
# print len of label names: 32
#
# Batch 42:
# Data: tensor([[ 5.,  5.,  4.,  ...,  3., 12.,  8.],
#         [ 1.,  1.,  1.,  ...,  6., 11., 11.],
#         [ 3.,  6.,  0.,  ...,  2.,  1.,  1.],
#         ...,
#         [ 5.,  3.,  6.,  ...,  6.,  9., 13.],
#         [ 4.,  1.,  4.,  ...,  3.,  4., 11.],
#         [13.,  7.,  2.,  ...,  4.,  8., 24.]])
# Labels: tensor([26, 13, 73, 60, 78, 35, 32, 32, 20, 66, 56, 47, 77, 49, 40, 42, 12, 28,
#         21, 73, 54,  2,  9, 32, 44, 77, 25, 72, 32, 42, 77, 40])
# Label Names: ['Gymnopus', 'Clavulina', 'Trichoderma', 'Russula', 'Wickerhamomyces', 'Lactarius', 'Inocybe', 'Inocybe', 'Elsinoe', 'Starmerella', 'Pseudosperma', 'Ogataea', 'Wickerhamiella', 'Orbilia', 'Lipomyces', 'Marasmius', 'Clavaria', 'Hygrocybe', 'Entoloma', 'Trichoderma', 'Pichia', 'Apiospora', 'Candida', 'Inocybe', 'Mortierella', 'Wickerhamiella', 'Genea', 'Tremella', 'Inocybe', 'Marasmius', 'Wickerhamiella', 'Lipomyces']
# print len of label names: 32
#
# Batch 43:
# Data: tensor([[ 7.,  2.,  4.,  ...,  9.,  7., 12.],
#         [ 3.,  4.,  3.,  ...,  4., 10.,  8.],
#         [ 2.,  3.,  1.,  ...,  2., 10.,  6.],
#         ...,
#         [15.,  3.,  5.,  ...,  4.,  7., 30.],
#         [ 2.,  4.,  0.,  ...,  3.,  2.,  1.],
#         [ 4.,  4.,  3.,  ...,  9.,  9., 11.]])
# Labels: tensor([32, 35, 39, 58, 42, 12, 53, 17, 21, 75, 72, 50, 32, 13, 76,  8, 44, 21,
#         33, 28, 32, 45, 21, 50, 49, 21, 34, 26, 32, 45, 57, 32])
# Label Names: ['Inocybe', 'Lactarius', 'Leucoagaricus', 'Ramaria', 'Marasmius', 'Clavaria', 'Phyllosticta', 'Crepidotus', 'Entoloma', 'Tuber', 'Tremella', 'Otidea', 'Inocybe', 'Clavulina', 'Verrucaria', 'Boletus', 'Mortierella', 'Entoloma', 'Inosperma', 'Hygrocybe', 'Inocybe', 'Mucor', 'Entoloma', 'Otidea', 'Orbilia', 'Entoloma', 'Kazachstania', 'Gymnopus', 'Inocybe', 'Mucor', 'Raffaelea', 'Inocybe']
# print len of label names: 32
#
# Batch 44:
# Data: tensor([[11.,  5.,  3.,  ...,  6.,  6., 13.],
#         [ 6.,  3.,  0.,  ...,  3.,  7.,  3.],
#         [ 0.,  3.,  0.,  ...,  6.,  9.,  7.],
#         ...,
#         [ 2.,  1.,  1.,  ...,  2.,  6.,  3.],
#         [ 1.,  0.,  2.,  ...,  3., 10.,  7.],
#         [ 4.,  3.,  4.,  ...,  3.,  4.,  1.]])
# Labels: tensor([ 7, 67, 16, 41, 28, 51, 59, 10, 32, 32, 55, 78, 24,  8,  2, 76, 52, 55,
#         52, 32, 45,  9, 32, 61, 49, 23, 23,  4, 48,  1, 29, 69])
# Label Names: ['Blastobotrys', 'Sugiyamaella', 'Cortinarius', 'Malassezia', 'Hygrocybe', 'Perenniporia', 'Roussoella', 'Cantharellus', 'Inocybe', 'Inocybe', 'Pluteus', 'Wickerhamomyces', 'Geastrum', 'Boletus', 'Apiospora', 'Verrucaria', 'Phylloporus', 'Pluteus', 'Phylloporus', 'Inocybe', 'Mucor', 'Candida', 'Inocybe', 'Saccharomycopsis', 'Orbilia', 'Fomitiporia', 'Fomitiporia', 'Aspergillus', 'Ophiocordyceps', 'Amanita', 'Hygrophorus', 'Talaromyces']
# print len of label names: 32
#
# Batch 45:
# Data: tensor([[ 6.,  3.,  4.,  ...,  6.,  8.,  6.],
# Label Names: ['Tricholoma', 'Absidia', 'Inosperma', 'Hydnellum', 'Candida', 'Aspergillus', 'Geastrum', 'Kazachstania', 'Hypoxylon', 'Genea', 'Amanita', 'Mortierella', 'Fomitiporia', 'Entoloma', 'Wickerhamiella', 'Sugiyamaella', 'Mycena', 'Boletus', 'Xylaria', 'Cladophialophora', 'Scolecobasidium', 'Absidia', 'Trichoderma', 'Mycena', 'Orbilia', 'Candida', 'Inocybe', 'Candida', 'Hygrocybe', 'Lactifluus', 'Spathaspora', 'Sugiyamaella']
# print len of label names: 32
#
# Batch 48:
# Data: tensor([[ 5.,  6.,  3.,  ...,  2.,  4.,  3.],
#         [15.,  4.,  0.,  ...,  5.,  2.,  6.],
#         [ 1.,  2.,  2.,  ...,  3.,  5.,  1.],
#         ...,
#         [ 5.,  2.,  2.,  ...,  6.,  5.,  5.],
#         [ 4.,  4.,  2.,  ...,  2.,  2.,  4.],
#         [12.,  4.,  4.,  ...,  2.,  4., 23.]])
# Labels: tensor([49, 43, 68, 43, 65, 37, 56, 31, 45,  9, 16, 58, 28, 14, 71, 63, 75, 13,
#         79, 16, 42, 80, 79, 49, 11, 32, 49, 80,  1, 32, 79, 45])
# Label Names: ['Orbilia', 'Metschnikowia', 'Suhomyces', 'Metschnikowia', 'Spathaspora', 'Lecanora', 'Pseudosperma', 'Hypoxylon', 'Mucor', 'Candida', 'Cortinarius', 'Ramaria', 'Hygrocybe', 'Colacogloea', 'Trechispora', 'Scolecobasidium', 'Tuber', 'Clavulina', 'Xylaria', 'Cortinarius', 'Marasmius', 'Xylodon', 'Xylaria', 'Orbilia', 'Cladophialophora', 'Inocybe', 'Orbilia', 'Xylodon', 'Amanita', 'Inocybe', 'Xylaria', 'Mucor']
# print len of label names: 32
#
# Batch 49:
# Data: tensor([[ 7.,  6.,  2.,  ...,  4.,  7., 13.],
#         [ 1.,  1.,  1.,  ...,  3.,  1.,  1.],
#         [ 5.,  2.,  1.,  ...,  6.,  8.,  4.],
#         ...,
#         [ 3.,  4.,  2.,  ...,  7.,  6.,  0.],
#         [ 9.,  3.,  3.,  ...,  6., 11., 13.],
#         [ 3.,  2.,  4.,  ...,  5.,  9.,  5.]])
# Labels: tensor([78, 76, 16, 42,  7, 73,  1, 12, 75, 56, 15, 25, 38, 17, 33, 32, 59, 71,
#         28, 32, 18, 49,  6, 24, 80,  1, 50, 49, 32, 32, 36, 14])
# Label Names: ['Wickerhamomyces', 'Verrucaria', 'Cortinarius', 'Marasmius', 'Blastobotrys', 'Trichoderma', 'Amanita', 'Clavaria', 'Tuber', 'Pseudosperma', 'Coprinopsis', 'Genea', 'Lepiota', 'Crepidotus', 'Inosperma', 'Inocybe', 'Roussoella', 'Trechispora', 'Hygrocybe', 'Inocybe', 'Cyberlindnera', 'Orbilia', 'Bambusicola', 'Geastrum', 'Xylodon', 'Amanita', 'Otidea', 'Orbilia', 'Inocybe', 'Inocybe', 'Lactifluus', 'Colacogloea']
# print len of label names: 32
#
# Batch 50:
# Data: tensor([[ 4.,  1.,  2.,  ...,  1.,  1.,  1.],
# Label Names: ['Amanita', 'Pichia', 'Mucor', 'Hygrophorus', 'Blastobotrys', 'Lepiota', 'Genea', 'Hygrocybe', 'Arthroderma', 'Fomitiporia', 'Otidea', 'Mycena', 'Xylodon', 'Boletus', 'Exophiala', 'Inocybe', 'Amanita', 'Ramaria', 'Ramaria', 'Raffaelea', 'Cladophialophora', 'Tremella', 'Clavaria', 'Suhomyces', 'Orbilia', 'Saturnispora', 'Orbilia', 'Boletus', 'Amanita', 'Inocybe', 'Candida', 'Cortinarius']
# print len of label names: 32
#
# Batch 53:
# Data: tensor([[ 2.,  3.,  1.,  ...,  4.,  3.,  0.],
#         [ 7.,  2.,  4.,  ...,  6., 11., 12.],
#         [ 4.,  4.,  3.,  ...,  4.,  7.,  1.],
#         ...,
#         [13., 11.,  5.,  ...,  3., 10.,  6.],
#         [10.,  2.,  3.,  ...,  2., 11., 13.],
#         [ 2.,  2.,  3.,  ...,  3.,  6.,  6.]])
# Labels: tensor([20, 32, 16, 49, 60,  1,  1, 21, 49, 58,  4, 16, 58, 42, 39, 51,  7, 42,
#         31, 70, 60,  6, 47, 72,  7, 16, 49,  1, 30])
# Label Names: ['Elsinoe', 'Inocybe', 'Cortinarius', 'Orbilia', 'Russula', 'Amanita', 'Amanita', 'Entoloma', 'Orbilia', 'Ramaria', 'Aspergillus', 'Cortinarius', 'Ramaria', 'Marasmius', 'Leucoagaricus', 'Perenniporia', 'Blastobotrys', 'Marasmius', 'Hypoxylon', 'Tomentella', 'Russula', 'Bambusicola', 'Ogataea', 'Tremella', 'Blastobotrys', 'Cortinarius', 'Orbilia', 'Amanita', 'Hymenochaete']
# print len of label names: 29

# %%
# Define a CNN model with Conv1D layers and fully connected layers
class CNNModel(nn.Module):
    def __init__(self, input_length, nb_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(1, 5, 5, padding='valid')
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool1d(2)
        self.conv2 = nn.Conv1d(5, 10, 5, padding='valid')
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool1d(2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(10 * ((input_length - 4) // 2 - 4) // 2, 500)
        self.relu3 = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, nb_classes)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = x.unsqueeze(1) 
        x = self.relu1(self.conv1(x))
        x = self.pool1(x)
        x = self.relu2(self.conv2(x))
        x = self.pool2(x)
        x = self.flatten(x)
        x = self.relu3(self.fc1(x))
        x = self.dropout(x)
        x = self.softmax(self.fc2(x))
        return x

input_size = len(data_vectors[0])
num_classes = len(label_encoder.classes_)
model = CNNModel(input_size, num_classes)
input_size = len(data_vectors[0])
num_classes = len(label_encoder.classes_)
model = CNNModel(input_size, num_classes)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_size = int(0.8 * len(kmer_dataset))
test_size = len(kmer_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(kmer_dataset, [train_size, test_size])
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Training loop with testing
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0
    for batch_idx, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        outputs = model(data)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

    avg_train_loss = total_train_loss / len(train_loader)
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}')
    model.eval()
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            outputs = model(data)
            _, predicted = torch.max(output