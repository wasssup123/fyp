# %%
# Reading the uploaded FASTA file and modifying the headers to only retain the second string

input_file_path = 'data/fungi_ITS_sorted90.fasta'
output_file_path = 'data/fungi_ITS_cleaned.fasta'

# Open the input file and create the output file
with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
    for line in infile:
        if line.startswith('>'):
            # Splitting the line and keeping only the second string
            header_parts = line.strip().split()
            if len(header_parts) > 1:
                modified_header = '>' + header_parts[1] + '\n'
                outfile.write(modified_header)
            else:
                outfile.write(line)
        else:
            outfile.write(line)

output_file_path
# Out:
# 'data/fungi_ITS_cleaned.fasta'

# %% [markdown]
# # vectorization

# %%
import itertools

def generate_all_kmers(k):
    return [''.join(p) for p in itertools.product('ACGT', repeat=k)]

def kmer_vector(sequence, k):
    # gen all possible k-mers comb
    all_kmers = generate_all_kmers(k)
    vector = [0] * len(all_kmers)
    kmer_to_index = {kmer: idx for idx, kmer in enumerate(all_kmers)}
    for i in range(len(sequence) - k + 1):
        kmer = sequence[i:i+k]
        if kmer in kmer_to_index:
            vector[kmer_to_index[kmer]] += 1
    return vector

input_file_path = 'data/fungi_ITS_cleaned.fasta'
output_file_path = 'data/fungi_ITS_kmer_vector.txt'

############################# k
k = 4


with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
    current_sequence = ""
    current_header = ""
    
    for line in infile:
        if line.startswith('>'):
            if current_sequence:
                vector = kmer_vector(current_sequence, k)
                vector_str = ' '.join(map(str, vector))
                outfile.write(f"{current_header}\t{vector_str}\n")
            current_header = line.strip()
            current_sequence = ""
        else:
            current_sequence += line.strip()
    
    if current_sequence:
        vector = kmer_vector(current_sequence, k)
        vector_str = ' '.join(map(str, vector))
        outfile.write(f"{current_header}\t{vector_str}\n")

output_file_path
# Out:
# 'data/fungi_ITS_kmer_vector.txt'

# %%
from collections import defaultdict


input_file = 'data/fungi_ITS_kmer_vector.txt'
output_file = 'data/fungi_ITS_kmer_vector_filtered.txt'

genera_count = defaultdict(int)
with open(input_file, 'r') as f:
    for line in f:
        if line.startswith('>'):
            genus = line.split()[0][1:]
            genera_count[genus] += 1

# Filtering the sequences and saving to a new file
with open(input_file, 'r') as f, open(output_file, 'w') as out:
    write_line = False
    for line in f:
        if line.startswith('>'):
            genus = line.split()[0][1:]
            write_line = genera_count[genus] >= 10
        if write_line:
            out.write(line)

print("Filtering complete. The results are saved in 'fungi_ITS_kmer_vector_filtered.txt'.")
# Out:
# Filtering complete. The results are saved in 'fungi_ITS_kmer_vector_filtered.txt'.

# %%
# File paths
input_file_path = 'data/fungi_ITS_kmer_vector.txt'
output_file_path = 'data/fungi_ITS_kmer_vector_with_header.txt'

# k value to consider
k = 4

# Generate all possible k-mers for the header row
all_kmers = generate_all_kmers(k)
header_row = "ID\t" + "\t".join(all_kmers) + "\n"

# Open the input file and create the output file with the header row
with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
    # Write the header row to the output file
    outfile.write(header_row)
    # Write the rest of the content from the input file
    for line in infile:
        outfile.write(line)

output_file_path
# Out:
# 'data/fungi_ITS_kmer_vector_with_header.txt'

# %%
# Importing necessary libraries
import pandas as pd

# Load the file into a DataFrame
file_path = 'data/fungi_ITS_kmer_vector_with_header.txt'
df = pd.read_csv(file_path, sep='\t')

# Filter out genera with fewer than 10 sequences
filtered_df = df.groupby('ID').filter(lambda x: len(x) >= 10)

# Save the filtered DataFrame to a new file
filtered_file_path = 'data/fungi_ITS_kmer_vector_filtered.txt'
filtered_df.to_csv(filtered_file_path, sep='\t', index=False)

print("Filtering complete. The results are saved in 'filtered_fungi_ITS_kmer_vector.txt'.")
# Out:
# Filtering complete. The results are saved in 'filtered_fungi_ITS_kmer_vector.txt'.

# %% [markdown]
# # train test split

# %%
import random

input_file_path = 'data/fungi_ITS_kmer_vector_filtered.txt'
train_file_path = 'data/fungi_ITS_train.txt'
test_file_path = 'data/fungi_ITS_test.txt'

data_by_class = {}

with open(input_file_path, 'r') as infile:
    for line in infile:
        line = line.strip()
        if line.startswith('>'):
            parts = line.split('\t')
            if len(parts) == 2:
                label = parts[0][1:]  # remove '>'
                vector_str = parts[1]
                
                if label not in data_by_class:
                    data_by_class[label] = []
                data_by_class[label].append(line)

test_data = []
train_data = []

for label, samples in data_by_class.items():
    if len(samples) > 1:
        test_sample = random.choice(samples)
        test_data.append(test_sample)
        train_data.extend([sample for sample in samples if sample != test_sample])
    else:
        train_data.extend(samples)

with open(train_file_path, 'w') as train_file:
    for line in train_data:
        train_file.write(line + '\n')

with open(test_file_path, 'w') as test_file:
    for line in test_data:
        test_file.write(line + '\n')


train_file_path, test_file_path
# Out:
# ('data/fungi_ITS_train.txt', 'data/fungi_ITS_test.txt')

# %% [markdown]
# # start

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader

# Load data and labels from input file
input_file_path = 'data/fungi_ITS_kmer_vector_filtered.txt'

labels = []
data_vectors = []

with open(input_file_path, 'r') as infile:
    for line in infile:
        line = line.strip()
        if line.startswith('>'):
            parts = line.split('\t')
            if len(parts) == 2:
                label = parts[0][1:]  # remove '>'
                vector_str = parts[1]
                vector = list(map(int, vector_str.split()))
                labels.append(label)
                data_vectors.append(vector)

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

#
data_tensor = torch.tensor(data_vectors, dtype=torch.float32)
labels_tensor = torch.tensor(encoded_labels, dtype=torch.long)

class KmerDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Create the DataLoader
kmer_dataset = KmerDataset(data_tensor, labels_tensor)
dataloader = DataLoader(kmer_dataset, batch_size=32, shuffle=True)

# Create a dictionary to map class indices to class names
class_mapping = {index: label for index, label in enumerate(label_encoder.classes_)}

# Print dataset information
print(len(kmer_dataset))
print(set(labels))
print(len(label_encoder.classes_))

for batch_idx, (data, labels) in enumerate(dataloader):
    print(f"Batch {batch_idx + 1}:")
    print("Data:", data)
    print("Labels:", labels)
    # Map label indices to class names for each batch
    label_names = [class_mapping[idx.item()] for idx in labels]
    print("Label Names:", label_names)
    print("print len of label names:", len(label_names))
    print()
# Out:
# 1693
# {'Marasmius', 'Suhomyces', 'Tricholoma', 'Spathaspora', 'Ophiocordyceps', 'Trichoderma', 'Roussoella', 'Phylloporus', 'Apiospora', 'Mortierella', 'Lepiota', 'Pluteus', 'Backusella', 'Inocybe', 'Pseudosperma', 'Scytinostroma', 'Aspergillus', 'Hydnellum', 'Scolecobasidium', 'Mucor', 'Absidia', 'Raffaelea', 'Arthroderma', 'Pichia', 'Otidea', 'Cortinarius', 'Wickerhamiella', 'Tuber', 'Entoloma', 'Ogataea', 'Xylodon', 'Crepidotus', 'Russula', 'Fomitiporia', 'Lactarius', 'Gymnopus', 'Clavulina', 'Blastobotrys', 'Hypoxylon', 'Ramaria', 'Clavaria', 'Saturnispora', 'Cladophialophora', 'Inosperma', 'Coprinopsis', 'Kazachstania', 'Malassezia', 'Genea', 'Boletus', 'Cantharellus', 'Cyphellophora', 'Colacogloea', 'Metschnikowia', 'Hygrophorus', 'Lipomyces', 'Mycena', 'Perenniporia', 'Wickerhamomyces', 'Candida', 'Lactifluus', 'Tremella', 'Geastrum', 'Leucoagaricus', 'Bambusicola', 'Exophiala', 'Lecanora', 'Phyllosticta', 'Saccharomycopsis', 'Trechispora', 'Elsinoe', 'Xylaria', 'Tomentella', 'Sugiyamaella', 'Hymenochaete', 'Cyberlindnera', 'Amanita', 'Starmerella', 'Hygrocybe', 'Verrucaria', 'Orbilia', 'Talaromyces'}
# 81
# Batch 1:
# Data: tensor([[16.,  3.,  2.,  ...,  3.,  6.,  8.],
#         [ 0.,  2.,  3.,  ...,  7.,  6.,  3.],
#         [ 8.,  4.,  4.,  ...,  4.,  5.,  4.],
#         ...,
#         [ 8.,  5.,  2.,  ...,  4.,  6., 12.],
#         [ 4.,  2.,  2.,  ...,  8.,  6.,  5.],
#         [ 8.,  2.,  6.,  ...,  3., 10.,  8.]])
# Labels: tensor([43, 38, 72, 54, 30, 31, 15, 19, 63, 66, 18, 21, 20, 49, 32, 16, 12, 75,
#         60, 34, 32, 47, 31, 60, 77, 54, 31, 33, 54,  5, 32, 29])
# Label Names: ['Metschnikowia', 'Lepiota', 'Tremella', 'Pichia', 'Hymenochaete', 'Hypoxylon', 'Coprinopsis', 'Cyphellophora', 'Scolecobasidium', 'Starmerella', 'Cyberlindnera', 'Entoloma', 'Elsinoe', 'Orbilia', 'Inocybe', 'Cortinarius', 'Clavaria', 'Tuber', 'Russula', 'Kazachstania', 'Inocybe', 'Ogataea', 'Hypoxylon', 'Russula', 'Wickerhamiella', 'Pichia', 'Hypoxylon', 'Inosperma', 'Pichia', 'Backusella', 'Inocybe', 'Hygrophorus']
# print len of label names: 32
#
# Batch 2:
# Data: tensor([[ 3.,  3.,  3.,  ...,  7.,  6., 10.],
#         [17.,  8.,  3.,  ...,  4.,  3.,  6.],
#         [ 1.,  4.,  2.,  ...,  4.,  9.,  3.],
#         ...,
#         [ 6.,  7.,  3.,  ...,  8.,  9., 10.],
#         [ 3.,  3.,  2.,  ...,  4., 11.,  6.],
#         [ 0.,  1.,  0.,  ...,  6.,  8.,  6.]])
# Labels: tensor([56,  9, 46, 17, 22, 51, 10, 59,  2, 55, 49, 32, 63,  6, 69, 11, 32, 40,
#         47, 76, 78,  1, 21, 33, 50, 42, 60,  1, 35, 34, 46, 16])
# Label Names: ['Pseudosperma', 'Candida', 'Mycena', 'Crepidotus', 'Exophiala', 'Perenniporia', 'Cantharellus', 'Roussoella', 'Apiospora', 'Pluteus', 'Orbilia', 'Inocybe', 'Scolecobasidium', 'Bambusicola', 'Talaromyces', 'Cladophialophora', 'Inocybe', 'Lipomyces', 'Ogataea', 'Verrucaria', 'Wickerhamomyces', 'Amanita', 'Entoloma', 'Inosperma', 'Otidea', 'Marasmius', 'Russula', 'Amanita', 'Lactarius', 'Kazachstania', 'Mycena', 'Cortinarius']
# print len of label names: 32
#
# Batch 3:
# Data: tensor([[ 0.,  0.,  1.,  ...,  3.,  8., 11.],
#         [ 9.,  3.,  3.,  ...,  2.,  8.,  6.],
#         [ 4.,  2.,  2.,  ...,  4.,  4.,  5.],
#         ...,
#         [ 4.,  3.,  4.,  ...,  3.,  2.,  0.],
#         [14.,  5.,  2.,  ...,  2.,  3., 10.],
#         [ 1.,  1.,  2.,  ...,  3.,  7.,  2.]])
# Labels: tensor([56,  1, 13, 11, 75, 24, 38, 60, 58, 71, 52, 56,  2, 75, 12, 49,  5, 34,
#         40, 47, 34, 57, 64,  4, 47, 47,  9, 75, 70, 69, 77, 15])
# Label Names: ['Pseudosperma', 'Amanita', 'Clavulina', 'Cladophialophora', 'Tuber', 'Geastrum', 'Lepiota', 'Russula', 'Ramaria', 'Trechispora', 'Phylloporus', 'Pseudosperma', 'Apiospora', 'Tuber', 'Clavaria', 'Orbilia', 'Backusella', 'Kazachstania', 'Lipomyces', 'Ogataea', 'Kazachstania', 'Raffaelea', 'Scytinostroma', 'Aspergillus', 'Ogataea', 'Ogataea', 'Candida', 'Tuber', 'Tomentella', 'Talaromyces', 'Wickerhamiella', 'Coprinopsis']
# print len of label names: 32
#
# Batch 4:
# Data: tensor([[ 1.,  4.,  1.,  ...,  5.,  5.,  7.],
#         [ 6.,  6.,  4.,  ...,  7.,  7., 10.],
#         [ 2.,  4.,  0.,  ...,  7., 11.,  9.],
#         ...,
#         [ 1.,  2.,  2.,  ...,  4.,  7.,  5.],
#         [ 2.,  3.,  1.,  ...,  5.,  3.,  3.],
#         [12.,  5.,  5.,  ...,  1.,  6., 27.]])
# Labels: tensor([65,  7, 21, 32,  0, 73, 10, 60, 49, 42, 56, 29, 31,  1, 59, 32, 32, 16,
#         10, 49, 21, 27, 69, 75, 71,  4, 80, 21, 32, 46, 25, 45])
# Label Names: ['Spathaspora', 'Blastobotrys', 'Entoloma', 'Inocybe', 'Absidia', 'Trichoderma', 'Cantharellus', 'Russula', 'Orbilia', 'Marasmius', 'Pseudosperma', 'Hygrophorus', 'Hypoxylon', 'Amanita', 'Roussoella', 'Inocybe', 'Inocybe', 'Cortinarius', 'Cantharellus', 'Orbilia', 'Entoloma', 'Hydnellum', 'Talaromyces', 'Tuber', 'Trechispora', 'Aspergillus', 'Xylodon', 'Entoloma', 'Inocybe', 'Mycena', 'Genea', 'Mucor']
# print len of label names: 32
#
# Batch 5:
# Data: tensor([[ 4.,  3.,  5.,  ...,  7.,  8.,  3.],
#         [18.,  4.,  0.,  ...,  2.,  5.,  4.],
#         [ 7.,  6.,  2.,  ...,  2.,  1.,  4.],
#         ...,
#         [ 3.,  4.,  3.,  ...,  4.,  3.,  5.],
#         [ 3.,  4.,  1.,  ...,  8.,  3.,  7.],
#         [ 3.,  4.,  1.,  ...,  4.,  7.,  9.]])
# Labels: tensor([21, 43, 57,  1, 45, 74, 80, 12, 32, 66, 49, 32, 12, 52, 16, 32, 41,  0,
#         60, 36, 55, 17, 32, 39, 22, 18, 14, 39, 23, 11, 18, 32])
# Label Names: ['Entoloma', 'Metschnikowia', 'Raffaelea', 'Amanita', 'Mucor', 'Tricholoma', 'Xylodon', 'Clavaria', 'Inocybe', 'Starmerella', 'Orbilia', 'Inocybe', 'Clavaria', 'Phylloporus', 'Cortinarius', 'Inocybe', 'Malassezia', 'Absidia', 'Russula', 'Lactifluus', 'Pluteus', 'Crepidotus', 'Inocybe', 'Leucoagaricus', 'Exophiala', 'Cyberlindnera', 'Colacogloea', 'Leucoagaricus', 'Fomitiporia', 'Cladophialophora', 'Cyberlindnera', 'Inocybe']
# print len of label names: 32
#
# Batch 6:
# Data: tensor([[6., 1., 3.,  ..., 4., 6., 6.],
#         [2., 4., 4.,  ..., 6., 7., 3.],
#         [2., 1., 1.,  ..., 4., 6., 5.],
#         ...,
#         [3., 3., 3.,  ..., 7., 8., 7.],
#         [0., 2., 2.,  ..., 4., 8., 2.],
#         [2., 2., 0.,  ..., 4., 9., 4.]])
# Labels: tensor([17, 58, 15,  9, 39, 52, 32, 50,  4, 16, 42, 25, 21, 32, 73,  1, 32,  9,
#         70, 16, 32, 79, 56, 24, 32, 23, 20, 32, 21, 32, 80, 35])
# Label Names: ['Crepidotus', 'Ramaria', 'Coprinopsis', 'Candida', 'Leucoagaricus', 'Phylloporus', 'Inocybe', 'Otidea', 'Aspergillus', 'Cortinarius', 'Marasmius', 'Genea', 'Entoloma', 'Inocybe', 'Trichoderma', 'Amanita', 'Inocybe', 'Candida', 'Tomentella', 'Cortinarius', 'Inocybe', 'Xylaria', 'Pseudosperma', 'Geastrum', 'Inocybe', 'Fomitiporia', 'Elsinoe', 'Inocybe', 'Entoloma', 'Inocybe', 'Xylodon', 'Lactarius']
# print len of label names: 32
#
# Batch 7:
# Data: tensor([[ 4.,  2.,  1.,  ...,  3.,  3.,  1.],
#         [ 0.,  2.,  1.,  ...,  6.,  7.,  6.],
#         [ 2.,  0.,  3.,  ...,  3.,  9., 14.],
#         ...,
#         [ 2.,  1.,  4.,  ...,  4., 11.,  5.],
#         [ 2.,  4.,  2.,  ...,  4.,  7.,  9.],
#         [ 3.,  2.,  4.,  ...,  3., 11.,  8.]])
# Labels: tensor([68, 36, 29, 69, 21, 32,  3, 34, 74, 32, 21, 32, 32, 43, 70, 61,  1,  1,
#         39, 75, 13,  1, 32, 22, 49, 55, 60, 41, 25, 35, 65, 28])
# Label Names: ['Suhomyces', 'Lactifluus', 'Hygrophorus', 'Talaromyces', 'Entoloma', 'Inocybe', 'Arthroderma', 'Kazachstania', 'Tricholoma', 'Inocybe', 'Entoloma', 'Inocybe', 'Inocybe', 'Metschnikowia', 'Tomentella', 'Saccharomycopsis', 'Amanita', 'Amanita', 'Leucoagaricus', 'Tuber', 'Clavulina', 'Amanita', 'Inocybe', 'Exophiala', 'Orbilia', 'Pluteus', 'Russula', 'Malassezia', 'Genea', 'Lactarius', 'Spathaspora', 'Hygrocybe']
# print len of label names: 32
#
# Batch 8:
# Data: tensor([[ 6.,  2.,  4.,  ...,  5.,  4.,  8.],
#         [ 1.,  3.,  1.,  ...,  7.,  6., 11.],
#         [ 4.,  3.,  5.,  ...,  8.,  8.,  8.],
#         ...,
#         [ 1.,  2.,  1.,  ...,  1.,  2.,  0.],
#         [ 2.,  4.,  4.,  ...,  8.,  4., 10.],
#         [ 0.,  3.,  1.,  ...,  7.,  9.,  8.]])
# Labels: tensor([44, 16,  1, 32, 32,  4, 32,  1, 69, 67, 28, 68, 32, 63, 36, 62, 38, 36,
#         32, 76,  9, 77, 54, 28, 32, 32, 75, 37,  9, 79, 32, 32])
# Label Names: ['Mortierella', 'Cortinarius', 'Amanita', 'Inocybe', 'Inocybe', 'Aspergillus', 'Inocybe', 'Amanita', 'Talaromyces', 'Sugiyamaella', 'Hygrocybe', 'Suhomyces', 'Inocybe', 'Scolecobasidium', 'Lactifluus', 'Saturnispora', 'Lepiota', 'Lactifluus', 'Inocybe', 'Verrucaria', 'Candida', 'Wickerhamiella', 'Pichia', 'Hygrocybe', 'Inocybe', 'Inocybe', 'Tuber', 'Lecanora', 'Candida', 'Xylaria', 'Inocybe', 'Inocybe']
# print len of label names: 32
#
# Batch 9:
# Data: tensor([[2., 2., 2.,  ..., 3., 4., 3.],
#         [5., 2., 1.,  ..., 6., 8., 4.],
#         [2., 1., 1.,  ..., 2., 9., 4.],
#         ...,
#         [7., 2., 3.,  ..., 5., 6., 4.],
#         [5., 5., 4.,  ..., 4., 7., 5.],
#         [1., 3., 1.,  ..., 1., 9., 2.]])
# Labels: tensor([63, 16, 39, 45, 58,  1, 20, 63,  8,  4, 34, 31, 58, 31, 22, 37, 36, 16,
#         30, 32, 25, 35, 64, 46, 49, 32, 20,  1, 77,  9, 67, 70])
# Label Names: ['Scolecobasidium', 'Cortinarius', 'Leucoagaricus', 'Mucor', 'Ramaria', 'Amanita', 'Elsinoe', 'Scolecobasidium', 'Boletus', 'Aspergillus', 'Kazachstania', 'Hypoxylon', 'Ramaria', 'Hypoxylon', 'Exophiala', 'Lecanora', 'Lactifluus', 'Cortinarius', 'Hymenochaete', 'Inocybe', 'Genea', 'Lactarius', 'Scytinostroma', 'Mycena', 'Orbilia', 'Inocybe', 'Elsinoe', 'Amanita', 'Wickerhamiella', 'Candida', 'Sugiyamaella', 'Tomentella']
# print len of label names: 32
#
# Batch 10:
# Data: tensor([[14.,  2.,  5.,  ...,  3.,  8., 20.],
#         [ 3.,  4.,  2.,  ...,  4.,  8., 19.],
#         [ 6.,  3.,  4.,  ...,  1., 12.,  9.],
#         ...,
#         [ 6.,  4.,  5.,  ...,  2.,  6.,  5.],
#         [ 1.,  5.,  2.,  ...,  8.,  6.,  8.],
#         [ 2.,  4.,  0.,  ...,  5.,  7.,  5.]])
# Labels: tensor([44, 18, 28, 27, 16, 55, 74, 49, 62, 42, 37, 31, 11, 52, 56, 56,  1,  4,
#         25, 49, 28, 75, 32, 13, 80, 31, 74, 12, 54, 63, 32, 50])
# Label Names: ['Mortierella', 'Cyberlindnera', 'Hygrocybe', 'Hydnellum', 'Cortinarius', 'Pluteus', 'Tricholoma', 'Orbilia', 'Saturnispora', 'Marasmius', 'Lecanora', 'Hypoxylon', 'Cladophialophora', 'Phylloporus', 'Pseudosperma', 'Pseudosperma', 'Amanita', 'Aspergillus', 'Genea', 'Orbilia', 'Hygrocybe', 'Tuber', 'Inocybe', 'Clavulina', 'Xylodon', 'Hypoxylon', 'Tricholoma', 'Clavaria', 'Pichia', 'Scolecobasidium', 'Inocybe', 'Otidea']
# print len of label names: 32
#
# Batch 11:
# Data: tensor([[ 7.,  1.,  3.,  ...,  4.,  6., 10.],
#         [ 2.,  5.,  3.,  ...,  3.,  7.,  8.],
#         [ 6.,  0.,  3.,  ...,  2.,  5.,  1.],
#         ...,
#         [ 5.,  6.,  4.,  ...,  5.,  6.,  3.],
#         [13., 11.,  3.,  ...,  3.,  6.,  5.],
#         [ 9.,  4.,  3.,  ...,  3.,  3.,  3.]])
# Labels: tensor([32, 44, 64, 58, 67, 42, 16,  1, 36, 73, 14, 33, 41, 68, 68, 60, 74, 25,
#          9,  1, 70, 39, 44, 30, 21, 79, 80, 22, 67, 35, 49, 77])
# Label Names: ['Inocybe', 'Mortierella', 'Scytinostroma', 'Ramaria', 'Sugiyamaella', 'Marasmius', 'Cortinarius', 'Amanita', 'Lactifluus', 'Trichoderma', 'Colacogloea', 'Inosperma', 'Malassezia', 'Suhomyces', 'Suhomyces', 'Russula', 'Tricholoma', 'Genea', 'Candida', 'Amanita', 'Tomentella', 'Leucoagaricus', 'Mortierella', 'Hymenochaete', 'Entoloma', 'Xylaria', 'Xylodon', 'Exophiala', 'Sugiyamaella', 'Lactarius', 'Orbilia', 'Wickerhamiella']
# print len of label names: 32
#
# Batch 12:
# Data: tensor([[ 3.,  3.,  4.,  ...,  4.,  4.,  2.],
#         [ 4.,  2.,  6.,  ...,  6.,  8., 14.],
#         [10.,  4.,  5.,  ...,  4., 10., 14.],
#         ...,
#         [ 3.,  4.,  2.,  ...,  5., 10., 12.],
#         [ 6.,  5.,  2.,  ...,  4.,  8., 10.],
#         [10.,  8.,  5.,  ...,  6.,  8.,  5.]])
# Labels: tensor([ 9, 60, 29, 32,  6, 45, 32, 30, 49, 78, 46, 36,  4, 49, 53, 42, 32, 32,
#         49, 59, 43, 21, 32, 29, 75, 68, 76, 40, 65, 61, 44, 49])
# Label Names: ['Candida', 'Russula', 'Hygrophorus', 'Inocybe', 'Bambusicola', 'Mucor', 'Inocybe', 'Hymenochaete', 'Orbilia', 'Wickerhamomyces', 'Mycena', 'Lactifluus', 'Aspergillus', 'Orbilia', 'Phyllosticta', 'Marasmius', 'Inocybe', 'Inocybe', 'Orbilia', 'Roussoella', 'Metschnikowia', 'Entoloma', 'Inocybe', 'Hygrophorus', 'Tuber', 'Suhomyces', 'Verrucaria', 'Lipomyces', 'Spathaspora', 'Saccharomycopsis', 'Mortierella', 'Orbilia']
# print len of label names: 32
#
# Batch 13:
# Data: tensor([[ 1.,  3.,  2.,  ...,  5.,  9., 10.],
#         [ 6.,  8.,  5.,  ...,  3.,  6.,  2.],
#         [ 3.,  4.,  2.,  ...,  2.,  6.,  2.],
#         ...,
#         [ 4.,  8.,  3.,  ...,  3.,  3.,  2.],
#         [ 8., 11.,  7.,  ...,  5.,  6.,  4.],
#         [10.,  2.,  4.,  ...,  3.,  9.,  9.]])
# Labels: tensor([21, 49, 72, 51,  4, 27, 47, 75, 49, 78,  7,  1, 35,  0, 77, 14,  0, 63,
#          9,  9, 10, 76, 66,  7, 33, 71, 53, 45, 36, 19, 49, 32])
# Label Names: ['Entoloma', 'Orbilia', 'Tremella', 'Perenniporia', 'Aspergillus', 'Hydnellum', 'Ogataea', 'Tuber', 'Orbilia', 'Wickerhamomyces', 'Blastobotrys', 'Amanita', 'Lactarius', 'Absidia', 'Wickerhamiella', 'Colacogloea', 'Absidia', 'Scolecobasidium', 'Candida', 'Candida', 'Cantharellus', 'Verrucaria', 'Starmerella', 'Blastobotrys', 'Inosperma', 'Trechispora', 'Phyllosticta', 'Mucor', 'Lactifluus', 'Cyphellophora', 'Orbilia', 'Inocybe']
# print len of label names: 32
#
# Batch 14:
# Data: tensor([[ 5.,  2.,  3.,  ...,  4., 12.,  7.],
#         [ 2.,  3.,  5.,  ...,  4.,  4.,  4.],
#         [ 6.,  5.,  2.,  ...,  3.,  5.,  8.],
#         ...,
#         [ 7.,  7.,  3.,  ...,  2.,  2.,  1.],
#         [ 6.,  4.,  3.,  ...,  2.,  6.,  6.],
#         [ 3.,  0.,  1.,  ...,  8.,  9.,  7.]])
# Labels: tensor([32, 12, 59, 32, 23,  5, 32, 31, 32, 32, 32, 21, 80, 10,  2, 52, 16,  1,
#         80,  1, 66, 66, 32, 13, 18,  9, 28, 39, 21, 75, 63, 74])
# Label Names: ['Inocybe', 'Clavaria', 'Roussoella', 'Inocybe', 'Fomitiporia', 'Backusella', 'Inocybe', 'Hypoxylon', 'Inocybe', 'Inocybe', 'Inocybe', 'Entoloma', 'Xylodon', 'Cantharellus', 'Apiospora', 'Phylloporus', 'Cortinarius', 'Amanita', 'Xylodon', 'Amanita', 'Starmerella', 'Starmerella', 'Inocybe', 'Clavulina', 'Cyberlindnera', 'Candida', 'Hygrocybe', 'Leucoagaricus', 'Entoloma', 'Tuber', 'Scolecobasidium', 'Tricholoma']
# print len of label names: 32
#
# Batch 15:
# Data: tensor([[2., 2., 2.,  ..., 5., 5., 4.],
#         [1., 2., 2.,  ..., 7., 8., 6.],
#         [0., 2., 1.,  ..., 1., 6., 3.],
#         ...,
#         [3., 3., 3.,  ..., 6., 5., 6.],
#         [4., 5., 1.,  ..., 1., 6., 0.],
#         [2., 3., 3.,  ..., 3., 3., 2.]])
# Labels: tensor([15, 36, 71, 32, 49,  8,  8, 29, 14, 17, 16, 72, 65, 56, 24, 60, 27, 79,
#         32, 52, 42, 17, 32, 57, 72, 32, 46, 77, 24, 63, 41, 11])
# Label Names: ['Coprinopsis', 'Lactifluus', 'Trechispora', 'Inocybe', 'Orbilia', 'Boletus', 'Boletus', 'Hygrophorus', 'Colacogloea', 'Crepidotus', 'Cortinarius', 'Tremella', 'Spathaspora', 'Pseudosperma', 'Geastrum', 'Russula', 'Hydnellum', 'Xylaria', 'Inocybe', 'Phylloporus', 'Marasmius', 'Crepidotus', 'Inocybe', 'Raffaelea', 'Tremella', 'Inocybe', 'Mycena', 'Wickerhamiella', 'Geastrum', 'Scolecobasidium', 'Malassezia', 'Cladophialophora']
# print len of label names: 32
#
# Batch 16:
# Data: tensor([[ 8.,  4.,  5.,  ...,  7., 11., 14.],
#         [ 7.,  4.,  2.,  ...,  6.,  8.,  5.],
#         [ 2.,  2.,  1.,  ...,  3.,  9.,  7.],
#         ...,
#         [ 3.,  3.,  2.,  ...,  2.,  3.,  3.],
#         [ 8.,  4.,  3.,  ...,  7.,  6.,  5.],
#         [ 4.,  3.,  1.,  ...,  4.,  3.,  5.]])
# Labels: tensor([ 7, 67, 16, 45, 78, 45, 49, 27, 73,  8,  4, 78, 16, 58, 20, 32, 27, 33,
#          2, 32, 58, 78,  4, 32, 78,  1, 11, 38, 11, 20, 32, 68])
# Label Names: ['Blastobotrys', 'Sugiyamaella', 'Cortinarius', 'Mucor', 'Wickerhamomyces', 'Mucor', 'Orbilia', 'Hydnellum', 'Trichoderma', 'Boletus', 'Aspergillus', 'Wickerhamomyces', 'Cortinarius', 'Ramaria', 'Elsinoe', 'Inocybe', 'Hydnellum', 'Inosperma', 'Apiospora', 'Inocybe', 'Ramaria', 'Wickerhamomyces', 'Aspergillus', 'Inocybe', 'Wickerhamomyces', 'Amanita', 'Cladophialophora', 'Lepiota', 'Cladophialophora', 'Elsinoe', 'Inocybe', 'Suhomyces']
# print len of label names: 32
#
# Batch 17:
# Data: tensor([[ 4.,  1.,  3.,  ...,  3., 11.,  9.],
#         [ 2.,  4.,  2.,  ...,  3.,  5.,  2.],
#         [14.,  9.,  2.,  ...,  3.,  6.,  7.],
#         ...,
#         [ 9.,  3.,  0.,  ...,  2.,  6.,  3.],
#         [ 1.,  2.,  1.,  ...,  5.,  7., 11.],
#         [ 0.,  1.,  1.,  ...,  5.,  9.,  3.]])
# Labels: tensor([ 1, 11, 49,  3, 13, 53,  8, 21, 38, 39, 36, 75, 33,  5, 31, 74, 46, 39,
#         39, 54, 43, 66, 54,  0, 60, 58, 29, 11, 50, 40, 51, 80])
# Label Names: ['Amanita', 'Cladophialophora', 'Orbilia', 'Arthroderma', 'Clavulina', 'Phyllosticta', 'Boletus', 'Entoloma', 'Lepiota', 'Leucoagaricus', 'Lactifluus', 'Tuber', 'Inosperma', 'Backusella', 'Hypoxylon', 'Tricholoma', 'Mycena', 'Leucoagaricus', 'Leucoagaricus', 'Pichia', 'Metschnikowia', 'Starmerella', 'Pichia', 'Absidia', 'Russula', 'Ramaria', 'Hygrophorus', 'Cladophialophora', 'Otidea', 'Lipomyces', 'Perenniporia', 'Xylodon']
# print len of label names: 32
#
# Batch 18:
# Data: tensor([[ 6.,  3.,  2.,  ...,  3.,  8., 12.],
#         [ 5.,  2.,  6.,  ...,  4.,  7.,  5.],
#         [ 9.,  6.,  4.,  ...,  5.,  8., 10.],
#         ...,
#         [ 5.,  2.,  3.,  ...,  6.,  9.,  2.],
#         [ 4.,  6.,  3.,  ...,  5.,  7.,  3.],
#         [ 1.,  1.,  1.,  ...,  2., 11., 13.]])
# Labels: tensor([21,  1, 67, 32, 32, 77, 34, 38, 69, 45, 40, 32, 32, 11,  1, 49, 50, 26,
#         21,  1, 77, 32, 80, 32, 32, 75,  9, 22, 28, 35, 65, 56])
# Label Names: ['Entoloma', 'Amanita', 'Sugiyamaella', 'Inocybe', 'Inocybe', 'Wickerhamiella', 'Kazachstania', 'Lepiota', 'Talaromyces', 'Mucor', 'Lipomyces', 'Inocybe', 'Inocybe', 'Cladophialophora', 'Amanita', 'Orbilia', 'Otidea', 'Gymnopus', 'Entoloma', 'Amanita', 'Wickerhamiella', 'Inocybe', 'Xylodon', 'Inocybe', 'Inocybe', 'Tuber', 'Candida', 'Exophiala', 'Hygrocybe', 'Lactarius', 'Spathaspora', 'Pseudosperma']
# print len of label names: 32
#
# Batch 19:
# Data: tensor([[11.,  5.,  4.,  ...,  5.,  5.,  9.],
#         [11.,  4.,  3.,  ...,  5.,  9., 14.],
#         [ 2.,  0.,  3.,  ...,  6.,  9.,  7.],
#         ...,
#         [ 8.,  2.,  2.,  ...,  2.,  3.,  7.],
#         [ 4.,  2.,  3.,  ...,  7., 11.,  5.],
#         [ 0.,  3.,  2.,  ...,  3.,  6.,  4.]])
# Labels: tensor([45, 63, 74, 36, 21, 25, 21, 66, 33, 17, 60, 28, 70, 26, 67, 49,  2,  6,
#         62, 28,  8, 66, 40, 55, 32, 60,  1, 35, 28, 77, 32, 72])
# Label Names: ['Mucor', 'Scolecobasidium', 'Tricholoma', 'Lactifluus', 'Entoloma', 'Genea', 'Entoloma', 'Starmerella', 'Inosperma', 'Crepidotus', 'Russula', 'Hygrocybe', 'Tomentella', 'Gymnopus', 'Sugiyamaella', 'Orbilia', 'Apiospora', 'Bambusicola', 'Saturnispora', 'Hygrocybe', 'Boletus', 'Starmerella', 'Lipomyces', 'Pluteus', 'Inocybe', 'Russula', 'Amanita', 'Lactarius', 'Hygrocybe', 'Wickerhamiella', 'Inocybe', 'Tremella']
# print len of label names: 32
#
# Batch 20:
# Data: tensor([[ 3.,  4.,  3.,  ...,  7.,  4.,  3.],
#         [ 0.,  2.,  3.,  ...,  3.,  7.,  8.],
#         [ 5.,  2.,  4.,  ...,  7., 10., 18.],
#         ...,
#         [ 2.,  1.,  2.,  ...,  3.,  6.,  5.],
#         [ 2.,  5.,  2.,  ...,  8.,  4., 10.],
#         [10.,  4.,  3.,  ...,  2.,  4., 10.]])
# Labels: tensor([58, 46, 21, 16, 36,  0, 23, 35, 32, 56, 11, 16, 54, 70, 32, 72, 14, 65,
#         17,  9, 49, 31, 55, 58, 32, 49, 38, 49, 48, 70, 32, 45])
# Label Names: ['Ramaria', 'Mycena', 'Entoloma', 'Cortinarius', 'Lactifluus', 'Absidia', 'Fomitiporia', 'Lactarius', 'Inocybe', 'Pseudosperma', 'Cladophialophora', 'Cortinarius', 'Pichia', 'Tomentella', 'Inocybe', 'Tremella', 'Colacogloea', 'Spathaspora', 'Crepidotus', 'Candida', 'Orbilia', 'Hypoxylon', 'Pluteus', 'Ramaria', 'Inocybe', 'Orbilia', 'Lepiota', 'Orbilia', 'Ophiocordyceps', 'Tomentella', 'Inocybe', 'Mucor']
# print len of label names: 32
#
# Batch 21:
# Data: tensor([[ 5.,  2.,  4.,  ...,  2.,  4.,  9.],
#         [ 6.,  7.,  0.,  ...,  5.,  4.,  3.],
#         [ 1.,  2.,  1.,  ...,  4.,  1.,  0.],
#         ...,
#         [ 2.,  3.,  2.,  ...,  5.,  6.,  6.],
#         [ 1.,  3.,  0.,  ...,  5.,  8.,  6.],
#         [11.,  5.,  4.,  ...,  6.,  7.,  6.]])
# Labels: tensor([ 1, 78, 69, 32, 32, 33, 50, 73,  9, 62, 32, 23, 21, 10, 60, 34, 34,  9,
#         68, 34, 32, 16, 35, 45, 63, 32, 32, 10, 76, 36, 50, 32])
# Label Names: ['Amanita', 'Wickerhamomyces', 'Talaromyces', 'Inocybe', 'Inocybe', 'Inosperma', 'Otidea', 'Trichoderma', 'Candida', 'Saturnispora', 'Inocybe', 'Fomitiporia', 'Entoloma', 'Cantharellus', 'Russula', 'Kazachstania', 'Kazachstania', 'Candida', 'Suhomyces', 'Kazachstania', 'Inocybe', 'Cortinarius', 'Lactarius', 'Mucor', 'Scolecobasidium', 'Inocybe', 'Inocybe', 'Cantharellus', 'Verrucaria', 'Lactifluus', 'Otidea', 'Inocybe']
# print len of label names: 32
#
# Batch 22:
# Data: tensor([[ 3.,  0.,  3.,  ...,  4.,  7.,  8.],
#         [11.,  5.,  2.,  ...,  5.,  8., 11.],
#         [ 3.,  6.,  0.,  ...,  3.,  1.,  2.],
#         ...,
#         [ 5.,  3.,  2.,  ...,  6.,  2.,  3.],
#         [ 4.,  3.,  8.,  ...,  6.,  9.,  7.],
#         [ 4.,  5.,  2.,  ...,  4.,  6.,  4.]])
# Labels: tensor([36, 36, 73, 44, 63, 26, 60, 15,  1, 14, 13, 48, 32, 32, 32,  9, 46, 60,
#         29, 32, 73, 23, 44, 67, 75,  2, 12, 42, 52, 31, 36, 50])
# Label Names: ['Lactifluus', 'Lactifluus', 'Trichoderma', 'Mortierella', 'Scolecobasidium', 'Gymnopus', 'Russula', 'Coprinopsis', 'Amanita', 'Colacogloea', 'Clavulina', 'Ophiocordyceps', 'Inocybe', 'Inocybe', 'Inocybe', 'Candida', 'Mycena', 'Russula', 'Hygrophorus', 'Inocybe', 'Trichoderma', 'Fomitiporia', 'Mortierella', 'Sugiyamaella', 'Tuber', 'Apiospora', 'Clavaria', 'Marasmius', 'Phylloporus', 'Hypoxylon', 'Lactifluus', 'Otidea']
# print len of label names: 32
#
# Batch 23:
# Data: tensor([[ 1.,  3.,  2.,  ...,  7.,  7.,  8.],
#         [ 4.,  2.,  2.,  ...,  7., 11., 14.],
#         [ 5.,  4.,  3.,  ...,  9.,  8., 16.],
#         ...,
#         [ 6.,  3.,  3.,  ...,  3., 10.,  9.],
#         [ 4.,  4.,  2.,  ...,  9.,  6., 27.],
#         [ 1.,  2.,  2.,  ...,  4.,  9.,  3.]])
# Labels: tensor([60, 13, 32, 64, 46, 52,  7,  9, 32, 12, 14, 30,  2, 47, 65, 63, 32, 43,
#         56, 63, 13, 21, 39, 67, 36, 67,  1, 32, 71, 60,  0, 55])
# Label Names: ['Russula', 'Clavulina', 'Inocybe', 'Scytinostroma', 'Mycena', 'Phylloporus', 'Blastobotrys', 'Candida', 'Inocybe', 'Clavaria', 'Colacogloea', 'Hymenochaete', 'Apiospora', 'Ogataea', 'Spathaspora', 'Scolecobasidium', 'Inocybe', 'Metschnikowia', 'Pseudosperma', 'Scolecobasidium', 'Clavulina', 'Entoloma', 'Leucoagaricus', 'Sugiyamaella', 'Lactifluus', 'Sugiyamaella', 'Amanita', 'Inocybe', 'Trechispora', 'Russula', 'Absidia', 'Pluteus']
# print len of label names: 32
#
# Batch 24:
# Data: tensor([[ 4.,  3.,  1.,  ...,  2.,  8.,  5.],
#         [11.,  5.,  4.,  ...,  3.,  4., 23.],
#         [ 8.,  4.,  2.,  ...,  3.,  4.,  1.],
#         ...,
#         [ 3.,  3.,  1.,  ...,  2.,  5.,  2.],
#         [ 3.,  3.,  2.,  ...,  2.,  4.,  1.],
#         [ 5.,  7.,  0.,  ...,  4.,  3., 22.]])
# Labels: tensor([39, 45, 50, 73, 43, 78,  1, 53, 32, 24, 54, 74, 32, 60, 32,  9, 39, 16,
#         44, 60, 39, 16, 42, 50,  2,  9, 23, 21,  9, 37, 76, 43])
# Label Names: ['Leucoagaricus', 'Mucor', 'Otidea', 'Trichoderma', 'Metschnikowia', 'Wickerhamomyces', 'Amanita', 'Phyllosticta', 'Inocybe', 'Geastrum', 'Pichia', 'Tricholoma', 'Inocybe', 'Russula', 'Inocybe', 'Candida', 'Leucoagaricus', 'Cortinarius', 'Mortierella', 'Russula', 'Leucoagaricus', 'Cortinarius', 'Marasmius', 'Otidea', 'Apiospora', 'Candida', 'Fomitiporia', 'Entoloma', 'Candida', 'Lecanora', 'Verrucaria', 'Metschnikowia']
# print len of label names: 32
#
# Batch 25:
# Data: tensor([[11.,  3.,  3.,  ...,  2.,  9.,  7.],
#         [ 2.,  3.,  2.,  ...,  4.,  7.,  4.],
#         [ 0.,  2.,  1.,  ...,  2., 10.,  4.],
#         ...,
#         [ 4.,  3.,  1.,  ...,  5.,  6.,  3.],
#         [ 2.,  1.,  1.,  ...,  4.,  7., 10.],
#         [ 2.,  2.,  2.,  ...,  3.,  1.,  0.]])
# Labels: tensor([ 1, 70, 56, 49,  1, 55, 31, 32, 44, 13, 32, 49, 58, 68, 32, 69, 41, 30,
#         42, 39, 60, 76, 80, 72, 35, 49, 54, 24, 38, 21, 33,  4])
# Label Names: ['Amanita', 'Tomentella', 'Pseudosperma', 'Orbilia', 'Amanita', 'Pluteus', 'Hypoxylon', 'Inocybe', 'Mortierella', 'Clavulina', 'Inocybe', 'Orbilia', 'Ramaria', 'Suhomyces', 'Inocybe', 'Talaromyces', 'Malassezia', 'Hymenochaete', 'Marasmius', 'Leucoagaricus', 'Russula', 'Verrucaria', 'Xylodon', 'Tremella', 'Lactarius', 'Orbilia', 'Pichia', 'Geastrum', 'Lepiota', 'Entoloma', 'Inosperma', 'Aspergillus']
# print len of label names: 32
#
# Batch 26:
# Data: tensor([[ 1.,  2.,  1.,  ...,  7., 10., 20.],
#         [ 4.,  3.,  1.,  ...,  7.,  8., 10.],
#         [ 4.,  4.,  3.,  ...,  9.,  9., 11.],
#         ...,
#         [ 4.,  2.,  1.,  ...,  2.,  3.,  1.],
#         [ 6.,  4.,  2.,  ...,  3.,  8., 10.],
#         [ 2.,  3.,  4.,  ...,  6.,  7.,  3.]])
# Labels: tensor([13, 44, 32, 42, 26,  1, 44,  8, 60, 36, 27,  4, 13, 32, 15, 73, 77, 64,
#         31, 64, 49,  1, 49,  7, 32, 77, 55,  9, 46, 37, 44, 32])
# Label Names: ['Clavulina', 'Mortierella', 'Inocybe', 'Marasmius', 'Gymnopus', 'Amanita', 'Mortierella', 'Boletus', 'Russula', 'Lactifluus', 'Hydnellum', 'Aspergillus', 'Clavulina', 'Inocybe', 'Coprinopsis', 'Trichoderma', 'Wickerhamiella', 'Scytinostroma', 'Hypoxylon', 'Scytinostroma', 'Orbilia', 'Amanita', 'Orbilia', 'Blastobotrys', 'Inocybe', 'Wickerhamiella', 'Pluteus', 'Candida', 'Mycena', 'Lecanora', 'Mortierella', 'Inocybe']
# print len of label names: 32
#
# Batch 27:
# Data: tensor([[ 8.,  9.,  2.,  ...,  6.,  8.,  9.],
#         [ 2.,  2.,  2.,  ...,  6.,  9.,  9.],
#         [ 4.,  6.,  2.,  ...,  5.,  8.,  5.],
#         ...,
#         [11.,  3.,  5.,  ...,  7.,  8., 12.],
#         [23.,  8.,  2.,  ...,  3.,  2.,  8.],
#         [ 6.,  4.,  4.,  ...,  5., 11., 10.]])
# Labels: tensor([49, 24, 34, 43, 47, 11, 49, 49, 21, 31,  1, 34, 37,  0, 42, 32,  7, 72,
#         45, 47,  1, 45, 63, 13, 13,  8, 32, 45,  1, 21, 54, 32])
# Label Names: ['Orbilia', 'Geastrum', 'Kazachstania', 'Metschnikowia', 'Ogataea', 'Cladophialophora', 'Orbilia', 'Orbilia', 'Entoloma', 'Hypoxylon', 'Amanita', 'Kazachstania', 'Lecanora', 'Absidia', 'Marasmius', 'Inocybe', 'Blastobotrys', 'Tremella', 'Mucor', 'Ogataea', 'Amanita', 'Mucor', 'Scolecobasidium', 'Clavulina', 'Clavulina', 'Boletus', 'Inocybe', 'Mucor', 'Amanita', 'Entoloma', 'Pichia', 'Inocybe']
# print len of label names: 32
#
# Batch 28:
# Data: tensor([[ 6.,  6.,  4.,  ...,  4., 13., 18.],
#         [ 0.,  1.,  1.,  ...,  1., 10.,  6.],
#         [ 5.,  2.,  5.,  ...,  3.,  3.,  0.],
#         ...,
#         [14.,  4.,  4.,  ...,  5.,  5.,  8.],
#         [ 3.,  4.,  6.,  ...,  4.,  7.,  0.],
#         [ 3.,  2.,  1.,  ...,  5., 12.,  9.]])
# Labels: tensor([67, 29,  3, 27, 49, 25,  8, 32, 18, 72, 69, 77, 60,  4, 69, 61, 36, 21,
#         32, 32, 28, 49, 49, 75, 34, 36, 56, 32, 20, 25, 64, 35])
# Label Names: ['Sugiyamaella', 'Hygrophorus', 'Arthroderma', 'Hydnellum', 'Orbilia', 'Genea', 'Boletus', 'Inocybe', 'Cyberlindnera', 'Tremella', 'Talaromyces', 'Wickerhamiella', 'Russula', 'Aspergillus', 'Talaromyces', 'Saccharomycopsis', 'Lactifluus', 'Entoloma', 'Inocybe', 'Inocybe', 'Hygrocybe', 'Orbilia', 'Orbilia', 'Tuber', 'Kazachstania', 'Lactifluus', 'Pseudosperma', 'Inocybe', 'Elsinoe', 'Genea', 'Scytinostroma', 'Lactarius']
# print len of label names: 32
#
# Batch 29:
# Data: tensor([[ 3.,  3.,  2.,  ...,  2.,  2.,  4.],
#         [ 6.,  5.,  0.,  ...,  3.,  1.,  1.],
#         [10.,  5.,  4.,  ...,  2.,  7., 17.],
#         ...,
#         [12.,  4.,  4.,  ...,  3.,  9., 34.],
#         [ 4.,  6.,  2.,  ...,  1.,  7.,  1.],
#         [ 4.,  4.,  4.,  ...,  4., 10., 10.]])
# Labels: tensor([ 4, 73, 40, 31, 21, 32, 74, 24, 45, 51, 42, 40, 38, 71, 32, 49,  1, 32,
#         42,  1, 68, 45, 31, 29, 62, 55,  8, 21, 60, 45, 71, 32])
# Label Names: ['Aspergillus', 'Trichoderma', 'Lipomyces', 'Hypoxylon', 'Entoloma', 'Inocybe', 'Tricholoma', 'Geastrum', 'Mucor', 'Perenniporia', 'Marasmius', 'Lipomyces', 'Lepiota', 'Trechispora', 'Inocybe', 'Orbilia', 'Amanita', 'Inocybe', 'Marasmius', 'Amanita', 'Suhomyces', 'Mucor', 'Hypoxylon', 'Hygrophorus', 'Saturnispora', 'Pluteus', 'Boletus', 'Entoloma', 'Russula', 'Mucor', 'Trechispora', 'Inocybe']
# print len of label names: 32
#
# Batch 30:
# Data: tensor([[ 9.,  6.,  1.,  ...,  6., 10.,  8.],
#         [ 6.,  3.,  5.,  ...,  2.,  2., 10.],
#         [ 5.,  2.,  7.,  ...,  4.,  6.,  7.],
#         ...,
#         [ 4.,  1.,  3.,  ...,  6.,  8.,  8.],
#         [17.,  7.,  1.,  ...,  5.,  3.,  8.],
#         [ 4.,  4.,  2.,  ...,  2.,  7., 12.]])
# Labels: tensor([67, 77,  1, 51, 53,  6,  3, 31, 63, 28, 28, 63, 78, 32,  0, 49, 78, 32,
#         31, 43, 49, 78,  3, 24, 32, 66, 53, 61, 32, 33, 43, 40])
# Label Names: ['Sugiyamaella', 'Wickerhamiella', 'Amanita', 'Perenniporia', 'Phyllosticta', 'Bambusicola', 'Arthroderma', 'Hypoxylon', 'Scolecobasidium', 'Hygrocybe', 'Hygrocybe', 'Scolecobasidium', 'Wickerhamomyces', 'Inocybe', 'Absidia', 'Orbilia', 'Wickerhamomyces', 'Inocybe', 'Hypoxylon', 'Metschnikowia', 'Orbilia', 'Wickerhamomyces', 'Arthroderma', 'Geastrum', 'Inocybe', 'Starmerella', 'Phyllosticta', 'Saccharomycopsis', 'Inocybe', 'Inosperma', 'Metschnikowia', 'Lipomyces']
# print len of label names: 32
#
# Batch 31:
# Data: tensor([[ 9.,  5.,  3.,  ...,  7.,  9.,  6.],
#         [ 0.,  5.,  1.,  ...,  1.,  5.,  3.],
#         [ 3.,  2.,  1.,  ...,  6.,  8.,  2.],
#         ...,
#         [12.,  8.,  2.,  ...,  2.,  7.,  9.],
#         [ 6.,  5.,  2.,  ...,  6., 10.,  8.],
#         [19.,  6.,  8.,  ...,  5.,  7., 22.]])
# Labels: tensor([ 1, 71, 60, 15, 58, 21, 76, 21, 62, 17, 33, 78, 39, 80, 58, 22, 52, 24,
#         45,  2, 51, 36, 21, 75, 78, 21, 45, 32, 22, 40,  9, 45])
# Label Names: ['Amanita', 'Trechispora', 'Russula', 'Coprinopsis', 'Ramaria', 'Entoloma', 'Verrucaria', 'Entoloma', 'Saturnispora', 'Crepidotus', 'Inosperma', 'Wickerhamomyces', 'Leucoagaricus', 'Xylodon', 'Ramaria', 'Exophiala', 'Phylloporus', 'Geastrum', 'Mucor', 'Apiospora', 'Perenniporia', 'Lactifluus', 'Entoloma', 'Tuber', 'Wickerhamomyces', 'Entoloma', 'Mucor', 'Inocybe', 'Exophiala', 'Lipomyces', 'Candida', 'Mucor']
# print len of label names: 32
#
# Batch 32:
# Data: tensor([[ 5.,  6.,  3.,  ...,  5.,  9.,  9.],
#         [ 1.,  4.,  2.,  ...,  4., 13.,  9.],
#         [ 4.,  2.,  2.,  ...,  3.,  9.,  4.],
#         ...,
#         [ 6.,  2.,  3.,  ..., 11.,  7.,  8.],
#         [ 0.,  2.,  1.,  ...,  1.,  9.,  6.],
#         [ 6.,  4.,  1.,  ...,  5.,  6.,  4.]])
# Labels: tensor([21, 60,  1, 39, 31,  1, 68, 50, 19, 32,  4, 28, 71, 50, 21, 42, 35, 30,
#         53, 38, 62, 45, 22, 28, 49, 63, 11,  2, 40, 32, 60, 24])
# Label Names: ['Entoloma', 'Russula', 'Amanita', 'Leucoagaricus', 'Hypoxylon', 'Amanita', 'Suhomyces', 'Otidea', 'Cyphellophora', 'Inocybe', 'Aspergillus', 'Hygrocybe', 'Trechispora', 'Otidea', 'Entoloma', 'Marasmius', 'Lactarius', 'Hymenochaete', 'Phyllosticta', 'Lepiota', 'Saturnispora', 'Mucor', 'Exophiala', 'Hygrocybe', 'Orbilia', 'Scolecobasidium', 'Cladophialophora', 'Apiospora', 'Lipomyces', 'Inocybe', 'Russula', 'Geastrum']
# print len of label names: 32
#
# Batch 33:
# Data: tensor([[1., 1., 1.,  ..., 2., 7., 2.],
#         [3., 4., 2.,  ..., 3., 6., 7.],
#         [2., 1., 1.,  ..., 2., 6., 3.],
#         ...,
#         [5., 5., 4.,  ..., 4., 3., 1.],
#         [5., 4., 2.,  ..., 4., 3., 9.],
#         [3., 3., 3.,  ..., 2., 5., 3.]])
# Labels: tensor([15, 24,  1, 32, 24, 33, 39, 51, 25, 72, 32, 36, 21, 49, 32, 32, 16, 34,
#         69, 39, 48,  0,  9, 59, 73, 53, 43, 59, 19, 75, 43,  4])
# Label Names: ['Coprinopsis', 'Geastrum', 'Amanita', 'Inocybe', 'Geastrum', 'Inosperma', 'Leucoagaricus', 'Perenniporia', 'Genea', 'Tremella', 'Inocybe', 'Lactifluus', 'Entoloma', 'Orbilia', 'Inocybe', 'Inocybe', 'Cortinarius', 'Kazachstania', 'Talaromyces', 'Leucoagaricus', 'Ophiocordyceps', 'Absidia', 'Candida', 'Roussoella', 'Trichoderma', 'Phyllosticta', 'Metschnikowia', 'Roussoella', 'Cyphellophora', 'Tuber', 'Metschnikowia', 'Aspergillus']
# print len of label names: 32
#
# Batch 34:
# Data: tensor([[ 5.,  1.,  3.,  ...,  1.,  7.,  9.],
#         [ 6.,  4.,  7.,  ...,  7.,  9., 14.],
#         [ 5.,  7.,  4.,  ...,  8.,  8.,  8.],
#         ...,
#         [ 5.,  5.,  1.,  ...,  3.,  2.,  3.],
#         [10., 11.,  1.,  ...,  4.,  5.,  3.],
#         [ 0.,  1.,  3.,  ...,  4.,  8.,  4.]])
# Labels: tensor([ 1,  8,  7, 64, 24, 54, 41, 49, 55, 32, 20, 16, 61, 60, 27, 34, 53, 25,
#         57,  9, 39, 21, 24, 70, 32, 60,  5,  4, 49, 79, 49, 17])
# Label Names: ['Amanita', 'Boletus', 'Blastobotrys', 'Scytinostroma', 'Geastrum', 'Pichia', 'Malassezia', 'Orbilia', 'Pluteus', 'Inocybe', 'Elsinoe', 'Cortinarius', 'Saccharomycopsis', 'Russula', 'Hydnellum', 'Kazachstania', 'Phyllosticta', 'Genea', 'Raffaelea', 'Candida', 'Leucoagaricus', 'Entoloma', 'Geastrum', 'Tomentella', 'Inocybe', 'Russula', 'Backusella', 'Aspergillus', 'Orbilia', 'Xylaria', 'Orbilia', 'Crepidotus']
# print len of label names: 32
#
# Batch 35:
# Data: tensor([[ 3.,  3.,  4.,  ...,  4.,  9.,  5.],
#         [ 3.,  3.,  2.,  ...,  3.,  2., 12.],
#         [14., 12.,  6.,  ...,  5.,  8.,  5.],
#         ...,
#         [ 4.,  6.,  2.,  ...,  3.,  7.,  7.],
#         [ 4.,  5.,  2.,  ...,  5.,  3.,  1.],
#         [ 5.,  3.,  2.,  ...,  7.,  6., 11.]])
# Labels: tensor([42,  2, 49, 22, 63, 52, 71, 32, 60,  1, 79, 32,  7, 24, 47, 73,  1, 50,
#         32, 31,  4,  1, 56,  0, 22, 64, 40, 34, 72, 38, 53, 65])
# Label Names: ['Marasmius', 'Apiospora', 'Orbilia', 'Exophiala', 'Scolecobasidium', 'Phylloporus', 'Trechispora', 'Inocybe', 'Russula', 'Amanita', 'Xylaria', 'Inocybe', 'Blastobotrys', 'Geastrum', 'Ogataea', 'Trichoderma', 'Amanita', 'Otidea', 'Inocybe', 'Hypoxylon', 'Aspergillus', 'Amanita', 'Pseudosperma', 'Absidia', 'Exophiala', 'Scytinostroma', 'Lipomyces', 'Kazachstania', 'Tremella', 'Lepiota', 'Phyllosticta', 'Spathaspora']
# print len of label names: 32
#
# Batch 36:
# Data: tensor([[ 1.,  1.,  0.,  ...,  1., 10.,  4.],
#         [ 0.,  3.,  0.,  ...,  5.,  5.,  7.],
#         [ 1.,  2.,  1.,  ...,  3.,  6.,  1.],
#         ...,
#         [ 5.,  4.,  3.,  ...,  6.,  7., 12.],
#         [ 3.,  6.,  1.,  ...,  4.,  6.,  9.],
#         [ 0.,  0.,  1.,  ...,  1.,  6.,  1.]])
# Labels: tensor([39, 55, 55, 49, 47, 63, 50, 26, 50, 28, 60, 32, 17, 75, 29, 32, 26, 27,
#         37, 32, 35, 76, 34, 31, 20, 19, 32, 62, 16,  9, 21, 70])
# Label Names: ['Leucoagaricus', 'Pluteus', 'Pluteus', 'Orbilia', 'Ogataea', 'Scolecobasidium', 'Otidea', 'Gymnopus', 'Otidea', 'Hygrocybe', 'Russula', 'Inocybe', 'Crepidotus', 'Tuber', 'Hygrophorus', 'Inocybe', 'Gymnopus', 'Hydnellum', 'Lecanora', 'Inocybe', 'Lactarius', 'Verrucaria', 'Kazachstania', 'Hypoxylon', 'Elsinoe', 'Cyphellophora', 'Inocybe', 'Saturnispora', 'Cortinarius', 'Candida', 'Entoloma', 'Tomentella']
# print len of label names: 32
#
# Batch 37:
# Data: tensor([[ 7.,  7.,  0.,  ...,  9.,  5.,  8.],
#         [ 2.,  3.,  2.,  ...,  3.,  1.,  2.],
#         [ 5.,  5.,  1.,  ...,  8.,  9., 13.],
#         ...,
#         [15.,  3.,  3.,  ...,  6.,  9., 42.],
#         [ 3.,  3.,  1.,  ...,  5., 12.,  9.],
#         [29.,  3.,  8.,  ...,  2.,  2., 14.]])
# Labels: tensor([18, 57, 34, 32, 29, 32, 45, 73, 32, 39, 79, 68,  2, 32, 75, 79,  8, 71,
#         16, 56, 60,  8, 11,  7, 61, 59, 32,  1, 49,  5, 32, 48])
# Label Names: ['Cyberlindnera', 'Raffaelea', 'Kazachstania', 'Inocybe', 'Hygrophorus', 'Inocybe', 'Mucor', 'Trichoderma', 'Inocybe', 'Leucoagaricus', 'Xylaria', 'Suhomyces', 'Apiospora', 'Inocybe', 'Tuber', 'Xylaria', 'Boletus', 'Trechispora', 'Cortinarius', 'Pseudosperma', 'Russula', 'Boletus', 'Cladophialophora', 'Blastobotrys', 'Saccharomycopsis', 'Roussoella', 'Inocybe', 'Amanita', 'Orbilia', 'Backusella', 'Inocybe', 'Ophiocordyceps']
# print len of label names: 32
#
# Batch 38:
# Data: tensor([[ 3.,  4.,  1.,  ...,  4.,  3.,  9.],
#         [ 6.,  6.,  4.,  ...,  2.,  6.,  4.],
#         [ 9.,  3.,  3.,  ...,  9.,  3., 18.],
#         ...,
#         [ 1.,  1.,  1.,  ...,  2.,  2.,  0.],
#         [ 4.,  1.,  4.,  ...,  3.,  4., 11.],
#         [ 3.,  3.,  0.,  ...,  3.,  4.,  2.]])
# Labels: tensor([ 9, 75,  0,  8,  6, 61, 74,  1, 49, 34, 45, 49, 36, 41, 20, 52,  9, 18,
#         21, 77,  1,  5, 67, 34, 22, 48, 59, 31, 42, 69, 77, 37])
# Label Names: ['Candida', 'Tuber', 'Absidia', 'Boletus', 'Bambusicola', 'Saccharomycopsis', 'Tricholoma', 'Amanita', 'Orbilia', 'Kazachstania', 'Mucor', 'Orbilia', 'Lactifluus', 'Malassezia', 'Elsinoe', 'Phylloporus', 'Candida', 'Cyberlindnera', 'Entoloma', 'Wickerhamiella', 'Amanita', 'Backusella', 'Sugiyamaella', 'Kazachstania', 'Exophiala', 'Ophiocordyceps', 'Roussoella', 'Hypoxylon', 'Marasmius', 'Talaromyces', 'Wickerhamiella', 'Lecanora']
# print len of label names: 32
#
# Batch 39:
# Data: tensor([[ 1.,  1.,  1.,  ...,  2.,  1.,  5.],
#         [ 1.,  1.,  2.,  ...,  2., 12.,  7.],
#         [ 9.,  6.,  3.,  ...,  2.,  4.,  2.],
#         ...,
#         [ 4.,  5.,  1.,  ...,  5.,  9., 10.],
#         [15.,  4.,  0.,  ...,  5.,  2.,  6.],
#         [ 0.,  4.,  0.,  ...,  8.,  4.,  9.]])
# Labels: tensor([ 4, 46, 43,  1,  9, 66, 45, 67, 19,  1, 21,  1, 27, 32, 49, 71, 73, 32,
#          3, 49, 42, 50,  1, 60,  3,  8,  4, 45, 43, 61, 43,  8])
# Label Names: ['Aspergillus', 'Mycena', 'Metschnikowia', 'Amanita', 'Candida', 'Starmerella', 'Mucor', 'Sugiyamaella', 'Cyphellophora', 'Amanita', 'Entoloma', 'Amanita', 'Hydnellum', 'Inocybe', 'Orbilia', 'Trechispora', 'Trichoderma', 'Inocybe', 'Arthroderma', 'Orbilia', 'Marasmius', 'Otidea', 'Amanita', 'Russula', 'Arthroderma', 'Boletus', 'Aspergillus', 'Mucor', 'Metschnikowia', 'Saccharomycopsis', 'Metschnikowia', 'Boletus']
# print len of label names: 32
#
# Batch 40:
# Data: tensor([[10., 10.,  6.,  ...,  5.,  5.,  1.],
#         [ 9.,  6.,  2.,  ...,  7., 10., 17.],
#         [ 2.,  2.,  3.,  ...,  5.,  8.,  7.],
#         ...,
#         [ 0.,  3.,  2.,  ...,  2.,  7.,  2.],
#         [ 2.,  3.,  3.,  ...,  2.,  9.,  7.],
#         [ 6.,  4.,  4.,  ...,  1.,  5., 13.]])
# Labels: tensor([49, 32, 56, 32, 45, 21, 49, 67, 59, 14, 60, 57, 63, 63,  7, 39, 77, 32,
#         79, 32,  4, 18, 22, 32,  3, 72, 26, 38, 57, 80, 58, 45])
# Label Names: ['Orbilia', 'Inocybe', 'Pseudosperma', 'Inocybe', 'Mucor', 'Entoloma', 'Orbilia', 'Sugiyamaella', 'Roussoella', 'Colacogloea', 'Russula', 'Raffaelea', 'Scolecobasidium', 'Scolecobasidium', 'Blastobotrys', 'Leucoagaricus', 'Wickerhamiella', 'Inocybe', 'Xylaria', 'Inocybe', 'Aspergillus', 'Cyberlindnera', 'Exophiala', 'Inocybe', 'Arthroderma', 'Tremella', 'Gymnopus', 'Lepiota', 'Raffaelea', 'Xylodon', 'Ramaria', 'Mucor']
# print len of label names: 32
#
# Batch 41:
# Data: tensor([[4., 5., 1.,  ..., 4., 3., 6.],
#         [3., 5., 1.,  ..., 2., 4., 0.],
#         [8., 6., 1.,  ..., 4., 6., 2.],
#         ...,
#         [2., 2., 3.,  ..., 8., 7., 2.],
#         [0., 3., 2.,  ..., 1., 6., 4.],
#         [4., 2., 3.,  ..., 2., 1., 2.]])
# Labels: tensor([73, 71, 49, 75, 45, 75,  8, 31, 31,  1, 46, 80, 57, 66, 48, 32, 11, 47,
#         18, 36, 67, 43, 72, 49, 20, 75, 32, 61, 76, 78,  6,  4])
# Label Names: ['Trichoderma', 'Trechispora', 'Orbilia', 'Tuber', 'Mucor', 'Tuber', 'Boletus', 'Hypoxylon', 'Hypoxylon', 'Amanita', 'Mycena', 'Xylodon', 'Raffaelea', 'Starmerella', 'Ophiocordyceps', 'Inocybe', 'Cladophialophora', 'Ogataea', 'Cyberlindnera', 'Lactifluus', 'Sugiyamaella', 'Metschnikowia', 'Tremella', 'Orbilia', 'Elsinoe', 'Tuber', 'Inocybe', 'Saccharomycopsis', 'Verrucaria', 'Wickerhamomyces', 'Bambusicola', 'Aspergillus']
# print len of label names: 32
#
# Batch 42:
# Data: tensor([[ 0.,  2.,  2.,  ...,  2., 11.,  3.],
#         [ 7.,  2.,  2.,  ...,  4.,  5., 16.],
#         [ 2.,  1.,  2.,  ...,  5.,  5.,  3.],
#         ...,
#         [ 3.,  5.,  3.,  ...,  3.,  0.,  0.],
#         [ 7.,  2.,  7.,  ...,  6.,  6.,  7.],
#         [ 5.,  2.,  2.,  ...,  6.,  5.,  5.]])
# Labels: tensor([80, 32, 38,  7, 40, 44, 48, 51, 67, 71, 22, 79,  2, 21, 32, 32,  3, 32,
#         15,  3,  5, 18,  8, 63,  4, 62, 32, 57, 67, 54,  1, 32])
# Label Names: ['Xylodon', 'Inocybe', 'Lepiota', 'Blastobotrys', 'Lipomyces', 'Mortierella', 'Ophiocordyceps', 'Perenniporia', 'Sugiyamaella', 'Trechispora', 'Exophiala', 'Xylaria', 'Apiospora', 'Entoloma', 'Inocybe', 'Inocybe', 'Arthroderma', 'Inocybe', 'Coprinopsis', 'Arthroderma', 'Backusella', 'Cyberlindnera', 'Boletus', 'Scolecobasidium', 'Aspergillus', 'Saturnispora', 'Inocybe', 'Raffaelea', 'Sugiyamaella', 'Pichia', 'Amanita', 'Inocybe']
# print len of label names: 32
#
# Batch 43:
# Data: tensor([[11.,  2.,  5.,  ...,  3.,  8., 20.],
#         [ 8.,  4.,  0.,  ...,  4.,  3.,  3.],
#         [ 0.,  3.,  0.,  ...,  3.,  9.,  4.],
#         ...,
#         [ 0.,  2.,  2.,  ...,  3.,  8.,  5.],
#         [ 3.,  4.,  2.,  ...,  2.,  1.,  0.],
#         [ 2.,  2.,  7.,  ...,  5., 12., 14.]])
# Labels: tensor([ 0, 31, 23, 48, 32, 32, 32, 67, 38, 21, 46, 24, 11, 17, 55, 63,  4,  1,
#         57, 41, 32, 63, 35, 71, 79,  1, 32, 26, 80, 80,  4, 27])
# Label Names: ['Absidia', 'Hypoxylon', 'Fomitiporia', 'Ophiocordyceps', 'Inocybe', 'Inocybe', 'Inocybe', 'Sugiyamaella', 'Lepiota', 'Entoloma', 'Mycena', 'Geastrum', 'Cladophialophora', 'Crepidotus', 'Pluteus', 'Scolecobasidium', 'Aspergillus', 'Amanita', 'Raffaelea', 'Malassezia', 'Inocybe', 'Scolecobasidium', 'Lactarius', 'Trechispora', 'Xylaria', 'Amanita', 'Inocybe', 'Gymnopus', 'Xylodon', 'Xylodon', 'Aspergillus', 'Hydnellum']
# print len of label names: 32
#
# Batch 44:
# Data: tensor([[ 4.,  2.,  3.,  ...,  3.,  9.,  2.],
#         [ 4.,  5.,  4.,  ...,  5.,  8., 12.],
#         [ 3.,  5.,  2.,  ...,  3.,  2.,  2.],
#         ...,
#         [ 4.,  5.,  5.,  ...,  3.,  5.,  4.],
#         [ 2.,  1.,  1.,  ...,  3.,  8.,  0.],
#         [ 8.,  6.,  0.,  ...,  2.,  2.,  0.]])
# Labels: tensor([80, 49, 20,  1, 51, 36, 21, 27, 32, 21, 12, 21, 47, 78, 50, 47, 52, 32,
#         31, 44, 18, 60, 32, 60,  1, 72, 32, 68,  6, 72, 70, 73])
# Label Names: ['Xylodon', 'Orbilia', 'Elsinoe', 'Amanita', 'Perenniporia', 'Lactifluus', 'Entoloma', 'Hydnellum', 'Inocybe', 'Entoloma', 'Clavaria', 'Entoloma', 'Ogataea', 'Wickerhamomyces', 'Otidea', 'Ogataea', 'Phylloporus', 'Inocybe', 'Hypoxylon', 'Mortierella', 'Cyberlindnera', 'Russula', 'Inocybe', 'Russula', 'Amanita', 'Tremella', 'Inocybe', 'Suhomyces', 'Bambusicola', 'Tremella', 'Tomentella', 'Trichoderma']
# print len of label names: 32
#
# Batch 45:
# Data: tensor([[ 3.,  4.,  3.,  ...,  2.,  3.,  2.],
#         [12.,  3.,  4.,  ...,  2.,  4., 11.],
#         [10.,  7.,  5.,  ..., 10., 11., 11.],
#         ...,
#         [ 7.,  5.,  2.,  ..., 10.,  7., 11.],
#         [ 6.,  6.,  2.,  ...,  4.,  4.,  2.],
#         [ 4.,  7.,  1.,  ...,  2.,  1.,  0.]])
# Labels: tensor([22, 45, 47, 70,  1, 18, 39, 74,  5, 49, 27, 75, 49, 32, 55, 31, 19, 58,
#         32, 47, 14, 26, 27, 21, 33, 16, 32, 10, 49, 34, 19, 75])
# Label Names: ['Exophiala', 'Mucor', 'Ogataea', 'Tomentella', 'Amanita', 'Cyberlindnera', 'Leucoagaricus', 'Tricholoma', 'Backusella', 'Orbilia', 'Hydnellum', 'Tuber', 'Orbilia', 'Inocybe', 'Pluteus', 'Hypoxylon', 'Cyphellophora', 'Ramaria', 'Inocybe', 'Ogataea', 'Colacogloea', 'Gymnopus', 'Hydnellum', 'Entoloma', 'Inosperma', 'Cortinarius', 'Inocybe', 'Cantharellus', 'Orbilia', 'Kazachstania', 'Cyphellophora', 'Tuber']
# print len of label names: 32
#
# Batch 46:
# Data: tensor([[ 2.,  4.,  4.,  ...,  5.,  5.,  4.],
#         [ 1., 10.,  3.,  ...,  4.,  7.,  5.],
#         [ 2.,  4.,  2.,  ...,  4.,  2.,  1.],
#         ...,
#         [ 7.,  6.,  2.,  ...,  4.,  7., 13.],
#         [ 8.,  3.,  4.,  ...,  6.,  5.,  4.],
#         [ 2.,  1.,  2.,  ...,  3.,  5.,  5.]])
# Labels: tensor([72, 41, 66, 73, 52, 45, 48, 76, 28, 32,  4, 22, 16, 41, 49, 21, 45, 16,
#         49, 73, 16, 32, 77, 24, 22, 34, 32, 28, 60, 78, 21, 32])
# Label Names: ['Tremella', 'Malassezia', 'Starmerella', 'Trichoderma', 'Phylloporus', 'Mucor', 'Ophiocordyceps', 'Verrucaria', 'Hygrocybe', 'Inocybe', 'Aspergillus', 'Exophiala', 'Cortinarius', 'Malassezia', 'Orbilia', 'Entoloma', 'Mucor', 'Cortinarius', 'Orbilia', 'Trichoderma', 'Cortinarius', 'Inocybe', 'Wickerhamiella', 'Geastrum', 'Exophiala', 'Kazachstania', 'Inocybe', 'Hygrocybe', 'Russula', 'Wickerhamomyces', 'Entoloma', 'Inocybe']
# print len of label names: 32
#
# Batch 47:
# Data: tensor([[ 1.,  2.,  1.,  ...,  9.,  6., 13.],
#         [10., 10.,  2.,  ...,  4.,  5.,  4.],
#         [ 6.,  1.,  2.,  ...,  5.,  7.,  5.],
#         ...,
#         [ 3.,  0.,  5.,  ...,  5.,  9., 12.],
#         [ 6.,  6.,  4.,  ...,  4.,  2.,  0.],
#         [ 8.,  0.,  7.,  ..., 12., 10.,  5.]])
# Labels: tensor([32, 49, 32,  7, 32, 48, 38, 60,  2, 19, 24, 32, 16, 19, 24, 36, 32, 45,
#         26, 24, 23, 58, 32,  0, 60, 42, 65, 73, 67, 29, 54,  8])
# Label Names: ['Inocybe', 'Orbilia', 'Inocybe', 'Blastobotrys', 'Inocybe', 'Ophiocordyceps', 'Lepiota', 'Russula', 'Apiospora', 'Cyphellophora', 'Geastrum', 'Inocybe', 'Cortinarius', 'Cyphellophora', 'Geastrum', 'Lactifluus', 'Inocybe', 'Mucor', 'Gymnopus', 'Geastrum', 'Fomitiporia', 'Ramaria', 'Inocybe', 'Absidia', 'Russula', 'Marasmius', 'Spathaspora', 'Trichoderma', 'Sugiyamaella', 'Hygrophorus', 'Pichia', 'Boletus']
# print len of label names: 32
#
# Batch 48:
# Data: tensor([[ 1.,  3.,  2.,  ...,  7., 11.,  5.],
#         [ 3.,  0.,  8.,  ..., 11.,  7., 10.],
#         [ 3.,  7.,  1.,  ...,  2.,  5.,  1.],
#         ...,
#         [ 3.,  2.,  3.,  ...,  6.,  8.,  4.],
#         [ 3.,  2.,  3.,  ...,  3.,  5.,  0.],
#         [ 7.,  3.,  2.,  ...,  2.,  3.,  3.]])
# Labels: tensor([ 8,  8, 49,  6, 67, 45, 12, 56,  0, 64,  1, 32, 38, 72, 32, 10, 10, 10,
#         35, 30, 58,  9, 66, 66, 21, 63, 32, 42, 56, 32, 42, 63])
# Label Names: ['Boletus', 'Boletus', 'Orbilia', 'Bambusicola', 'Sugiyamaella', 'Mucor', 'Clavaria', 'Pseudosperma', 'Absidia', 'Scytinostroma', 'Amanita', 'Inocybe', 'Lepiota', 'Tremella', 'Inocybe', 'Cantharellus', 'Cantharellus', 'Cantharellus', 'Lactarius', 'Hymenochaete', 'Ramaria', 'Candida', 'Starmerella', 'Starmerella', 'Entoloma', 'Scolecobasidium', 'Inocybe', 'Marasmius', 'Pseudosperma', 'Inocybe', 'Marasmius', 'Scolecobasidium']
# print len of label names: 32
#
# Batch 49:
# Data: tensor([[ 8.,  4.,  1.,  ...,  7.,  8., 10.],
#         [ 4.,  4.,  2.,  ...,  4.,  6.,  3.],
#         [ 3.,  2.,  0.,  ...,  3.,  4.,  2.],
#         ...,
#         [ 4.,  2.,  1.,  ...,  3.,  4.,  0.],
#         [14.,  3.,  4.,  ..., 10.,  6., 31.],
#         [10.,  6.,  2.,  ...,  7.,  4.,  8.]])
# Labels: tensor([21, 50, 59,  7, 17, 50, 32, 66, 32, 49, 12, 32, 32, 32,  6, 21, 21, 32,
#         60, 45, 49, 47, 68, 63,  1, 23,  4, 14, 33, 55,  0, 61])
# Label Names: ['Entoloma', 'Otidea', 'Roussoella', 'Blastobotrys', 'Crepidotus', 'Otidea', 'Inocybe', 'Starmerella', 'Inocybe', 'Orbilia', 'Clavaria', 'Inocybe', 'Inocybe', 'Inocybe', 'Bambusicola', 'Entoloma', 'Entoloma', 'Inocybe', 'Russula', 'Mucor', 'Orbilia', 'Ogataea', 'Suhomyces', 'Scolecobasidium', 'Amanita', 'Fomitiporia', 'Aspergillus', 'Colacogloea', 'Inosperma', 'Pluteus', 'Absidia', 'Saccharomycopsis']
# print len of label names: 32
#
# Batch 50:
# Data: tensor([[12., 14.,  5.,  ...,  3.,  9.,  4.],
#         [ 2.,  3.,  1.,  ...,  4., 10., 11.],
#         [ 0.,  1.,  1.,  ...,  4.,  5.,  1.],
#         ...,
#         [ 7.,  2.,  4.,  ...,  6., 11., 12.],
#         [ 6.,  8.,  3.,  ...,  4.,  7.,  3.],
#         [ 6.,  5.,  3.,  ..., 10.,  9., 17.]])
# Labels: tensor([49, 32, 15, 16, 49, 58,  1, 21,  0, 32, 50,  1, 48,  2, 49, 32, 31,  0,
#         79,  5, 30, 45, 32, 42, 32, 32, 32,  7, 59, 32, 49, 34])
# Label Names: ['Orbilia', 'Inocybe', 'Coprinopsis', 'Cortinarius', 'Orbilia', 'Ramaria', 'Amanita', 'Entoloma', 'Absidia', 'Inocybe', 'Otidea', 'Amanita', 'Ophiocordyceps', 'Apiospora', 'Orbilia', 'Inocybe', 'Hypoxylon', 'Absidia', 'Xylaria', 'Backusella', 'Hymenochaete', 'Mucor', 'Inocybe', 'Marasmius', 'Inocybe', 'Inocybe', 'Inocybe', 'Blastobotrys', 'Roussoella', 'Inocybe', 'Orbilia', 'Kazachstania']
# print len of label names: 32
#
# Batch 51:
# Data: tensor([[ 1.,  3.,  3.,  ...,  9.,  9.,  4.],
#         [ 8.,  1.,  4.,  ...,  5.,  6.,  5.],
#         [17.,  5.,  2.,  ...,  1.,  2.,  3.],
#         ...,
#         [ 8.,  2.,  3.,  ...,  5.,  5.,  6.],
#         [ 2.,  1.,  4.,  ...,  9.,  6., 12.],
#         [ 7.,  6.,  1.,  ...,  3.,  8.,  4.]])
# Labels: tensor([21, 24, 43,  7, 49, 51, 31, 37, 60, 52, 77, 71, 12, 24, 32, 18, 63, 37,
#          8, 34, 45, 31, 68, 52, 54, 70, 39, 22, 21, 42, 32,  9])
# Label Names: ['Entoloma', 'Geastrum', 'Metschnikowia', 'Blastobotrys', 'Orbilia', 'Perenniporia', 'Hypoxylon', 'Lecanora', 'Russula', 'Phylloporus', 'Wickerhamiella', 'Trechispora', 'Clavaria', 'Geastrum', 'Inocybe', 'Cyberlindnera', 'Scolecobasidium', 'Lecanora', 'Boletus', 'Kazachstania', 'Mucor', 'Hypoxylon', 'Suhomyces', 'Phylloporus', 'Pichia', 'Tomentella', 'Leucoagaricus', 'Exophiala', 'Entoloma', 'Marasmius', 'Inocybe', 'Candida']
# print len of label names: 32
#
# Batch 52:
# Data: tensor([[ 4.,  4.,  3.,  ...,  3., 11.,  8.],
#         [ 2.,  2.,  2.,  ...,  4., 10.,  9.],
#         [ 4., 10.,  3.,  ...,  3.,  7.,  6.],
#         ...,
#         [ 3.,  6.,  0.,  ...,  2.,  1.,  1.],
#         [ 0.,  2.,  2.,  ...,  1., 10.,  1.],
#         [ 5.,  4.,  2.,  ...,  5.,  6.,  2.]])
# Labels: tensor([29, 13, 41, 74, 49, 56,  0, 54, 32, 58, 22, 52,  2, 21, 32,  9, 35, 65,
#          4, 80, 32, 78, 80, 21, 29, 61,  6, 21, 68, 73, 38, 68])
# Label Names: ['Hygrophorus', 'Clavulina', 'Malassezia', 'Tricholoma', 'Orbilia', 'Pseudosperma', 'Absidia', 'Pichia', 'Inocybe', 'Ramaria', 'Exophiala', 'Phylloporus', 'Apiospora', 'Entoloma', 'Inocybe', 'Candida', 'Lactarius', 'Spathaspora', 'Aspergillus', 'Xylodon', 'Inocybe', 'Wickerhamomyces', 'Xylodon', 'Entoloma', 'Hygrophorus', 'Saccharomycopsis', 'Bambusicola', 'Entoloma', 'Suhomyces', 'Trichoderma', 'Lepiota', 'Suhomyces']
# print len of label names: 32
#
# Batch 53:
# Data: tensor([[12.,  1.,  2.,  ...,  7., 12., 27.],
#         [ 1.,  1.,  1.,  ...,  2., 10.,  6.],
#         [ 2.,  5.,  2.,  ...,  3.,  3.,  1.],
#         ...,
#         [12.,  7.,  2.,  ...,  7., 10., 12.],
#         [12.,  7.,  7.,  ...,  6.,  4., 15.],
#         [ 7.,  4.,  2.,  ...,  3.,  8., 11.]])
# Labels: tensor([ 1, 60, 71, 38, 49, 32, 61,  7, 22, 45, 63, 33, 32,  4, 72, 42,  9,  4,
#         30, 67, 32, 19, 32, 62, 21,  1, 49,  7,  9])
# Label Names: ['Amanita', 'Russula', 'Trechispora', 'Lepiota', 'Orbilia', 'Inocybe', 'Saccharomycopsis', 'Blastobotrys', 'Exophiala', 'Mucor', 'Scolecobasidium', 'Inosperma', 'Inocybe', 'Aspergillus', 'Tremella', 'Marasmius', 'Candida', 'Aspergillus', 'Hymenochaete', 'Sugiyamaella', 'Inocybe', 'Cyphellophora', 'Inocybe', 'Saturnispora', 'Entoloma', 'Amanita', 'Orbilia', 'Blastobotrys', 'Candida']
# print len of label names: 29

# %%
# Define a CNN model with Conv1D layers and fully connected layers
class CNNModel(nn.Module):
    def __init__(self, input_length, nb_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(1, 5, 5, padding='valid')
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool1d(2)
        self.conv2 = nn.Conv1d(5, 10, 5, padding='valid')
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool1d(2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(10 * ((input_length - 4) // 2 - 4) // 2, 500)
        self.relu3 = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, nb_classes)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = x.unsqueeze(1) 
        x = self.relu1(self.conv1(x))
        x = self.pool1(x)
        x = self.relu2(self.conv2(x))
        x = self.pool2(x)
        x = self.flatten(x)
        x = self.relu3(self.fc1(x))
        x = self.dropout(x)
        x = self.softmax(self.fc2(x))
        return x

input_size = len(data_vectors[0])
num_classes = len(label_encoder.classes_)
model = CNNModel(input_size, num_classes)
input_size = len(data_vectors[0])
num_classes = len(label_encoder.classes_)
model = CNNModel(input_size, num_classes)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_size = int(0.8 * len(kmer_dataset))
test_size = len(kmer_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(kmer_dataset, [train_size, test_size])
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Training loop with testing
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0
    for batch_idx, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device), labels.to(device)
        outputs = model(data)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

    avg_train_loss = total_train_loss / len(train_loader)
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}')
    model.eval()
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs, 1)
            total_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)

    accuracy = total_correct / total_samples * 100
    print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {accuracy:.2f}%')
# Out:
# Epoch [1/100], Training Loss: 4.3060
# Epoch [1/100], Test Accuracy: 11.21%
# Epoch [2/100], Training Loss: 4.2945
# Epoch [2/100], Test Accuracy: 11.21%
# Epoch [3/100], Training Loss: 4.2955
# Epoch [3/100], Test Accuracy: 11.21%
# Epoch [4/100], Training Loss: 4.2918
# Epoch [4/100], Test Accuracy: 11.21%
# Epoch [5/100], Training Loss: 4.2735
# Epoch [5/100], Test Accuracy: 15.04%
# Epoch [6/100], Training Loss: 4.2392
# Epoch [6/100], Test Accuracy: 18.29%
# Epoch [7/100], Training Loss: 4.2119
# Epoch [7/100], Test Accuracy: 21.53%
# Epoch [8/100], Training Loss: 4.1998
# Epoch [8/100], Test Accuracy: 20.94%
# Epoch [9/100], Training Loss: 4.1864
# Epoch [9/100], Test Accuracy: 22.12%
# Epoch [10/100], Training Loss: 4.1717
# Epoch [10/100], Test Accuracy: 23.60%
# Epoch [11/100], Training Loss: 4.1626
# Epoch [11/100], Test Accuracy: 24.78%
# Epoch [12/100], Training Loss: 4.1453
# Epoch [12/100], Test Accuracy: 25.37%
# Epoch [13/100], Training Loss: 4.1190
# Epoch [13/100], Test Accuracy: 27.73%
# Epoch [14/100], Training Loss: 4.1118
# Epoch [14/100], Test Accuracy: 29.79%
# Epoch [15/100], Training Loss: 4.0924
# Epoch [15/100], Test Accuracy: 30.38%
# Epoch [16/100], Training Loss: 4.0852
# Epoch [16/100], Test Accuracy: 30.38%
# Epoch [17/100], Training Loss: 4.0757
# Epoch [17/100], Test Accuracy: 34.22%
# Epoch [18/100], Training Loss: 4.0565
# Epoch [18/100], Test Accuracy: 35.40%
# Epoch [19/100], Training Loss: 4.0573
# Epoch [19/100], Test Accuracy: 34.81%
# Epoch [20/100], Training Loss: 4.0505
# Epoch [20/100], Test Accuracy: 35.99%
# Epoch [21/100], Training Loss: 4.0506
# Epoch [21/100], Test Accuracy: 36.87%
# Epoch [22/100], Training Loss: 4.0405
# Epoch [22/100], Test Accuracy: 36.58%
# Epoch [23/100], Training Loss: 4.0327
# Epoch [23/100], Test Accuracy: 38.35%
# Epoch [24/100], Training Loss: 4.0187
# Epoch [24/100], Test Accuracy: 37.46%
# Epoch [25/100], Training Loss: 4.0113
# Epoch [25/100], Test Accuracy: 39.53%
# Epoch [26/100], Training Loss: 3.9973
# Epoch [26/100], Test Accuracy: 37.76%
# Epoch [27/100], Training Loss: 3.9972
# Epoch [27/100], Test Accuracy: 39.82%
# Epoch [28/100], Training Loss: 3.9878
# Epoch [28/100], Test Accuracy: 39.53%
# Epoch [29/100], Training Loss: 3.9895
# Epoch [29/100], Test Accuracy: 38.94%
# Epoch [30/100], Training Loss: 3.9868
# Epoch [30/100], Test Accuracy: 39.23%
# Epoch [31/100], Training Loss: 3.9849
# Epoch [31/100], Test Accuracy: 40.71%
# Epoch [32/100], Training Loss: 3.9704
# Epoch [32/100], Test Accuracy: 40.12%
# Epoch [33/100], Training Loss: 3.9516
# Epoch [33/100], Test Accuracy: 41.89%
# Epoch [34/100], Training Loss: 3.9587
# Epoch [34/100], Test Accuracy: 42.48%
# Epoch [35/100], Training Loss: 3.9505
# Epoch [35/100], Test Accuracy: 42.48%
# Epoch [36/100], Training Loss: 3.9454
# Epoch [36/100], Test Accuracy: 42.18%
# Epoch [37/100], Training Loss: 3.9359
# Epoch [37/100], Test Accuracy: 42.48%
# Epoch [38/100], Training Loss: 3.9340
# Epoch [38/100], Test Accuracy: 42.48%
# Epoch [39/100], Training Loss: 3.9346
# Epoch [39/100], Test Accuracy: 43.07%
# Epoch [40/100], Training Loss: 3.9394
# Epoch [40/100], Test Accuracy: 42.48%
# Epoch [41/100], Training Loss: 3.9364
# Epoch [41/100], Test Accuracy: 42.48%
# Epoch [42/100], Training Loss: 3.9200
# Epoch [42/100], Test Accuracy: 45.43%
# Epoch [43/100], Training Loss: 3.9022
# Epoch [43/100], Test Accuracy: 44.54%
# Epoch [44/100], Training Loss: 3.8906
# Epoch [44/100], Test Accuracy: 46.02%
# Epoch [45/100], Training Loss: 3.8893
# Epoch [45/100], Test Accuracy: 46.90%
# Epoch [46/100], Training Loss: 3.8846
# Epoch [46/100], Test Accuracy: 46.02%
# Epoch [47/100], Training Loss: 3.8704
# Epoch [47/100], Test Accuracy: 48.08%
# Epoch [48/100], Training Loss: 3.8622
# Epoch [48/100], Test Accuracy: 48.67%
# Epoch [49/100], Training Loss: 3.8634
# Epoch [49/100], Test Accuracy: 47.79%
# Epoch [50/100], Training Loss: 3.8583
# Epoch [50/100], Test Accuracy: 48.97%
# Epoch [51/100], Training Loss: 3.8535
# Epoch [51/100], Test Accuracy: 48.38%
# Epoch [52/100], Training Loss: 3.8463
# Epoch [52/100], Test Accuracy: 48.97%
# Epoch [53/100], Training Loss: 3.8416
# Epoch [53/100], Test Accuracy: 48.97%
# Epoch [54/100], Training Loss: 3.8427
# Epoch [54/100], Test Accuracy: 49.56%
# Epoch [55/100], Training Loss: 3.8406
# Epoch [55/100], Test Accuracy: 50.15%
# Epoch [56/100], Training Loss: 3.8345
# Epoch [56/100], Test Accuracy: 49.26%
# Epoch [57/100], Training Loss: 3.8268
# Epoch [57/100], Test Accuracy: 51.03%
# Epoch [58/100], Training Loss: 3.8253
# Epoch [58/100], Test Accuracy: 51.62%
# Epoch [59/100], Training Loss: 3.8169
# Epoch [59/100], Test Accuracy: 50.74%
# Epoch [60/100], Training Loss: 3.8240
# Epoch [60/100], Test Accuracy: 49.85%
# Epoch [61/100], Training Loss: 3.8243
# Epoch [61/100], Test Accuracy: 50.74%
# Epoch [62/100], Training Loss: 3.8176
# Epoch [62/100], Test Accuracy: 50.74%
# Epoch [63/100], Training Loss: 3.8169
# Epoch [63/100], Test Accuracy: 51.62%
# Epoch [64/100], Training Loss: 3.8135
# Epoch [64/100], Test Accuracy: 52.21%
# Epoch [65/100], Training Loss: 3.8152
# Epoch [65/100], Test Accuracy: 52.21%
# Epoch [66/100], Training Loss: 3.8181
# Epoch [66/100], Test Accuracy: 51.92%
# Epoch [67/100], Training Loss: 3.8129
# Epoch [67/100], Test Accuracy: 51.92%
# Epoch [68/100], Training Loss: 3.8162
# Epoch [68/100], Test Accuracy: 51.92%
# Epoch [69/100], Training Loss: 3.8105
# Epoch [69/100], Test Accuracy: 52.21%
# Epoch [70/100], Training Loss: 3.8074
# Epoch [70/100], Test Accuracy: 50.74%
# Epoch [71/100], Training Loss: 3.8064
# Epoch [71/100], Test Accuracy: 51.33%
# Epoch [72/100], Training Loss: 3.8022
# Epoch [72/100], Test Accuracy: 52.21%
# Epoch [73/100], Training Loss: 3.8059
# Epoch [73/100], Test Accuracy: 52.21%
# Epoch [74/100], Training Loss: 3.7995
# Epoch [74/100], Test Accuracy: 51.62%
# Epoch [75/100], Training Loss: 3.8052
# Epoch [75/100], Test Accuracy: 51.92%
# Epoch [76/100], Training Loss: 3.8085
# Epoch [76/100], Test Accuracy: 51.92%
# Epoch [77/100], Training Loss: 3.8043
# Epoch [77/100], Test Accuracy: 51.92%
# Epoch [78/100], Training Loss: 3.7946
# Epoch [78/100], Test Accuracy: 52.80%
# Epoch [79/100], Training Loss: 3.7928
# Epoch [79/100], Test Accuracy: 52.21%
# Epoch [80/100], Training Loss: 3.7911
# Epoch [80/100], Test Accuracy: 54.28%
# Epoch [81/100], Training Loss: 3.7963
# Epoch [81/100], Test Accuracy: 53.98%
# Epoch [82/100], Training Loss: 3.7910
# Epoch [82/100], Test Accuracy: 53.69%
# Epoch [83/100], Training Loss: 3.7912
# Epoch [83/100], Test Accuracy: 54.87%
# Epoch [84/100], Training Loss: 3.7864
# Epoch [84/100], Test Accuracy: 53.69%
# Epoch [85/100], Training Loss: 3.7820
# Epoch [85/100], Test Accuracy: 54.57%
# Epoch [86/100], Training Loss: 3.7778
# Epoch [86/100], Test Accuracy: 55.46%
# Epoch [87/100], Training Loss: 3.7780
# Epoch [87/100], Test Accuracy: 55.46%
# Epoch [88/100], Training Loss: 3.7753
# Epoch [88/100], Test Accuracy: 56.93%
# Epoch [89/100], Training Loss: 3.7712
# Epoch [89/100], Test Accuracy: 57.52%
# Epoch [90/100], Training Loss: 3.7709
# Epoch [90/100], Test Accuracy: 56.93%
# Epoch [91/100], Training Loss: 3.7658
# Epoch [91/100], Test Accuracy: 56.05%
# Epoch [92/100], Training Loss: 3.7616
# Epoch [92/100], Test Accuracy: 55.46%
# Epoch [93/100], Training Loss: 3.7693
# Epoch [93/100], Test Accuracy: 56.93%
# Epoch [94/100], Training Loss: 3.7632
# Epoch [94/100], Test Accuracy: 56.64%
# Epoch [95/100], Training Loss: 3.7623
# Epoch [95/100], Test Accuracy: 57.23%
# Epoch [96/100], Training Loss: 3.7536
# Epoch [96/100], Test Accuracy: 57.52%
# Epoch [97/100], Training Loss: 3.7506
# Epoch [97/100], Test Accuracy: 55.75%
# Epoch [98/100], Training Loss: 3.7488
# Epoch [98/100], Test Accuracy: 58.11%
# Epoch [99/100], Training Loss: 3.7459
# Epoch [99/100], Test Accuracy: 57.52%
# Epoch [100/100], Training Loss: 3.7493
# Epoch [100/100], Test Accuracy: 57.82%

# %%
num_classes
# Out:
# 81
