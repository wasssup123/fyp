# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# %%
import os
from Bio import SeqIO

def encode_and_save_fasta(fasta_file, data_file):
    # Define the mapping for encoding
    nucleotide_mapping = {'A': '1', 'C': '2', 'G': '3', 'T': '4'}

    # Ensure the directory exists
    os.makedirs(os.path.dirname(data_file), exist_ok=True)

    # Extract sequences, encode, and save to the file
    with open(data_file, 'w') as f:
        for record in SeqIO.parse(fasta_file, "fasta"):
            label = record.description  # Get the label from the header
            sequence = str(record.seq).upper()  # Ensure the sequence is uppercase

            # Encode the sequence using the nucleotide mapping
            encoded_sequence = ''.join([nucleotide_mapping.get(nuc, '0') for nuc in sequence])

            # Write to the file in the format: class label encoded_data
            f.write(f"{label} {encoded_sequence}\n")

# File paths
fasta_file = "data2/fungi_ITS_cleaned.fasta"
data_file = "data2/encoded_data.txt"

# Call the function
encode_and_save_fasta(fasta_file, data_file)

# %% [markdown]
# # genera more than x samples

# %%
import os
from collections import Counter
def filter_classes_with_more_than_5_samples(encoded_data_file, filtered_data_file):
    # Step 1: Count occurrences of each class
    class_counts = Counter()

    # Read the encoded data and count class occurrences
    with open(encoded_data_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            class_label = line.split()[0]  # Assume class label is the first part of each line
            class_counts[class_label] += 1

    # Step 2: Filter classes with more than 5 samples
    valid_classes = {cls for cls, count in class_counts.items() if count >= 5}

    # Step 3: Save filtered sequences to another file
    with open(filtered_data_file, 'w') as filtered_f:
        for line in lines:
            class_label = line.split()[0]
            # Write to the filtered file only if the class has more than 5 samples
            if class_label in valid_classes:
                filtered_f.write(line)


encoded_data_file = "data2/encoded_data.txt"
filtered_data_file = "data2/filtered_encoded_data.txt"
filter_classes_with_more_than_5_samples(encoded_data_file, filtered_data_file)

# %% [markdown]
# # train test split

# %%
import os
import random
from collections import defaultdict

def train_test_split(filtered_data_file, train_file, test_file):
    # Dictionary to hold samples for each class
    class_samples = defaultdict(list)

    # Step 1: Read the filtered data file and organize samples by class
    with open(filtered_data_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            class_label = line.split()[0]
            class_samples[class_label].append(line)

    # Step 2: Split into train and test
    train_samples = []
    test_samples = []

    for class_label, samples in class_samples.items():
        if len(samples) > 1:  # Only take a sample for test if there are multiple samples
            test_sample = random.choice(samples)
            test_samples.append(test_sample)
            # Add the remaining samples to the train set
            train_samples.extend([sample for sample in samples if sample != test_sample])
        else:
            # If only one sample, add it to the train set
            train_samples.extend(samples)

    # Step 3: Save train and test samples to respective files
    with open(train_file, 'w') as train_f, open(test_file, 'w') as test_f:
        train_f.writelines(train_samples)
        test_f.writelines(test_samples)

# File paths
filtered_data_file = "data2/filtered_encoded_data.txt"
train_file = "data2/train_data.txt"
test_file = "data2/test_data.txt"

# Perform train-test split
train_test_split(filtered_data_file, train_file, test_file)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from collections import defaultdict

class SequenceDataset(Dataset):
    def __init__(self, data_file):
        self.samples = []
        self.label_mapping = {}  # To keep track of label-to-number mapping
        label_counter = 0
        
        # Read the file and parse each line
        with open(data_file, 'r') as f:
            lines = f.readlines()
            for line in lines:
                parts = line.strip().split(maxsplit=1)
                label = parts[0]
                sequence_str = parts[1]

                # Map class label to a numeric value
                if label not in self.label_mapping:
                    self.label_mapping[label] = label_counter
                    label_counter += 1

                numeric_label = self.label_mapping[label]
                sequence = [int(x) for x in sequence_str]  # Convert encoded sequence characters to integers
                self.samples.append((sequence, numeric_label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sequence, label = self.samples[idx]
        return torch.tensor(sequence, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# Custom collate function to pad sequences
def pad_collate(batch):
    sequences, labels = zip(*batch)

    # Find the longest sequence in the batch
    max_length = max(len(seq) for seq in sequences)

    # Pad sequences to the maximum length
    padded_sequences = []
    for seq in sequences:
        padded_seq = torch.cat([seq, torch.zeros(max_length - len(seq))])
        padded_sequences.append(padded_seq)

    # Stack padded sequences and labels
    padded_sequences = torch.stack(padded_sequences)
    labels = torch.tensor(labels, dtype=torch.long)

    return padded_sequences, labels

# File paths
train_file = "data2/train_data.txt"
test_file = "data2/test_data.txt"

# Create Dataset objects
train_dataset = SequenceDataset(train_file)
test_dataset = SequenceDataset(test_file)

# Create DataLoaders
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=pad_collate)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=pad_collate)

# Get class mapping
class_mapping = train_dataset.label_mapping
inverse_class_mapping = {v: k for k, v in class_mapping.items()}  # Reverse the mapping to get label names

# Print dataset information
print(f"Number of samples in training dataset: {len(train_dataset)}")
print(f"Class mapping: {class_mapping}")
print(f"Number of unique classes: {len(class_mapping)}")

# Iterate over the DataLoader and print batch information
for batch_idx, (data, labels) in enumerate(train_loader):
    print(f"Batch {batch_idx + 1}:")
    print("Data shape:", data.shape)
    print("Labels:", labels)

    # Map label indices to class names for each batch
    label_names = [inverse_class_mapping[idx.item()] for idx in labels]
    print("Label Names:", label_names)
    print("Number of labels in batch:", len(label_names))
    print()
# Out:
# Number of samples in training dataset: 2500
# Class mapping: {'Cortinarius': 0, 'Penicillium': 1, 'Aspergillus': 2, 'Inocybe': 3, 'Colletotrichum': 4, 'Trichoderma': 5, 'Phlegmacium': 6, 'Talaromyces': 7, 'Fusarium': 8, 'Agaricus': 9, 'Amanita': 10, 'Entoloma': 11, 'Orbilia': 12, 'Russula': 13, 'Lactarius': 14, 'Thaxterogaster': 15, 'Elsinoe': 16, 'Psathyrella': 17, 'Cytospora': 18, 'Phyllosticta': 19, 'Mucor': 20, 'Candida': 21, 'Apiospora': 22, 'Hydnum': 23, 'Exophiala': 24, 'Marasmius': 25, 'Zasmidium': 26, 'Hypoxylon': 27, 'Ogataea': 28, 'Ophiostoma': 29, 'Tuber': 30, 'Pluteus': 31, 'Scolecobasidium': 32, 'Lactifluus': 33, 'Metschnikowia': 34, 'Leucoagaricus': 35, 'Sticta': 36, 'Claviceps': 37, 'Sporothrix': 38, 'Gymnopus': 39, 'Xylodon': 40, 'Cladophialophora': 41, 'Distoseptispora': 42, 'Tomentella': 43, 'Ganoderma': 44, 'Derxomyces': 45, 'Otidea': 46, 'Kazachstania': 47, 'Coniochaeta': 48, 'Verrucaria': 49, 'Sarocladium': 50, 'Lipomyces': 51, 'Hygrophorus': 52, 'Tubeufia': 53, 'Geastrum': 54, 'Pseudosperma': 55, 'Boletus': 56, 'Cyberlindnera': 57, 'Absidia': 58, 'Sugiyamaella': 59, 'Wickerhamiella': 60, 'Leptographium': 61, 'Mortierella': 62, 'Phialocephala': 63, 'Arthroderma': 64, 'Phanerochaete': 65, 'Suhomyces': 66, 'Fomitiporia': 67, 'Malbranchea': 68, 'Taphrina': 69, 'Neodevriesia': 70, 'Tremella': 71, 'Xylaria': 72, 'Rhizopogon': 73, 'Starmerella': 74, 'Papiliotrema': 75, 'Trechispora': 76, 'Periconia': 77, 'Acremonium': 78, 'Cyphellophora': 79, 'Mycena': 80, 'Yamadazyma': 81, 'Wickerhamomyces': 82, 'Pichia': 83, 'Tricholoma': 84, 'Erysiphe': 85, 'Lepiota': 86, 'Blastobotrys': 87, 'Ramaria': 88, 'Metarhizium': 89, 'Tolypocladium': 90, 'Hygrocybe': 91, 'Hypomyces': 92, 'Acaulospora': 93, 'Clavulina': 94, 'Puccinia': 95, 'Vishniacozyma': 96, 'Phylloporus': 97, 'Kondoa': 98, 'Coprinopsis': 99, 'Roussoella': 100, 'Cutaneotrichosporon': 101, 'Hymenoscyphus': 102, 'Inosperma': 103, 'Saccharomycopsis': 104, 'Ceratocystis': 105, 'Helminthosporium': 106, 'Hydnellum': 107, 'Fulvifomes': 108, 'Spathaspora': 109, 'Nemania': 110, 'Crepidotus': 111, 'Hymenochaete': 112, 'Saturnispora': 113, 'Malassezia': 114, 'Trichomerium': 115, 'Bambusicola': 116, 'Perenniporia': 117, 'Chrysosporium': 118, 'Cyathus': 119, 'Podospora': 120, 'Teunomyces': 121, 'Bulleribasidium': 122, 'Nakazawaea': 123, 'Clavaria': 124, 'Fuscoporia': 125, 'Lyomyces': 126, 'Tetraploa': 127, 'Gyromitra': 128, 'Ascosphaera': 129, 'Ophiocordyceps': 130, 'Muyocopron': 131, 'Kwoniella': 132, 'Phellodon': 133, 'Nannizzia': 134, 'Capronia': 135, 'Rhodocybe': 136, 'Colacogloea': 137, 'Filobasidium': 138, 'Nannizziopsis': 139, 'Backusella': 140, 'Umbelopsis': 141, 'Mallocybe': 142, 'Lecanora': 143, 'Collybiopsis': 144, 'Elaphomyces': 145, 'Phlebiopsis': 146, 'Genea': 147, 'Cantharellus': 148, 'Hyphopichia': 149, 'Scytinostroma': 150, 'Cladonia': 151, 'Kodamaea': 152, 'Strigula': 153, 'Mollisia': 154, 'Tropicoporus': 155, 'Efibula': 156, 'Peniophorella': 157, 'Gyroporus': 158, 'Phallus': 159, 'Arthrobotrys': 160, 'Caloplaca': 161, 'Raffaelea': 162, 'Peziza': 163, 'Chlorociboria': 164, 'Leptosillia': 165, 'Ceramothyrium': 166, 'Rhinocladiella': 167, 'Phialemonium': 168, 'Picipes': 169, 'Plenodomus': 170, 'Bacidia': 171, 'Polyporus': 172, 'Phellinus': 173, 'Phyllachora': 174, 'Pachyphlodes': 175, 'Sporidesmium': 176, 'Lindgomyces': 177, 'Endoraecium': 178, 'Ambrosiozyma': 179, 'Dipodascus': 180, 'Kirschsteiniothelia': 181, 'Waltergamsia': 182, 'Niesslia': 183, 'Scleroderma': 184, 'Meliola': 185, 'Calocybe': 186, 'Peroneutypa': 187, 'Crittendenia': 188, 'Nakaseomyces': 189, 'Murispora': 190, 'Paragaeumannomyces': 191, 'Helvella': 192, 'Basidiodendron': 193, 'Diutina': 194, 'Dacrymyces': 195, 'Subulicystidium': 196, 'Massaria': 197, 'Astrothelium': 198, 'Strobilomyces': 199, 'Peltula': 200, 'Trapelia': 201, 'Tulasnella': 202, 'Phylloporia': 203, 'Squamanita': 204, 'Clavariadelphus': 205, 'Sclerococcum': 206, 'Barnettozyma': 207, 'Conocybe': 208, 'Piskurozyma': 209, 'Rhizopus': 210, 'Conioscypha': 211, 'Escovopsis': 212, ' ...
# Number of unique classes: 247
# Batch 1:
# Data shape: torch.Size([16, 863])
# Labels: tensor([ 35,  58,  12,  74, 160, 184, 190,  71,   3, 105, 121,  20, 113,  59,
#         108, 196])
# Label Names: ['Leucoagaricus', 'Absidia', 'Orbilia', 'Starmerella', 'Arthrobotrys', 'Scleroderma', 'Murispora', 'Tremella', 'Inocybe', 'Ceratocystis', 'Teunomyces', 'Mucor', 'Saturnispora', 'Sugiyamaella', 'Fulvifomes', 'Subulicystidium']
# Number of labels in batch: 16
#
# Batch 2:
# Data shape: torch.Size([16, 833])
# Labels: tensor([224,  47,   3,  58,   4,  86,  20, 190,  30, 165, 227,  34,  34,  40,
#           0, 189])
# Label Names: ['Octaviania', 'Kazachstania', 'Inocybe', 'Absidia', 'Colletotrichum', 'Lepiota', 'Mucor', 'Murispora', 'Tuber', 'Leptosillia', 'Tarzetta', 'Metschnikowia', 'Metschnikowia', 'Xylodon', 'Cortinarius', 'Nakaseomyces']
# Number of labels in batch: 16
#
# Batch 3:
# Data shape: torch.Size([16, 804])
# Labels: tensor([ 14,  59,   3,  25,  98,  14, 162,  52,  46,  42, 158,  54, 220,   3,
#         140,   0])
# Label Names: ['Lactarius', 'Sugiyamaella', 'Inocybe', 'Marasmius', 'Kondoa', 'Lactarius', 'Raffaelea', 'Hygrophorus', 'Otidea', 'Distoseptispora', 'Gyroporus', 'Geastrum', 'Phyllactinia', 'Inocybe', 'Backusella', 'Cortinarius']
# Number of labels in batch: 16
#
# Batch 4:
# Data shape: torch.Size([16, 864])
# Labels: tensor([ 36, 159,  13,  47, 147, 210,  19,  20,  51,  46, 114, 122,  59,  67,
#         213,  92])
# Label Names: ['Sticta', 'Phallus', 'Russula', 'Kazachstania', 'Genea', 'Rhizopus', 'Phyllosticta', 'Mucor', 'Lipomyces', 'Otidea', 'Malassezia', 'Bulleribasidium', 'Sugiyamaella', 'Fomitiporia', 'Tetrapisispora', 'Hypomyces']
# Number of labels in batch: 16
#
# Batch 5:
# Data shape: torch.Size([16, 850])
# Labels: tensor([192,   3, 193, 227, 162,  21, 115, 201, 128,  35,  97,  28,  93,  59,
#           3,  33])
# Label Names: ['Helvella', 'Inocybe', 'Basidiodendron', 'Tarzetta', 'Raffaelea', 'Candida', 'Trichomerium', 'Trapelia', 'Gyromitra', 'Leucoagaricus', 'Phylloporus', 'Ogataea', 'Acaulospora', 'Sugiyamaella', 'Inocybe', 'Lactifluus']
# Number of labels in batch: 16
#
# Batch 6:
# Data shape: torch.Size([16, 790])
# Labels: tensor([ 38,  87,  14,  52, 104,  63, 241, 112,  12,   3, 143,  35,  12,  11,
#          32, 113])
# Label Names: ['Sporothrix', 'Blastobotrys', 'Lactarius', 'Hygrophorus', 'Saccharomycopsis', 'Phialocephala', 'Coccomyces', 'Hymenochaete', 'Orbilia', 'Inocybe', 'Lecanora', 'Leucoagaricus', 'Orbilia', 'Entoloma', 'Scolecobasidium', 'Saturnispora']
# Number of labels in batch: 16
#
# Batch 7:
# Data shape: torch.Size([16, 750])
# Labels: tensor([ 39,  40, 110, 138,  86, 133,  35, 106,  19,  86,  13,   2, 192, 137,
#         199,   0])
# Label Names: ['Gymnopus', 'Xylodon', 'Nemania', 'Filobasidium', 'Lepiota', 'Phellodon', 'Leucoagaricus', 'Helminthosporium', 'Phyllosticta', 'Lepiota', 'Russula', 'Aspergillus', 'Helvella', 'Colacogloea', 'Strobilomyces', 'Cortinarius']
# Number of labels in batch: 16
#
# Batch 8:
# Data shape: torch.Size([16, 789])
# Labels: tensor([100,  59, 203, 222, 144,  76, 107,  97,   3,  13, 112,   7,  94, 103,
#          71,  86])
# Label Names: ['Roussoella', 'Sugiyamaella', 'Phylloporia', 'Calocybella', 'Collybiopsis', 'Trechispora', 'Hydnellum', 'Phylloporus', 'Inocybe', 'Russula', 'Hymenochaete', 'Talaromyces', 'Clavulina', 'Inosperma', 'Tremella', 'Lepiota']
# Number of labels in batch: 16
#
# Batch 9:
# Data shape: torch.Size([16, 791])
# Labels: tensor([163,   3, 103, 157,  11,   3,  25,  12,  25, 189,  10, 160,  11,  54,
#          10, 139])
# Label Names: ['Peziza', 'Inocybe', 'Inosperma', 'Peniophorella', 'Entoloma', 'Inocybe', 'Marasmius', 'Orbilia', 'Marasmius', 'Nakaseomyces', 'Amanita', 'Arthrobotrys', 'Entoloma', 'Geastrum', 'Amanita', 'Nannizziopsis']
# Number of labels in batch: 16
#
# Batch 10:
# Data shape: torch.Size([16, 746])
# Labels: tensor([  3,  14,  30, 116,  15,  87,  43,  70,  28,  27,  32, 114,  19, 155,
#          13, 173])
# Label Names: ['Inocybe', 'Lactarius', 'Tuber', 'Bambusicola', 'Thaxterogaster', 'Blastobotrys', 'Tomentella', 'Neodevriesia', 'Ogataea', 'Hypoxylon', 'Scolecobasidium', 'Malassezia', 'Phyllosticta', 'Tropicoporus', 'Russula', 'Phellinus']
# Number of labels in batch: 16
#
# Batch 11:
# Data shape: torch.Size([16, 780])
# Labels: tensor([207,  59,  17,  95,  83,   5,  36,   3,  12, 215,  13, 223, 142, 186,
#           0, 195])
# Label Names: ['Barnettozyma', 'Sugiyamaella', 'Psathyrella', 'Puccinia', 'Pichia', 'Trichoderma', 'Sticta', 'Inocybe', 'Orbilia', 'Gibellula', 'Russula', 'Sidera', 'Mallocybe', 'Calocybe', 'Cortinarius', 'Dacrymyces']
# Number of labels in batch: 16
#
# Batch 12:
# Data shape: torch.Size([16, 744])
# Labels: tensor([  3,  25,  32, 226,  32,   7,  62, 150,  16, 149, 162, 223,  89,  40,
#         245,  46])
# Label Names: ['Inocybe', 'Marasmius', 'Scolecobasidium', 'Phaeoclavulina', 'Scolecobasidium', 'Talaromyces', 'Mortierella', 'Scytinostroma', 'Elsinoe', 'Hyphopichia', 'Raffaelea', 'Sidera', 'Metarhizium', 'Xylodon', 'Atractospora', 'Otidea']
# Number of labels in batch: 16
#
# Batch 13:
# Data shape: torch.Size([16, 806])
# Labels: tensor([  3,  56,  13, 129,  76,  30,  64,  84, 214,  56, 207,  21,   0,   3,
#          54,  88])
# Label Names: ['Inocybe', 'Boletus', 'Russula', 'Ascosphaera', 'Trechispora', 'Tuber', 'Arthroderma', 'Tricholoma', 'Moniliella', 'Boletus', 'Barnettozyma', 'Candida', 'Cortinarius', 'Inocybe', 'Geastrum', 'Ramaria']
# Number of labels in batch: 16
#
# Batch 14:
# Data shape: torch.Size([16, 790])
# Labels: tensor([  8,  75,  13,  59, 210,  81, 191,  88,   3,  21, 149,   3,  93, 176,
#         230,  39])
# Label Names: ['Fusarium', 'Papiliotrema', 'Russula', 'Sugiyamaella', 'Rhizopus', 'Yamadazyma', 'Paragaeumannomyces', 'Ramaria', 'Inocybe', 'Candida', 'Hyphopichia', 'Inocybe', 'Acaulospora', 'Sporidesmium', 'Gibbosporina', 'Gymnopus']
# Number of labels in batch: 16
#
# Batch 15:
# Data shape: torch.Size([16, 823])
# Labels: tensor([ 42, 124, 228,  20, 106, 107,  43, 242,   3,  40, 128, 180,   3, 197,
#          11,  87])
# Label Names: ['Distoseptispora', 'Clavaria', 'Microsporomyces', 'Mucor', 'Helminthosporium', 'Hydnellum', 'Tomentella', 'Xerocomus', 'Inocybe', 'Xylodon', 'Gyromitra', 'Dipodascus', 'Inocybe', 'Massaria', 'Entoloma', 'Blastobotrys']
# Number of labels in batch: 16
#
# Batch 16:
# Data shape: torch.Size([16, 765])
# Labels: tensor([ 28, 221,  24,   8,  21, 128, 213, 209,   3, 119,  42, 110, 142, 124,
#           3,  82])
# Label Names: ['Ogataea', 'Hydnobolites', 'Exophiala', 'Fusarium', 'Candida', 'Gyromitra', 'Tetrapisispora', 'Piskurozyma', 'Inocybe', 'Cyathus', 'Distoseptispora', 'Nemania', 'Mallocybe', 'Clavaria', 'Inocybe', 'Wickerhamomyces']
# Number of labels in batch: 16
#
# Batch 17:
# Data shape: torch.Size([16, 765])
# Labels: tensor([ 21, 213,  12, 169,  21,  33,  59,  53, 162,  89,  34,  72,  92, 103,
#          84, 186])
# Label Names: ['Candida', 'Tetrapisispora', 'Orbilia', 'Picipes', 'Candida', 'Lactifluus', 'Sugiyamaella', 'Tubeufia', 'Raffaelea', 'Metarhizium', 'Metschnikowia', 'Xylaria', 'Hypomyces', 'Inosperma', 'Tricholoma', 'Calocybe']
# Number of labels in batch: 16
#
# Batch 18:
# Data shape: torch.Size([16, 753])
# Labels: tensor([155, 194,  65, 131,  35,  55,  87,  27, 176,   3, 126,  22,  10,  69,
#          11, 174])
# Label Names: ['Tropicoporus', 'Diutina', 'Phanerochaete', 'Muyocopron', 'Leucoagaricus', 'Pseudosperma', 'Blastobotrys', 'Hypoxylon', 'Sporidesmium', 'Inocybe', 'Lyomyces', 'Apiospora', 'Amanita', 'Taphrina', 'Entoloma', 'Phyllachora']
# Number of labels in batch: 16
#
# Batch 19:
# Data shape: torch.Size([16, 833])
# Labels: tensor([  3,   0,  19,  20,   3, 158,  47,  10,  11,  28,   5,  55,  47,  22,
#          56,  12])
# Label Names: ['Inocybe', 'Cortinarius', 'Phyllosticta', 'Mucor', 'Inocybe', 'Gyroporus', 'Kazachstania', 'Amanita', 'Entoloma', 'Ogataea', 'Trichoderma', 'Pseudosperma', 'Kazachstania', 'Apiospora', 'Boletus', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 20:
# Data shape: torch.Size([16, 801])
# Labels: tensor([181, 130,  11,  34, 119,   2,  16, 204,  13,  13,   3, 166,  92, 196,
#           3, 150])
# Label Names: ['Kirschsteiniothelia', 'Ophiocordyceps', 'Entoloma', 'Metschnikowia', 'Cyathus', 'Aspergillus', 'Elsinoe', 'Squamanita', 'Russula', 'Russula', 'Inocybe', 'Ceramothyrium', 'Hypomyces', 'Subulicystidium', 'Inocybe', 'Scytinostroma']
# Number of labels in batch: 16
#
# Batch 21:
# Data shape: torch.Size([16, 751])
# Labels: tensor([ 76,   3,   3, 140, 158,  20,  10,  58,  33,  77, 156,  92,  68, 111,
#         216,  32])
# Label Names: ['Trechispora', 'Inocybe', 'Inocybe', 'Backusella', 'Gyroporus', 'Mucor', 'Amanita', 'Absidia', 'Lactifluus', 'Periconia', 'Efibula', 'Hypomyces', 'Malbranchea', 'Crepidotus', 'Pleurothecium', 'Scolecobasidium']
# Number of labels in batch: 16
#
# Batch 22:
# Data shape: torch.Size([16, 807])
# Labels: tensor([ 64, 234,   7, 187,  12,   3,  58, 211,   3,  66, 225,  62, 203,  90,
#         236,  16])
# Label Names: ['Arthroderma', 'Lichtheimia', 'Talaromyces', 'Peroneutypa', 'Orbilia', 'Inocybe', 'Absidia', 'Conioscypha', 'Inocybe', 'Suhomyces', 'Pyrenophora', 'Mortierella', 'Phylloporia', 'Tolypocladium', 'Oxydothis', 'Elsinoe']
# Number of labels in batch: 16
#
# Batch 23:
# Data shape: torch.Size([16, 765])
# Labels: tensor([ 62,  32, 145,  15,   3, 178,  99,   7,  22,  71,  56,  45,  56,  71,
#          59,  25])
# Label Names: ['Mortierella', 'Scolecobasidium', 'Elaphomyces', 'Thaxterogaster', 'Inocybe', 'Endoraecium', 'Coprinopsis', 'Talaromyces', 'Apiospora', 'Tremella', 'Boletus', 'Derxomyces', 'Boletus', 'Tremella', 'Sugiyamaella', 'Marasmius']
# Number of labels in batch: 16
#
# Batch 24:
# Data shape: torch.Size([16, 748])
# Labels: tensor([ 33, 244,  27,   3,  37, 112, 138,  52, 198, 156,  10, 201,  84,  88,
#         191,  83])
# Label Names: ['Lactifluus', 'Tremateia', 'Hypoxylon', 'Inocybe', 'Claviceps', 'Hymenochaete', 'Filobasidium', 'Hygrophorus', 'Astrothelium', 'Efibula', 'Amanita', 'Trapelia', 'Tricholoma', 'Ramaria', 'Paragaeumannomyces', 'Pichia']
# Number of labels in batch: 16
#
# Batch 25:
# Data shape: torch.Size([16, 1104])
# Labels: tensor([ 43, 133,  11, 217,   3, 179,   3,  10, 229, 117,  33, 170,  59, 110,
#         166,  19])
# Label Names: ['Tomentella', 'Phellodon', 'Entoloma', 'Annulohypoxylon', 'Inocybe', 'Ambrosiozyma', 'Inocybe', 'Amanita', 'Verruconis', 'Perenniporia', 'Lactifluus', 'Plenodomus', 'Sugiyamaella', 'Nemania', 'Ceramothyrium', 'Phyllosticta']
# Number of labels in batch: 16
#
# Batch 26:
# Data shape: torch.Size([16, 779])
# Labels: tensor([ 12,  68, 133,  32,  78,   1,  20,   0,  17,  11,  35,  25,  33, 107,
#          81,   3])
# Label Names: ['Orbilia', 'Malbranchea', 'Phellodon', 'Scolecobasidium', 'Acremonium', 'Penicillium', 'Mucor', 'Cortinarius', 'Psathyrella', 'Entoloma', 'Leucoagaricus', 'Marasmius', 'Lactifluus', 'Hydnellum', 'Yamadazyma', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 27:
# Data shape: torch.Size([16, 685])
# Labels: tensor([  3,  12, 209,  42,  29, 137,  21, 164,  24,  60, 229,  87,  81, 104,
#          80, 112])
# Label Names: ['Inocybe', 'Orbilia', 'Piskurozyma', 'Distoseptispora', 'Ophiostoma', 'Colacogloea', 'Candida', 'Chlorociboria', 'Exophiala', 'Wickerhamiella', 'Verruconis', 'Blastobotrys', 'Yamadazyma', 'Saccharomycopsis', 'Mycena', 'Hymenochaete']
# Number of labels in batch: 16
#
# Batch 28:
# Data shape: torch.Size([16, 1176])
# Labels: tensor([ 13,  92,  12, 148, 114,  20,   3, 179,  55,  21,   3, 103,  10,  25,
#          84,  40])
# Label Names: ['Russula', 'Hypomyces', 'Orbilia', 'Cantharellus', 'Malassezia', 'Mucor', 'Inocybe', 'Ambrosiozyma', 'Pseudosperma', 'Candida', 'Inocybe', 'Inosperma', 'Amanita', 'Marasmius', 'Tricholoma', 'Xylodon']
# Number of labels in batch: 16
#
# Batch 29:
# Data shape: torch.Size([16, 723])
# Labels: tensor([ 83,  53,  83, 149, 166,   0, 125, 118,  31,  80,   5,  41,  10,  67,
#         222, 157])
# Label Names: ['Pichia', 'Tubeufia', 'Pichia', 'Hyphopichia', 'Ceramothyrium', 'Cortinarius', 'Fuscoporia', 'Chrysosporium', 'Pluteus', 'Mycena', 'Trichoderma', 'Cladophialophora', 'Amanita', 'Fomitiporia', 'Calocybella', 'Peniophorella']
# Number of labels in batch: 16
#
# Batch 30:
# Data shape: torch.Size([16, 835])
# Labels: tensor([  3,  76,  62, 231,   2,   2,   7,  66,  22, 167, 201, 222,  74, 118,
#           3,  82])
# Label Names: ['Inocybe', 'Trechispora', 'Mortierella', 'Zygosaccharomyces', 'Aspergillus', 'Aspergillus', 'Talaromyces', 'Suhomyces', 'Apiospora', 'Rhinocladiella', 'Trapelia', 'Calocybella', 'Starmerella', 'Chrysosporium', 'Inocybe', 'Wickerhamomyces']
# Number of labels in batch: 16
#
# Batch 31:
# Data shape: torch.Size([16, 745])
# Labels: tensor([ 18,   0,  17, 106,  28, 154, 156,   3, 194, 190, 132,   3,  76, 170,
#          76,  88])
# Label Names: ['Cytospora', 'Cortinarius', 'Psathyrella', 'Helminthosporium', 'Ogataea', 'Mollisia', 'Efibula', 'Inocybe', 'Diutina', 'Murispora', 'Kwoniella', 'Inocybe', 'Trechispora', 'Plenodomus', 'Trechispora', 'Ramaria']
# Number of labels in batch: 16
#
# Batch 32:
# Data shape: torch.Size([16, 1260])
# Labels: tensor([ 24, 121,  52, 206,  67,  84, 107,  27,   3, 127,  11, 231,  13, 148,
#          97,   3])
# Label Names: ['Exophiala', 'Teunomyces', 'Hygrophorus', 'Sclerococcum', 'Fomitiporia', 'Tricholoma', 'Hydnellum', 'Hypoxylon', 'Inocybe', 'Tetraploa', 'Entoloma', 'Zygosaccharomyces', 'Russula', 'Cantharellus', 'Phylloporus', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 33:
# Data shape: torch.Size([16, 745])
# Labels: tensor([ 11,  71,  12,  10,  11,  12, 174, 186,  66,  12,  18, 109,   3,  51,
#           3,  12])
# Label Names: ['Entoloma', 'Tremella', 'Orbilia', 'Amanita', 'Entoloma', 'Orbilia', 'Phyllachora', 'Calocybe', 'Suhomyces', 'Orbilia', 'Cytospora', 'Spathaspora', 'Inocybe', 'Lipomyces', 'Inocybe', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 34:
# Data shape: torch.Size([16, 1103])
# Labels: tensor([ 33, 116,  31,  91,  82,   0,  60,  21, 224,  21,  27,  91,  82,  51,
#          67, 230])
# Label Names: ['Lactifluus', 'Bambusicola', 'Pluteus', 'Hygrocybe', 'Wickerhamomyces', 'Cortinarius', 'Wickerhamiella', 'Candida', 'Octaviania', 'Candida', 'Hypoxylon', 'Hygrocybe', 'Wickerhamomyces', 'Lipomyces', 'Fomitiporia', 'Gibbosporina']
# Number of labels in batch: 16
#
# Batch 35:
# Data shape: torch.Size([16, 1329])
# Labels: tensor([ 67, 112,   0, 148,  12,  29, 185, 169,  80,  16, 147,   0,  19, 107,
#          27, 184])
# Label Names: ['Fomitiporia', 'Hymenochaete', 'Cortinarius', 'Cantharellus', 'Orbilia', 'Ophiostoma', 'Meliola', 'Picipes', 'Mycena', 'Elsinoe', 'Genea', 'Cortinarius', 'Phyllosticta', 'Hydnellum', 'Hypoxylon', 'Scleroderma']
# Number of labels in batch: 16
#
# Batch 36:
# Data shape: torch.Size([16, 834])
# Labels: tensor([ 11,  31,   2, 127, 201,  39,   3,  56, 234,  12,  28,   3,  80, 158,
#           3,  12])
# Label Names: ['Entoloma', 'Pluteus', 'Aspergillus', 'Tetraploa', 'Trapelia', 'Gymnopus', 'Inocybe', 'Boletus', 'Lichtheimia', 'Orbilia', 'Ogataea', 'Inocybe', 'Mycena', 'Gyroporus', 'Inocybe', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 37:
# Data shape: torch.Size([16, 726])
# Labels: tensor([ 46,  56, 199, 238,  41,  11, 102,   0,  69, 123, 187,  11,  83,  76,
#         163, 120])
# Label Names: ['Otidea', 'Boletus', 'Strobilomyces', 'Volvariella', 'Cladophialophora', 'Entoloma', 'Hymenoscyphus', 'Cortinarius', 'Taphrina', 'Nakazawaea', 'Peroneutypa', 'Entoloma', 'Pichia', 'Trechispora', 'Peziza', 'Podospora']
# Number of labels in batch: 16
#
# Batch 38:
# Data shape: torch.Size([16, 1126])
# Labels: tensor([130,  80, 109, 100,  27,  20, 108,  12,  37,  88,   3,  27, 239, 177,
#          27, 152])
# Label Names: ['Ophiocordyceps', 'Mycena', 'Spathaspora', 'Roussoella', 'Hypoxylon', 'Mucor', 'Fulvifomes', 'Orbilia', 'Claviceps', 'Ramaria', 'Inocybe', 'Hypoxylon', 'Vararia', 'Lindgomyces', 'Hypoxylon', 'Kodamaea']
# Number of labels in batch: 16
#
# Batch 39:
# Data shape: torch.Size([16, 742])
# Labels: tensor([ 52, 212, 104, 188,  27,  65,  20,   3, 140,  52, 107,  66,  31, 182,
#          72, 215])
# Label Names: ['Hygrophorus', 'Escovopsis', 'Saccharomycopsis', 'Crittendenia', 'Hypoxylon', 'Phanerochaete', 'Mucor', 'Inocybe', 'Backusella', 'Hygrophorus', 'Hydnellum', 'Suhomyces', 'Pluteus', 'Waltergamsia', 'Xylaria', 'Gibellula']
# Number of labels in batch: 16
#
# Batch 40:
# Data shape: torch.Size([16, 758])
# Labels: tensor([ 60,  24,  14,  20, 114,  10, 216,  14,  98,  13, 107,  63,  80,  41,
#           5, 164])
# Label Names: ['Wickerhamiella', 'Exophiala', 'Lactarius', 'Mucor', 'Malassezia', 'Amanita', 'Pleurothecium', 'Lactarius', 'Kondoa', 'Russula', 'Hydnellum', 'Phialocephala', 'Mycena', 'Cladophialophora', 'Trichoderma', 'Chlorociboria']
# Number of labels in batch: 16
#
# Batch 41:
# Data shape: torch.Size([16, 767])
# Labels: tensor([  6, 180,  37,  30, 172,  10,  33,  53,  46,  27, 134,  58,  10,  82,
#           3,  20])
# Label Names: ['Phlegmacium', 'Dipodascus', 'Claviceps', 'Tuber', 'Polyporus', 'Amanita', 'Lactifluus', 'Tubeufia', 'Otidea', 'Hypoxylon', 'Nannizzia', 'Absidia', 'Amanita', 'Wickerhamomyces', 'Inocybe', 'Mucor']
# Number of labels in batch: 16
#
# Batch 42:
# Data shape: torch.Size([16, 896])
# Labels: tensor([ 10,  43,  11, 178, 188,  83, 101,  44,  59, 176,  69,  14,  51, 204,
#          79,  20])
# Label Names: ['Amanita', 'Tomentella', 'Entoloma', 'Endoraecium', 'Crittendenia', 'Pichia', 'Cutaneotrichosporon', 'Ganoderma', 'Sugiyamaella', 'Sporidesmium', 'Taphrina', 'Lactarius', 'Lipomyces', 'Squamanita', 'Cyphellophora', 'Mucor']
# Number of labels in batch: 16
#
# Batch 43:
# Data shape: torch.Size([16, 830])
# Labels: tensor([184, 187,  99, 142,  56, 245,  26,  10, 126,   3,   0,  21,  16,  76,
#          25,  78])
# Label Names: ['Scleroderma', 'Peroneutypa', 'Coprinopsis', 'Mallocybe', 'Boletus', 'Atractospora', 'Zasmidium', 'Amanita', 'Lyomyces', 'Inocybe', 'Cortinarius', 'Candida', 'Elsinoe', 'Trechispora', 'Marasmius', 'Acremonium']
# Number of labels in batch: 16
#
# Batch 44:
# Data shape: torch.Size([16, 793])
# Labels: tensor([  6, 137,  87, 227, 191, 114,   5,   2, 234, 113,  65,   3, 216,   3,
#         210,  25])
# Label Names: ['Phlegmacium', 'Colacogloea', 'Blastobotrys', 'Tarzetta', 'Paragaeumannomyces', 'Malassezia', 'Trichoderma', 'Aspergillus', 'Lichtheimia', 'Saturnispora', 'Phanerochaete', 'Inocybe', 'Pleurothecium', 'Inocybe', 'Rhizopus', 'Marasmius']
# Number of labels in batch: 16
#
# Batch 45:
# Data shape: torch.Size([16, 746])
# Labels: tensor([ 86,  58,   3, 232, 159,  91,  57,  12,  74, 117,  12, 132, 193, 136,
#          90,  82])
# Label Names: ['Lepiota', 'Absidia', 'Inocybe', 'Auritella', 'Phallus', 'Hygrocybe', 'Cyberlindnera', 'Orbilia', 'Starmerella', 'Perenniporia', 'Orbilia', 'Kwoniella', 'Basidiodendron', 'Rhodocybe', 'Tolypocladium', 'Wickerhamomyces']
# Number of labels in batch: 16
#
# Batch 46:
# Data shape: torch.Size([16, 768])
# Labels: tensor([ 12,   8, 209, 131,   3, 180, 170,  83, 232, 241,   3,  45,  94,  20,
#          21,  22])
# Label Names: ['Orbilia', 'Fusarium', 'Piskurozyma', 'Muyocopron', 'Inocybe', 'Dipodascus', 'Plenodomus', 'Pichia', 'Auritella', 'Coccomyces', 'Inocybe', 'Derxomyces', 'Clavulina', 'Mucor', 'Candida', 'Apiospora']
# Number of labels in batch: 16
#
# Batch 47:
# Data shape: torch.Size([16, 792])
# Labels: tensor([ 11,  24, 178,  96, 144,  13, 150,   0,  33,  27,  54, 154, 206, 125,
#          10,  52])
# Label Names: ['Entoloma', 'Exophiala', 'Endoraecium', 'Vishniacozyma', 'Collybiopsis', 'Russula', 'Scytinostroma', 'Cortinarius', 'Lactifluus', 'Hypoxylon', 'Geastrum', 'Mollisia', 'Sclerococcum', 'Fuscoporia', 'Amanita', 'Hygrophorus']
# Number of labels in batch: 16
#
# Batch 48:
# Data shape: torch.Size([16, 759])
# Labels: tensor([ 10, 117, 117,  34,  37, 196,   3, 236,   3,  25,  55,  34, 131, 236,
#         124,  27])
# Label Names: ['Amanita', 'Perenniporia', 'Perenniporia', 'Metschnikowia', 'Claviceps', 'Subulicystidium', 'Inocybe', 'Oxydothis', 'Inocybe', 'Marasmius', 'Pseudosperma', 'Metschnikowia', 'Muyocopron', 'Oxydothis', 'Clavaria', 'Hypoxylon']
# Number of labels in batch: 16
#
# Batch 49:
# Data shape: torch.Size([16, 1205])
# Labels: tensor([  8,  25, 197,  20,   3,   2,  64,  33,  32,  14, 199, 147,  28,  70,
#          41, 215])
# Label Names: ['Fusarium', 'Marasmius', 'Massaria', 'Mucor', 'Inocybe', 'Aspergillus', 'Arthroderma', 'Lactifluus', 'Scolecobasidium', 'Lactarius', 'Strobilomyces', 'Genea', 'Ogataea', 'Neodevriesia', 'Cladophialophora', 'Gibellula']
# Number of labels in batch: 16
#
# Batch 50:
# Data shape: torch.Size([16, 726])
# Labels: tensor([ 32, 159,   3,  74,  71, 111,  32,   3,  81,  69, 123,  54,  12,  57,
#          37,  84])
# Label Names: ['Scolecobasidium', 'Phallus', 'Inocybe', 'Starmerella', 'Tremella', 'Crepidotus', 'Scolecobasidium', 'Inocybe', 'Yamadazyma', 'Taphrina', 'Nakazawaea', 'Geastrum', 'Orbilia', 'Cyberlindnera', 'Claviceps', 'Tricholoma']
# Number of labels in batch: 16
#
# Batch 51:
# Data shape: torch.Size([16, 734])
# Labels: tensor([ 25, 159,  31,   3, 240, 171, 120,  53,  91,  27, 143,   2,  12,  72,
#         130,   3])
# Label Names: ['Marasmius', 'Phallus', 'Pluteus', 'Inocybe', 'Buellia', 'Bacidia', 'Podospora', 'Tubeufia', 'Hygrocybe', 'Hypoxylon', 'Lecanora', 'Aspergillus', 'Orbilia', 'Xylaria', 'Ophiocordyceps', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 52:
# Data shape: torch.Size([16, 761])
# Labels: tensor([  5,   1,  54,  55,  59,   3,   3, 122, 183, 157,  77, 113,  10,  11,
#          54,  32])
# Label Names: ['Trichoderma', 'Penicillium', 'Geastrum', 'Pseudosperma', 'Sugiyamaella', 'Inocybe', 'Inocybe', 'Bulleribasidium', 'Niesslia', 'Peniophorella', 'Periconia', 'Saturnispora', 'Amanita', 'Entoloma', 'Geastrum', 'Scolecobasidium']
# Number of labels in batch: 16
#
# Batch 53:
# Data shape: torch.Size([16, 1390])
# Labels: tensor([173,  37,  11, 123,  14,  10, 197,  22,  27, 204,  58, 175,  49,  11,
#         137,  55])
# Label Names: ['Phellinus', 'Claviceps', 'Entoloma', 'Nakazawaea', 'Lactarius', 'Amanita', 'Massaria', 'Apiospora', 'Hypoxylon', 'Squamanita', 'Absidia', 'Pachyphlodes', 'Verrucaria', 'Entoloma', 'Colacogloea', 'Pseudosperma']
# Number of labels in batch: 16
#
# Batch 54:
# Data shape: torch.Size([16, 744])
# Labels: tensor([  3,  13, 100, 212,  70,  96, 117, 151, 212,  10,  38,  86, 113, 142,
#           9, 163])
# Label Names: ['Inocybe', 'Russula', 'Roussoella', 'Escovopsis', 'Neodevriesia', 'Vishniacozyma', 'Perenniporia', 'Cladonia', 'Escovopsis', 'Amanita', 'Sporothrix', 'Lepiota', 'Saturnispora', 'Mallocybe', 'Agaricus', 'Peziza']
# Number of labels in batch: 16
#
# Batch 55:
# Data shape: torch.Size([16, 784])
# Labels: tensor([ 91,  21,  58, 180, 220,  95,  23,  35,  10,  87, 221,  80,  57, 100,
#          30,  47])
# Label Names: ['Hygrocybe', 'Candida', 'Absidia', 'Dipodascus', 'Phyllactinia', 'Puccinia', 'Hydnum', 'Leucoagaricus', 'Amanita', 'Blastobotrys', 'Hydnobolites', 'Mycena', 'Cyberlindnera', 'Roussoella', 'Tuber', 'Kazachstania']
# Number of labels in batch: 16
#
# Batch 56:
# Data shape: torch.Size([16, 1003])
# Labels: tensor([140, 136,  24,  64,  11, 230,   3,  32,   3, 202,  25,  21, 155, 226,
#          11, 103])
# Label Names: ['Backusella', 'Rhodocybe', 'Exophiala', 'Arthroderma', 'Entoloma', 'Gibbosporina', 'Inocybe', 'Scolecobasidium', 'Inocybe', 'Tulasnella', 'Marasmius', 'Candida', 'Tropicoporus', 'Phaeoclavulina', 'Entoloma', 'Inosperma']
# Number of labels in batch: 16
#
# Batch 57:
# Data shape: torch.Size([16, 858])
# Labels: tensor([185, 235,  12,   4,  48, 168,   3, 238,  21,  45,  97, 170,  18, 228,
#         220, 231])
# Label Names: ['Meliola', 'Sulzbacheromyces', 'Orbilia', 'Colletotrichum', 'Coniochaeta', 'Phialemonium', 'Inocybe', 'Volvariella', 'Candida', 'Derxomyces', 'Phylloporus', 'Plenodomus', 'Cytospora', 'Microsporomyces', 'Phyllactinia', 'Zygosaccharomyces']
# Number of labels in batch: 16
#
# Batch 58:
# Data shape: torch.Size([16, 905])
# Labels: tensor([ 30,   9,  22,  13, 178,  28, 115,  83,  40,  12,  10,  32,  60,  47,
#         242,   3])
# Label Names: ['Tuber', 'Agaricus', 'Apiospora', 'Russula', 'Endoraecium', 'Ogataea', 'Trichomerium', 'Pichia', 'Xylodon', 'Orbilia', 'Amanita', 'Scolecobasidium', 'Wickerhamiella', 'Kazachstania', 'Xerocomus', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 59:
# Data shape: torch.Size([16, 1160])
# Labels: tensor([122, 117, 149,  29,  97, 164, 185,   5,  35, 244,   3, 141,  71,   2,
#         189,  99])
# Label Names: ['Bulleribasidium', 'Perenniporia', 'Hyphopichia', 'Ophiostoma', 'Phylloporus', 'Chlorociboria', 'Meliola', 'Trichoderma', 'Leucoagaricus', 'Tremateia', 'Inocybe', 'Umbelopsis', 'Tremella', 'Aspergillus', 'Nakaseomyces', 'Coprinopsis']
# Number of labels in batch: 16
#
# Batch 60:
# Data shape: torch.Size([16, 815])
# Labels: tensor([ 66,  52, 117,   5, 162, 124, 116, 246, 190, 150,  12,  43, 164,  10,
#          73,  89])
# Label Names: ['Suhomyces', 'Hygrophorus', 'Perenniporia', 'Trichoderma', 'Raffaelea', 'Clavaria', 'Bambusicola', 'Brettanomyces', 'Murispora', 'Scytinostroma', 'Orbilia', 'Tomentella', 'Chlorociboria', 'Amanita', 'Rhizopogon', 'Metarhizium']
# Number of labels in batch: 16
#
# Batch 61:
# Data shape: torch.Size([16, 850])
# Labels: tensor([237, 241,   5,  12,  10, 204,  54,  49,  56,   9,   5,  21,  39, 126,
#          68, 165])
# Label Names: ['Resupinatus', 'Coccomyces', 'Trichoderma', 'Orbilia', 'Amanita', 'Squamanita', 'Geastrum', 'Verrucaria', 'Boletus', 'Agaricus', 'Trichoderma', 'Candida', 'Gymnopus', 'Lyomyces', 'Malbranchea', 'Leptosillia']
# Number of labels in batch: 16
#
# Batch 62:
# Data shape: torch.Size([16, 780])
# Labels: tensor([ 72,  62,   3,  67,  20,  12,  12,   3, 151,  45, 205,  57,  23,  80,
#           3,  59])
# Label Names: ['Xylaria', 'Mortierella', 'Inocybe', 'Fomitiporia', 'Mucor', 'Orbilia', 'Orbilia', 'Inocybe', 'Cladonia', 'Derxomyces', 'Clavariadelphus', 'Cyberlindnera', 'Hydnum', 'Mycena', 'Inocybe', 'Sugiyamaella']
# Number of labels in batch: 16
#
# Batch 63:
# Data shape: torch.Size([16, 693])
# Labels: tensor([ 32, 237,  10, 205, 182,  74,  79, 106,  45,  66, 233,  94,  76,  60,
#          11,  32])
# Label Names: ['Scolecobasidium', 'Resupinatus', 'Amanita', 'Clavariadelphus', 'Waltergamsia', 'Starmerella', 'Cyphellophora', 'Helminthosporium', 'Derxomyces', 'Suhomyces', 'Kuraishia', 'Clavulina', 'Trechispora', 'Wickerhamiella', 'Entoloma', 'Scolecobasidium']
# Number of labels in batch: 16
#
# Batch 64:
# Data shape: torch.Size([16, 755])
# Labels: tensor([ 91,  95, 100,  35, 229,  30,  71,  48, 100,  99, 124,  79,  13, 119,
#         160, 186])
# Label Names: ['Hygrocybe', 'Puccinia', 'Roussoella', 'Leucoagaricus', 'Verruconis', 'Tuber', 'Tremella', 'Coniochaeta', 'Roussoella', 'Coprinopsis', 'Clavaria', 'Cyphellophora', 'Russula', 'Cyathus', 'Arthrobotrys', 'Calocybe']
# Number of labels in batch: 16
#
# Batch 65:
# Data shape: torch.Size([16, 818])
# Labels: tensor([234,  14,  73,  91, 159,  46,  56, 150,  30,  30,   2,  10, 217,  24,
#         129, 196])
# Label Names: ['Lichtheimia', 'Lactarius', 'Rhizopogon', 'Hygrocybe', 'Phallus', 'Otidea', 'Boletus', 'Scytinostroma', 'Tuber', 'Tuber', 'Aspergillus', 'Amanita', 'Annulohypoxylon', 'Exophiala', 'Ascosphaera', 'Subulicystidium']
# Number of labels in batch: 16
#
# Batch 66:
# Data shape: torch.Size([16, 742])
# Labels: tensor([  3, 173,  62,  86,  27,  88,  27,  91, 202,  19,  18,  24,  11, 196,
#          71, 195])
# Label Names: ['Inocybe', 'Phellinus', 'Mortierella', 'Lepiota', 'Hypoxylon', 'Ramaria', 'Hypoxylon', 'Hygrocybe', 'Tulasnella', 'Phyllosticta', 'Cytospora', 'Exophiala', 'Entoloma', 'Subulicystidium', 'Tremella', 'Dacrymyces']
# Number of labels in batch: 16
#
# Batch 67:
# Data shape: torch.Size([16, 765])
# Labels: tensor([ 46,   3,  44, 131, 218,   3,   4,   3,  93,  42,  34,  52,   3,  91,
#           3,  86])
# Label Names: ['Otidea', 'Inocybe', 'Ganoderma', 'Muyocopron', 'Hyphoderma', 'Inocybe', 'Colletotrichum', 'Inocybe', 'Acaulospora', 'Distoseptispora', 'Metschnikowia', 'Hygrophorus', 'Inocybe', 'Hygrocybe', 'Inocybe', 'Lepiota']
# Number of labels in batch: 16
#
# Batch 68:
# Data shape: torch.Size([16, 771])
# Labels: tensor([ 27,  17, 103,  91, 225,   3,  12,  13,  12, 136,  76,  33,  30,  21,
#         147,   5])
# Label Names: ['Hypoxylon', 'Psathyrella', 'Inosperma', 'Hygrocybe', 'Pyrenophora', 'Inocybe', 'Orbilia', 'Russula', 'Orbilia', 'Rhodocybe', 'Trechispora', 'Lactifluus', 'Tuber', 'Candida', 'Genea', 'Trichoderma']
# Number of labels in batch: 16
#
# Batch 69:
# Data shape: torch.Size([16, 793])
# Labels: tensor([  3,  60,  39,  53, 233, 195,   7,  16,  20,  20, 160,  90,  33, 224,
#         193,  33])
# Label Names: ['Inocybe', 'Wickerhamiella', 'Gymnopus', 'Tubeufia', 'Kuraishia', 'Dacrymyces', 'Talaromyces', 'Elsinoe', 'Mucor', 'Mucor', 'Arthrobotrys', 'Tolypocladium', 'Lactifluus', 'Octaviania', 'Basidiodendron', 'Lactifluus']
# Number of labels in batch: 16
#
# Batch 70:
# Data shape: torch.Size([16, 787])
# Labels: tensor([  3,  15,  19, 213,  55,  16,  95,  84,   3,  12, 199,  11, 129, 156,
#          74, 185])
# Label Names: ['Inocybe', 'Thaxterogaster', 'Phyllosticta', 'Tetrapisispora', 'Pseudosperma', 'Elsinoe', 'Puccinia', 'Tricholoma', 'Inocybe', 'Orbilia', 'Strobilomyces', 'Entoloma', 'Ascosphaera', 'Efibula', 'Starmerella', 'Meliola']
# Number of labels in batch: 16
#
# Batch 71:
# Data shape: torch.Size([16, 768])
# Labels: tensor([ 14,  30,  60,   3,  73,  24, 107, 162, 153, 133,  83,  34,  32, 208,
#          53, 195])
# Label Names: ['Lactarius', 'Tuber', 'Wickerhamiella', 'Inocybe', 'Rhizopogon', 'Exophiala', 'Hydnellum', 'Raffaelea', 'Strigula', 'Phellodon', 'Pichia', 'Metschnikowia', 'Scolecobasidium', 'Conocybe', 'Tubeufia', 'Dacrymyces']
# Number of labels in batch: 16
#
# Batch 72:
# Data shape: torch.Size([16, 833])
# Labels: tensor([ 46,   5,  86, 121,  94,  58,  82,  27, 129,  16,   3,   3,   3,  62,
#         238, 166])
# Label Names: ['Otidea', 'Trichoderma', 'Lepiota', 'Teunomyces', 'Clavulina', 'Absidia', 'Wickerhamomyces', 'Hypoxylon', 'Ascosphaera', 'Elsinoe', 'Inocybe', 'Inocybe', 'Inocybe', 'Mortierella', 'Volvariella', 'Ceramothyrium']
# Number of labels in batch: 16
#
# Batch 73:
# Data shape: torch.Size([16, 773])
# Labels: tensor([ 41,  77,   3, 198, 195, 140,  20,  13,  32,  41,  44,  84, 220,  51,
#           3, 152])
# Label Names: ['Cladophialophora', 'Periconia', 'Inocybe', 'Astrothelium', 'Dacrymyces', 'Backusella', 'Mucor', 'Russula', 'Scolecobasidium', 'Cladophialophora', 'Ganoderma', 'Tricholoma', 'Phyllactinia', 'Lipomyces', 'Inocybe', 'Kodamaea']
# Number of labels in batch: 16
#
# Batch 74:
# Data shape: torch.Size([16, 706])
# Labels: tensor([211,  74,  91,  82,  56,  40,  30,   2,   3,  13,   3, 130, 164,  28,
#          91,  47])
# Label Names: ['Conioscypha', 'Starmerella', 'Hygrocybe', 'Wickerhamomyces', 'Boletus', 'Xylodon', 'Tuber', 'Aspergillus', 'Inocybe', 'Russula', 'Inocybe', 'Ophiocordyceps', 'Chlorociboria', 'Ogataea', 'Hygrocybe', 'Kazachstania']
# Number of labels in batch: 16
#
# Batch 75:
# Data shape: torch.Size([16, 800])
# Labels: tensor([ 66, 194,   3, 111, 200, 146, 166,  25,  70, 104,  10,   3,  71,  56,
#           6,  32])
# Label Names: ['Suhomyces', 'Diutina', 'Inocybe', 'Crepidotus', 'Peltula', 'Phlebiopsis', 'Ceramothyrium', 'Marasmius', 'Neodevriesia', 'Saccharomycopsis', 'Amanita', 'Inocybe', 'Tremella', 'Boletus', 'Phlegmacium', 'Scolecobasidium']
# Number of labels in batch: 16
#
# Batch 76:
# Data shape: torch.Size([16, 1099])
# Labels: tensor([ 91,  40,  27,  11, 152, 108,   3,  11,  79, 162, 233,   9,  64,  33,
#         148,   2])
# Label Names: ['Hygrocybe', 'Xylodon', 'Hypoxylon', 'Entoloma', 'Kodamaea', 'Fulvifomes', 'Inocybe', 'Entoloma', 'Cyphellophora', 'Raffaelea', 'Kuraishia', 'Agaricus', 'Arthroderma', 'Lactifluus', 'Cantharellus', 'Aspergillus']
# Number of labels in batch: 16
#
# Batch 77:
# Data shape: torch.Size([16, 678])
# Labels: tensor([ 55,   2, 120,  82, 246,  33, 199,  94,  66, 232,  21,  10, 174,  83,
#         228,  96])
# Label Names: ['Pseudosperma', 'Aspergillus', 'Podospora', 'Wickerhamomyces', 'Brettanomyces', 'Lactifluus', 'Strobilomyces', 'Clavulina', 'Suhomyces', 'Auritella', 'Candida', 'Amanita', 'Phyllachora', 'Pichia', 'Microsporomyces', 'Vishniacozyma']
# Number of labels in batch: 16
#
# Batch 78:
# Data shape: torch.Size([16, 1247])
# Labels: tensor([  3,   3,  54,  88, 125, 175, 134, 148,  62,   3,  88, 161,  24, 103,
#           3,  58])
# Label Names: ['Inocybe', 'Inocybe', 'Geastrum', 'Ramaria', 'Fuscoporia', 'Pachyphlodes', 'Nannizzia', 'Cantharellus', 'Mortierella', 'Inocybe', 'Ramaria', 'Caloplaca', 'Exophiala', 'Inosperma', 'Inocybe', 'Absidia']
# Number of labels in batch: 16
#
# Batch 79:
# Data shape: torch.Size([16, 1179])
# Labels: tensor([ 31,  47,   3, 143, 148,  12,  55,  13, 200,  43,   3, 131,  10,  30,
#          21, 244])
# Label Names: ['Pluteus', 'Kazachstania', 'Inocybe', 'Lecanora', 'Cantharellus', 'Orbilia', 'Pseudosperma', 'Russula', 'Peltula', 'Tomentella', 'Inocybe', 'Muyocopron', 'Amanita', 'Tuber', 'Candida', 'Tremateia']
# Number of labels in batch: 16
#
# Batch 80:
# Data shape: torch.Size([16, 727])
# Labels: tensor([ 34, 120,  30, 175,  60,  60, 235, 200,  20, 132,  54,  53,  48,  87,
#         120, 130])
# Label Names: ['Metschnikowia', 'Podospora', 'Tuber', 'Pachyphlodes', 'Wickerhamiella', 'Wickerhamiella', 'Sulzbacheromyces', 'Peltula', 'Mucor', 'Kwoniella', 'Geastrum', 'Tubeufia', 'Coniochaeta', 'Blastobotrys', 'Podospora', 'Ophiocordyceps']
# Number of labels in batch: 16
#
# Batch 81:
# Data shape: torch.Size([16, 756])
# Labels: tensor([214,  13,  87, 113, 151,  13,  37, 165,  57, 147,  53, 167, 234,   1,
#           3,  24])
# Label Names: ['Moniliella', 'Russula', 'Blastobotrys', 'Saturnispora', 'Cladonia', 'Russula', 'Claviceps', 'Leptosillia', 'Cyberlindnera', 'Genea', 'Tubeufia', 'Rhinocladiella', 'Lichtheimia', 'Penicillium', 'Inocybe', 'Exophiala']
# Number of labels in batch: 16
#
# Batch 82:
# Data shape: torch.Size([16, 812])
# Labels: tensor([110, 145,   3,   3, 148, 218, 172, 137,  54, 204,   0, 175, 143,  88,
#          12, 222])
# Label Names: ['Nemania', 'Elaphomyces', 'Inocybe', 'Inocybe', 'Cantharellus', 'Hyphoderma', 'Polyporus', 'Colacogloea', 'Geastrum', 'Squamanita', 'Cortinarius', 'Pachyphlodes', 'Lecanora', 'Ramaria', 'Orbilia', 'Calocybella']
# Number of labels in batch: 16
#
# Batch 83:
# Data shape: torch.Size([16, 795])
# Labels: tensor([ 74,  10,   3,  47, 200, 142,   3,   3,  21,  10,   3,   3,   8,  77,
#           2,   5])
# Label Names: ['Starmerella', 'Amanita', 'Inocybe', 'Kazachstania', 'Peltula', 'Mallocybe', 'Inocybe', 'Inocybe', 'Candida', 'Amanita', 'Inocybe', 'Inocybe', 'Fusarium', 'Periconia', 'Aspergillus', 'Trichoderma']
# Number of labels in batch: 16
#
# Batch 84:
# Data shape: torch.Size([16, 718])
# Labels: tensor([155,  12,  22,  88, 111,  12,  20, 193,  77, 127,  76,  27,  21,  63,
#         111,  43])
# Label Names: ['Tropicoporus', 'Orbilia', 'Apiospora', 'Ramaria', 'Crepidotus', 'Orbilia', 'Mucor', 'Basidiodendron', 'Periconia', 'Tetraploa', 'Trechispora', 'Hypoxylon', 'Candida', 'Phialocephala', 'Crepidotus', 'Tomentella']
# Number of labels in batch: 16
#
# Batch 85:
# Data shape: torch.Size([16, 779])
# Labels: tensor([206,  40,  99, 149, 163,  32, 192,  21,   3,   6,  20, 156,  12,   3,
#           3,  99])
# Label Names: ['Sclerococcum', 'Xylodon', 'Coprinopsis', 'Hyphopichia', 'Peziza', 'Scolecobasidium', 'Helvella', 'Candida', 'Inocybe', 'Phlegmacium', 'Mucor', 'Efibula', 'Orbilia', 'Inocybe', 'Inocybe', 'Coprinopsis']
# Number of labels in batch: 16
#
# Batch 86:
# Data shape: torch.Size([16, 745])
# Labels: tensor([113,   2,  46,  32,  24,  10,  24,  96,  10, 104, 143,   3, 207,  74,
#         182,  35])
# Label Names: ['Saturnispora', 'Aspergillus', 'Otidea', 'Scolecobasidium', 'Exophiala', 'Amanita', 'Exophiala', 'Vishniacozyma', 'Amanita', 'Saccharomycopsis', 'Lecanora', 'Inocybe', 'Barnettozyma', 'Starmerella', 'Waltergamsia', 'Leucoagaricus']
# Number of labels in batch: 16
#
# Batch 87:
# Data shape: torch.Size([16, 996])
# Labels: tensor([185,   5,  27,  56, 224,  79, 176,  10, 208,   1, 181,  61,   3, 151,
#           3,  34])
# Label Names: ['Meliola', 'Trichoderma', 'Hypoxylon', 'Boletus', 'Octaviania', 'Cyphellophora', 'Sporidesmium', 'Amanita', 'Conocybe', 'Penicillium', 'Kirschsteiniothelia', 'Leptographium', 'Inocybe', 'Cladonia', 'Inocybe', 'Metschnikowia']
# Number of labels in batch: 16
#
# Batch 88:
# Data shape: torch.Size([16, 769])
# Labels: tensor([  3, 126, 121,   3,   3, 159,  96,  11,  21,  10, 211, 105,  30, 188,
#         114,  74])
# Label Names: ['Inocybe', 'Lyomyces', 'Teunomyces', 'Inocybe', 'Inocybe', 'Phallus', 'Vishniacozyma', 'Entoloma', 'Candida', 'Amanita', 'Conioscypha', 'Ceratocystis', 'Tuber', 'Crittendenia', 'Malassezia', 'Starmerella']
# Number of labels in batch: 16
#
# Batch 89:
# Data shape: torch.Size([16, 759])
# Labels: tensor([ 42,   3,  87,  25,  48, 119,  78, 164, 169,  31,   0, 217, 231,  32,
#          24,  82])
# Label Names: ['Distoseptispora', 'Inocybe', 'Blastobotrys', 'Marasmius', 'Coniochaeta', 'Cyathus', 'Acremonium', 'Chlorociboria', 'Picipes', 'Pluteus', 'Cortinarius', 'Annulohypoxylon', 'Zygosaccharomyces', 'Scolecobasidium', 'Exophiala', 'Wickerhamomyces']
# Number of labels in batch: 16
#
# Batch 90:
# Data shape: torch.Size([16, 724])
# Labels: tensor([ 38, 123,  68,  20, 105,   9,  89,   2,   3, 200,  35, 167, 110,   3,
#          35, 116])
# Label Names: ['Sporothrix', 'Nakazawaea', 'Malbranchea', 'Mucor', 'Ceratocystis', 'Agaricus', 'Metarhizium', 'Aspergillus', 'Inocybe', 'Peltula', 'Leucoagaricus', 'Rhinocladiella', 'Nemania', 'Inocybe', 'Leucoagaricus', 'Bambusicola']
# Number of labels in batch: 16
#
# Batch 91:
# Data shape: torch.Size([16, 873])
# Labels: tensor([116,  10,  86, 130,   5, 166,  43, 121,  47,  56,  10,  33,  79, 118,
#          21, 103])
# Label Names: ['Bambusicola', 'Amanita', 'Lepiota', 'Ophiocordyceps', 'Trichoderma', 'Ceramothyrium', 'Tomentella', 'Teunomyces', 'Kazachstania', 'Boletus', 'Amanita', 'Lactifluus', 'Cyphellophora', 'Chrysosporium', 'Candida', 'Inosperma']
# Number of labels in batch: 16
#
# Batch 92:
# Data shape: torch.Size([16, 790])
# Labels: tensor([ 13, 239, 147, 165,  26,  30,  10,  25,  31,  47,  91,  28,  33, 227,
#          76,  78])
# Label Names: ['Russula', 'Vararia', 'Genea', 'Leptosillia', 'Zasmidium', 'Tuber', 'Amanita', 'Marasmius', 'Pluteus', 'Kazachstania', 'Hygrocybe', 'Ogataea', 'Lactifluus', 'Tarzetta', 'Trechispora', 'Acremonium']
# Number of labels in batch: 16
#
# Batch 93:
# Data shape: torch.Size([16, 755])
# Labels: tensor([ 57,  59, 215, 161,  20,  94,  62,   3,  11,  86,  86,  66,  68, 198,
#         213,  91])
# Label Names: ['Cyberlindnera', 'Sugiyamaella', 'Gibellula', 'Caloplaca', 'Mucor', 'Clavulina', 'Mortierella', 'Inocybe', 'Entoloma', 'Lepiota', 'Lepiota', 'Suhomyces', 'Malbranchea', 'Astrothelium', 'Tetrapisispora', 'Hygrocybe']
# Number of labels in batch: 16
#
# Batch 94:
# Data shape: torch.Size([16, 736])
# Labels: tensor([158,  86,  35,  10, 181, 195,   3,  13,   7,  31, 108, 152, 124, 109,
#         106,  10])
# Label Names: ['Gyroporus', 'Lepiota', 'Leucoagaricus', 'Amanita', 'Kirschsteiniothelia', 'Dacrymyces', 'Inocybe', 'Russula', 'Talaromyces', 'Pluteus', 'Fulvifomes', 'Kodamaea', 'Clavaria', 'Spathaspora', 'Helminthosporium', 'Amanita']
# Number of labels in batch: 16
#
# Batch 95:
# Data shape: torch.Size([16, 725])
# Labels: tensor([153,  88, 168,  11,  51,  78, 107,  81,  26, 226,  14, 123, 110, 199,
#           3,  11])
# Label Names: ['Strigula', 'Ramaria', 'Phialemonium', 'Entoloma', 'Lipomyces', 'Acremonium', 'Hydnellum', 'Yamadazyma', 'Zasmidium', 'Phaeoclavulina', 'Lactarius', 'Nakazawaea', 'Nemania', 'Strobilomyces', 'Inocybe', 'Entoloma']
# Number of labels in batch: 16
#
# Batch 96:
# Data shape: torch.Size([16, 778])
# Labels: tensor([ 30, 200,   3, 137,  23,  12,  87,  13,  12,  65,  84,   2,   3,  90,
#         103,  25])
# Label Names: ['Tuber', 'Peltula', 'Inocybe', 'Colacogloea', 'Hydnum', 'Orbilia', 'Blastobotrys', 'Russula', 'Orbilia', 'Phanerochaete', 'Tricholoma', 'Aspergillus', 'Inocybe', 'Tolypocladium', 'Inosperma', 'Marasmius']
# Number of labels in batch: 16
#
# Batch 97:
# Data shape: torch.Size([16, 1313])
# Labels: tensor([182, 107, 111,  54, 177,   3, 133,  84,  20, 223, 148,   3,  56,  63,
#          21, 140])
# Label Names: ['Waltergamsia', 'Hydnellum', 'Crepidotus', 'Geastrum', 'Lindgomyces', 'Inocybe', 'Phellodon', 'Tricholoma', 'Mucor', 'Sidera', 'Cantharellus', 'Inocybe', 'Boletus', 'Phialocephala', 'Candida', 'Backusella']
# Number of labels in batch: 16
#
# Batch 98:
# Data shape: torch.Size([16, 878])
# Labels: tensor([233,  68,   3,  10,  49, 166,   3, 189,  33,   3,  63,   7,  46,  51,
#          10, 218])
# Label Names: ['Kuraishia', 'Malbranchea', 'Inocybe', 'Amanita', 'Verrucaria', 'Ceramothyrium', 'Inocybe', 'Nakaseomyces', 'Lactifluus', 'Inocybe', 'Phialocephala', 'Talaromyces', 'Otidea', 'Lipomyces', 'Amanita', 'Hyphoderma']
# Number of labels in batch: 16
#
# Batch 99:
# Data shape: torch.Size([16, 1296])
# Labels: tensor([163, 109,  10,  78, 136,  62,  94,  57,  32, 197,   6,  20,  80,   2,
#         220, 109])
# Label Names: ['Peziza', 'Spathaspora', 'Amanita', 'Acremonium', 'Rhodocybe', 'Mortierella', 'Clavulina', 'Cyberlindnera', 'Scolecobasidium', 'Massaria', 'Phlegmacium', 'Mucor', 'Mycena', 'Aspergillus', 'Phyllactinia', 'Spathaspora']
# Number of labels in batch: 16
#
# Batch 100:
# Data shape: torch.Size([16, 763])
# Labels: tensor([ 11, 115,  68,  57, 171,  20,  12, 202,  12,  21,  81,   3,   3,   3,
#          47,  41])
# Label Names: ['Entoloma', 'Trichomerium', 'Malbranchea', 'Cyberlindnera', 'Bacidia', 'Mucor', 'Orbilia', 'Tulasnella', 'Orbilia', 'Candida', 'Yamadazyma', 'Inocybe', 'Inocybe', 'Inocybe', 'Kazachstania', 'Cladophialophora']
# Number of labels in batch: 16
#
# Batch 101:
# Data shape: torch.Size([16, 857])
# Labels: tensor([ 43, 192,  72,   2, 145,  55,  95,  36, 153,  11,  75, 125, 225,  60,
#          49,  21])
# Label Names: ['Tomentella', 'Helvella', 'Xylaria', 'Aspergillus', 'Elaphomyces', 'Pseudosperma', 'Puccinia', 'Sticta', 'Strigula', 'Entoloma', 'Papiliotrema', 'Fuscoporia', 'Pyrenophora', 'Wickerhamiella', 'Verrucaria', 'Candida']
# Number of labels in batch: 16
#
# Batch 102:
# Data shape: torch.Size([16, 866])
# Labels: tensor([238, 203, 208,   3,  31, 171, 172,  66, 164, 122,  55,  56,  51,  50,
#          98, 100])
# Label Names: ['Volvariella', 'Phylloporia', 'Conocybe', 'Inocybe', 'Pluteus', 'Bacidia', 'Polyporus', 'Suhomyces', 'Chlorociboria', 'Bulleribasidium', 'Pseudosperma', 'Boletus', 'Lipomyces', 'Sarocladium', 'Kondoa', 'Roussoella']
# Number of labels in batch: 16
#
# Batch 103:
# Data shape: torch.Size([16, 773])
# Labels: tensor([194, 115, 245,   0,  84, 239,  12,  58,  87,  67,  46, 171,  24,  12,
#          34, 122])
# Label Names: ['Diutina', 'Trichomerium', 'Atractospora', 'Cortinarius', 'Tricholoma', 'Vararia', 'Orbilia', 'Absidia', 'Blastobotrys', 'Fomitiporia', 'Otidea', 'Bacidia', 'Exophiala', 'Orbilia', 'Metschnikowia', 'Bulleribasidium']
# Number of labels in batch: 16
#
# Batch 104:
# Data shape: torch.Size([16, 822])
# Labels: tensor([ 10,  28,  46,   3,   2,  51,  47,  21,  41, 181, 114,  74,  40,  59,
#         131,  35])
# Label Names: ['Amanita', 'Ogataea', 'Otidea', 'Inocybe', 'Aspergillus', 'Lipomyces', 'Kazachstania', 'Candida', 'Cladophialophora', 'Kirschsteiniothelia', 'Malassezia', 'Starmerella', 'Xylodon', 'Sugiyamaella', 'Muyocopron', 'Leucoagaricus']
# Number of labels in batch: 16
#
# Batch 105:
# Data shape: torch.Size([16, 760])
# Labels: tensor([  5,   0, 243,  80, 227,  88, 229,  58,  54, 141, 144,  32, 126, 136,
#         153,  11])
# Label Names: ['Trichoderma', 'Cortinarius', 'Ceriporiopsis', 'Mycena', 'Tarzetta', 'Ramaria', 'Verruconis', 'Absidia', 'Geastrum', 'Umbelopsis', 'Collybiopsis', 'Scolecobasidium', 'Lyomyces', 'Rhodocybe', 'Strigula', 'Entoloma']
# Number of labels in batch: 16
#
# Batch 106:
# Data shape: torch.Size([16, 812])
# Labels: tensor([127,  35,  85, 212,  51,  57,  33, 144,  34, 204,  74,  50,  94,  96,
#          35,  40])
# Label Names: ['Tetraploa', 'Leucoagaricus', 'Erysiphe', 'Escovopsis', 'Lipomyces', 'Cyberlindnera', 'Lactifluus', 'Collybiopsis', 'Metschnikowia', 'Squamanita', 'Starmerella', 'Sarocladium', 'Clavulina', 'Vishniacozyma', 'Leucoagaricus', 'Xylodon']
# Number of labels in batch: 16
#
# Batch 107:
# Data shape: torch.Size([16, 830])
# Labels: tensor([ 47,  66,  11,  15,  72, 239, 144, 104, 108,  12, 133,  58,  88, 194,
#          11,  33])
# ...
# Number of labels in batch: 16
#
# Batch 119:
# Data shape: torch.Size([16, 830])
# Labels: tensor([ 31,  99,  97,  31,  92, 104,  29, 117,  39,  30,   3,  50, 114,  22,
#           7,   9])
# Label Names: ['Pluteus', 'Coprinopsis', 'Phylloporus', 'Pluteus', 'Hypomyces', 'Saccharomycopsis', 'Ophiostoma', 'Perenniporia', 'Gymnopus', 'Tuber', 'Inocybe', 'Sarocladium', 'Malassezia', 'Apiospora', 'Talaromyces', 'Agaricus']
# Number of labels in batch: 16
#
# Batch 120:
# Data shape: torch.Size([16, 764])
# Labels: tensor([  0,   2,  60,  35,  41,  65, 108, 240, 114,  88,  25,  35, 242, 211,
#         190,  87])
# Label Names: ['Cortinarius', 'Aspergillus', 'Wickerhamiella', 'Leucoagaricus', 'Cladophialophora', 'Phanerochaete', 'Fulvifomes', 'Buellia', 'Malassezia', 'Ramaria', 'Marasmius', 'Leucoagaricus', 'Xerocomus', 'Conioscypha', 'Murispora', 'Blastobotrys']
# Number of labels in batch: 16
#
# Batch 121:
# Data shape: torch.Size([16, 960])
# Labels: tensor([ 21, 147,   3, 112,  59,  32,  22, 243, 103,  35, 168,   0, 148,  14,
#           3, 193])
# Label Names: ['Candida', 'Genea', 'Inocybe', 'Hymenochaete', 'Sugiyamaella', 'Scolecobasidium', 'Apiospora', 'Ceriporiopsis', 'Inosperma', 'Leucoagaricus', 'Phialemonium', 'Cortinarius', 'Cantharellus', 'Lactarius', 'Inocybe', 'Basidiodendron']
# Number of labels in batch: 16
#
# Batch 122:
# Data shape: torch.Size([16, 867])
# Labels: tensor([ 73,  54,  49,   5, 192,  63, 122,  60, 181, 103,   3, 203, 205,  86,
#           3,  41])
# Label Names: ['Rhizopogon', 'Geastrum', 'Verrucaria', 'Trichoderma', 'Helvella', 'Phialocephala', 'Bulleribasidium', 'Wickerhamiella', 'Kirschsteiniothelia', 'Inosperma', 'Inocybe', 'Phylloporia', 'Clavariadelphus', 'Lepiota', 'Inocybe', 'Cladophialophora']
# Number of labels in batch: 16
#
# Batch 123:
# Data shape: torch.Size([16, 883])
# Labels: tensor([243, 116, 218, 143,  32, 149,  72, 123,  28,   3,  25,  88,  56, 177,
#          94,   2])
# Label Names: ['Ceriporiopsis', 'Bambusicola', 'Hyphoderma', 'Lecanora', 'Scolecobasidium', 'Hyphopichia', 'Xylaria', 'Nakazawaea', 'Ogataea', 'Inocybe', 'Marasmius', 'Ramaria', 'Boletus', 'Lindgomyces', 'Clavulina', 'Aspergillus']
# Number of labels in batch: 16
#
# Batch 124:
# Data shape: torch.Size([16, 811])
# Labels: tensor([  2,  50, 124,  87,  28,   3, 102,  40,  98,  64,  11,   3,   7,  22,
#           0,   8])
# Label Names: ['Aspergillus', 'Sarocladium', 'Clavaria', 'Blastobotrys', 'Ogataea', 'Inocybe', 'Hymenoscyphus', 'Xylodon', 'Kondoa', 'Arthroderma', 'Entoloma', 'Inocybe', 'Talaromyces', 'Apiospora', 'Cortinarius', 'Fusarium']
# Number of labels in batch: 16
#
# Batch 125:
# Data shape: torch.Size([16, 735])
# Labels: tensor([161, 213,  60, 237,  57,  60,   3, 111,  25, 138, 145, 202,  24,   3,
#         112,  12])
# Label Names: ['Caloplaca', 'Tetrapisispora', 'Wickerhamiella', 'Resupinatus', 'Cyberlindnera', 'Wickerhamiella', 'Inocybe', 'Crepidotus', 'Marasmius', 'Filobasidium', 'Elaphomyces', 'Tulasnella', 'Exophiala', 'Inocybe', 'Hymenochaete', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 126:
# Data shape: torch.Size([16, 765])
# Labels: tensor([113,  20, 140,  10,  61, 150,   3,  22,  94, 208,  82,  87,   3,  31,
#          41,  44])
# Label Names: ['Saturnispora', 'Mucor', 'Backusella', 'Amanita', 'Leptographium', 'Scytinostroma', 'Inocybe', 'Apiospora', 'Clavulina', 'Conocybe', 'Wickerhamomyces', 'Blastobotrys', 'Inocybe', 'Pluteus', 'Cladophialophora', 'Ganoderma']
# Number of labels in batch: 16
#
# Batch 127:
# Data shape: torch.Size([16, 751])
# Labels: tensor([ 91,  94,  10, 128,  12, 185, 193,   3,   3, 244, 222,  77,  10, 198,
#           3, 189])
# Label Names: ['Hygrocybe', 'Clavulina', 'Amanita', 'Gyromitra', 'Orbilia', 'Meliola', 'Basidiodendron', 'Inocybe', 'Inocybe', 'Tremateia', 'Calocybella', 'Periconia', 'Amanita', 'Astrothelium', 'Inocybe', 'Nakaseomyces']
# Number of labels in batch: 16
#
# Batch 128:
# Data shape: torch.Size([16, 749])
# Labels: tensor([105,  58,  59, 217, 158,  12,  86,   3, 146,  33, 205,  47, 105,   0,
#         131,   3])
# Label Names: ['Ceratocystis', 'Absidia', 'Sugiyamaella', 'Annulohypoxylon', 'Gyroporus', 'Orbilia', 'Lepiota', 'Inocybe', 'Phlebiopsis', 'Lactifluus', 'Clavariadelphus', 'Kazachstania', 'Ceratocystis', 'Cortinarius', 'Muyocopron', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 129:
# Data shape: torch.Size([16, 1080])
# Labels: tensor([ 46, 111,  20,  40, 111,   0,  40, 108,  52,  35,  30,  16, 147,  78,
#          54,  12])
# Label Names: ['Otidea', 'Crepidotus', 'Mucor', 'Xylodon', 'Crepidotus', 'Cortinarius', 'Xylodon', 'Fulvifomes', 'Hygrophorus', 'Leucoagaricus', 'Tuber', 'Elsinoe', 'Genea', 'Acremonium', 'Geastrum', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 130:
# Data shape: torch.Size([16, 717])
# Labels: tensor([ 70, 186,  65,   4, 243, 169,  48,   3, 219, 116,  72, 135, 131, 133,
#          20,  73])
# Label Names: ['Neodevriesia', 'Calocybe', 'Phanerochaete', 'Colletotrichum', 'Ceriporiopsis', 'Picipes', 'Coniochaeta', 'Inocybe', 'Tylopilus', 'Bambusicola', 'Xylaria', 'Capronia', 'Muyocopron', 'Phellodon', 'Mucor', 'Rhizopogon']
# Number of labels in batch: 16
#
# Batch 131:
# Data shape: torch.Size([16, 780])
# Labels: tensor([ 89, 192,  41, 171, 141, 246,   3, 232,  54,  79, 111,  95,  34,  11,
#         146, 179])
# Label Names: ['Metarhizium', 'Helvella', 'Cladophialophora', 'Bacidia', 'Umbelopsis', 'Brettanomyces', 'Inocybe', 'Auritella', 'Geastrum', 'Cyphellophora', 'Crepidotus', 'Puccinia', 'Metschnikowia', 'Entoloma', 'Phlebiopsis', 'Ambrosiozyma']
# Number of labels in batch: 16
#
# Batch 132:
# Data shape: torch.Size([16, 774])
# Labels: tensor([ 99, 232,  97,  10,  98,  47, 135,  10,  90, 231, 175,  39,   3,  12,
#          49, 109])
# Label Names: ['Coprinopsis', 'Auritella', 'Phylloporus', 'Amanita', 'Kondoa', 'Kazachstania', 'Capronia', 'Amanita', 'Tolypocladium', 'Zygosaccharomyces', 'Pachyphlodes', 'Gymnopus', 'Inocybe', 'Orbilia', 'Verrucaria', 'Spathaspora']
# Number of labels in batch: 16
#
# Batch 133:
# Data shape: torch.Size([16, 780])
# Labels: tensor([ 11,  71, 215, 150, 226, 178,  21,  46,  82,  25,  11,  69, 219, 173,
#           1,  10])
# Label Names: ['Entoloma', 'Tremella', 'Gibellula', 'Scytinostroma', 'Phaeoclavulina', 'Endoraecium', 'Candida', 'Otidea', 'Wickerhamomyces', 'Marasmius', 'Entoloma', 'Taphrina', 'Tylopilus', 'Phellinus', 'Penicillium', 'Amanita']
# Number of labels in batch: 16
#
# Batch 134:
# Data shape: torch.Size([16, 755])
# Labels: tensor([ 22, 221,  43, 135, 219, 130,   5, 137,  59,  81, 164, 169,  12, 216,
#           3, 102])
# Label Names: ['Apiospora', 'Hydnobolites', 'Tomentella', 'Capronia', 'Tylopilus', 'Ophiocordyceps', 'Trichoderma', 'Colacogloea', 'Sugiyamaella', 'Yamadazyma', 'Chlorociboria', 'Picipes', 'Orbilia', 'Pleurothecium', 'Inocybe', 'Hymenoscyphus']
# Number of labels in batch: 16
#
# Batch 135:
# Data shape: torch.Size([16, 758])
# Labels: tensor([ 27,   0,  12,   3,  12,  57, 221,  83, 130,  41,  33, 132,  75,   3,
#         139,   3])
# Label Names: ['Hypoxylon', 'Cortinarius', 'Orbilia', 'Inocybe', 'Orbilia', 'Cyberlindnera', 'Hydnobolites', 'Pichia', 'Ophiocordyceps', 'Cladophialophora', 'Lactifluus', 'Kwoniella', 'Papiliotrema', 'Inocybe', 'Nannizziopsis', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 136:
# Data shape: torch.Size([16, 1400])
# Labels: tensor([ 60,   3, 197,  85,  11, 146,  81,  83,  20, 179,   3, 143, 117,  88,
#          31,  12])
# Label Names: ['Wickerhamiella', 'Inocybe', 'Massaria', 'Erysiphe', 'Entoloma', 'Phlebiopsis', 'Yamadazyma', 'Pichia', 'Mucor', 'Ambrosiozyma', 'Inocybe', 'Lecanora', 'Perenniporia', 'Ramaria', 'Pluteus', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 137:
# Data shape: torch.Size([16, 786])
# Labels: tensor([  3,  10,  61,  20,  24, 214,  54,  98, 143,  34, 121, 157,  71,  12,
#          49,   3])
# Label Names: ['Inocybe', 'Amanita', 'Leptographium', 'Mucor', 'Exophiala', 'Moniliella', 'Geastrum', 'Kondoa', 'Lecanora', 'Metschnikowia', 'Teunomyces', 'Peniophorella', 'Tremella', 'Orbilia', 'Verrucaria', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 138:
# Data shape: torch.Size([16, 842])
# Labels: tensor([ 62,   3,  95,  59, 183, 178, 143, 149, 109, 104, 196,  74, 138, 111,
#          66,   3])
# Label Names: ['Mortierella', 'Inocybe', 'Puccinia', 'Sugiyamaella', 'Niesslia', 'Endoraecium', 'Lecanora', 'Hyphopichia', 'Spathaspora', 'Saccharomycopsis', 'Subulicystidium', 'Starmerella', 'Filobasidium', 'Crepidotus', 'Suhomyces', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 139:
# Data shape: torch.Size([16, 789])
# Labels: tensor([ 75,  91,  11, 114,  54,  43,  26, 183,  13, 150,   3,  22, 139,   2,
#          30, 104])
# Label Names: ['Papiliotrema', 'Hygrocybe', 'Entoloma', 'Malassezia', 'Geastrum', 'Tomentella', 'Zasmidium', 'Niesslia', 'Russula', 'Scytinostroma', 'Inocybe', 'Apiospora', 'Nannizziopsis', 'Aspergillus', 'Tuber', 'Saccharomycopsis']
# Number of labels in batch: 16
#
# Batch 140:
# Data shape: torch.Size([16, 1083])
# Labels: tensor([ 11,  97, 145, 219,  80,  82,  13, 137,  83, 155,   3, 206,   3, 116,
#          13,  12])
# Label Names: ['Entoloma', 'Phylloporus', 'Elaphomyces', 'Tylopilus', 'Mycena', 'Wickerhamomyces', 'Russula', 'Colacogloea', 'Pichia', 'Tropicoporus', 'Inocybe', 'Sclerococcum', 'Inocybe', 'Bambusicola', 'Russula', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 141:
# Data shape: torch.Size([16, 947])
# Labels: tensor([  3, 150,   3,   2,   3,  97,  56,  76,  52,  82,  93, 158,  16,   7,
#           3,  11])
# Label Names: ['Inocybe', 'Scytinostroma', 'Inocybe', 'Aspergillus', 'Inocybe', 'Phylloporus', 'Boletus', 'Trechispora', 'Hygrophorus', 'Wickerhamomyces', 'Acaulospora', 'Gyroporus', 'Elsinoe', 'Talaromyces', 'Inocybe', 'Entoloma']
# Number of labels in batch: 16
#
# Batch 142:
# Data shape: torch.Size([16, 1138])
# Labels: tensor([  3, 197,  13,  89, 105,  35,   3, 241, 128, 160, 194, 155,  14,  79,
#          20,  20])
# Label Names: ['Inocybe', 'Massaria', 'Russula', 'Metarhizium', 'Ceratocystis', 'Leucoagaricus', 'Inocybe', 'Coccomyces', 'Gyromitra', 'Arthrobotrys', 'Diutina', 'Tropicoporus', 'Lactarius', 'Cyphellophora', 'Mucor', 'Mucor']
# Number of labels in batch: 16
#
# Batch 143:
# Data shape: torch.Size([16, 822])
# Labels: tensor([  3,  10, 188,  24,  88,   2, 130, 103,  20, 168,   3,  74, 136,  55,
#          94, 147])
# Label Names: ['Inocybe', 'Amanita', 'Crittendenia', 'Exophiala', 'Ramaria', 'Aspergillus', 'Ophiocordyceps', 'Inosperma', 'Mucor', 'Phialemonium', 'Inocybe', 'Starmerella', 'Rhodocybe', 'Pseudosperma', 'Clavulina', 'Genea']
# Number of labels in batch: 16
#
# Batch 144:
# Data shape: torch.Size([16, 1171])
# Labels: tensor([ 40,  12,  11, 124,  46,  27, 118,   3,  67, 125,  27,  99, 183,  97,
#         116,  25])
# Label Names: ['Xylodon', 'Orbilia', 'Entoloma', 'Clavaria', 'Otidea', 'Hypoxylon', 'Chrysosporium', 'Inocybe', 'Fomitiporia', 'Fuscoporia', 'Hypoxylon', 'Coprinopsis', 'Niesslia', 'Phylloporus', 'Bambusicola', 'Marasmius']
# Number of labels in batch: 16
#
# Batch 145:
# Data shape: torch.Size([16, 1018])
# Labels: tensor([ 11, 107,  97, 188,  34,  73, 206,  52, 135, 109, 100,  56,  92, 174,
#         100,  86])
# Label Names: ['Entoloma', 'Hydnellum', 'Phylloporus', 'Crittendenia', 'Metschnikowia', 'Rhizopogon', 'Sclerococcum', 'Hygrophorus', 'Capronia', 'Spathaspora', 'Roussoella', 'Boletus', 'Hypomyces', 'Phyllachora', 'Roussoella', 'Lepiota']
# Number of labels in batch: 16
#
# Batch 146:
# Data shape: torch.Size([16, 796])
# Labels: tensor([ 72,  46, 180,  13,  31, 120,  32, 168,  56,  27,  11,  14, 175,  55,
#         162,  10])
# Label Names: ['Xylaria', 'Otidea', 'Dipodascus', 'Russula', 'Pluteus', 'Podospora', 'Scolecobasidium', 'Phialemonium', 'Boletus', 'Hypoxylon', 'Entoloma', 'Lactarius', 'Pachyphlodes', 'Pseudosperma', 'Raffaelea', 'Amanita']
# Number of labels in batch: 16
#
# Batch 147:
# Data shape: torch.Size([16, 772])
# Labels: tensor([ 13,  18,  10,  61,  12, 113,   2,  12, 159,  55,  95,  80,  79,  11,
#         140,  12])
# Label Names: ['Russula', 'Cytospora', 'Amanita', 'Leptographium', 'Orbilia', 'Saturnispora', 'Aspergillus', 'Orbilia', 'Phallus', 'Pseudosperma', 'Puccinia', 'Mycena', 'Cyphellophora', 'Entoloma', 'Backusella', 'Orbilia']
# Number of labels in batch: 16
#
# Batch 148:
# Data shape: torch.Size([16, 853])
# Labels: tensor([ 18, 242, 206, 158, 187,   2, 186, 190, 104,  10,  10, 135, 193,  71,
#          10,  72])
# Label Names: ['Cytospora', 'Xerocomus', 'Sclerococcum', 'Gyroporus', 'Peroneutypa', 'Aspergillus', 'Calocybe', 'Murispora', 'Saccharomycopsis', 'Amanita', 'Amanita', 'Capronia', 'Basidiodendron', 'Tremella', 'Amanita', 'Xylaria']
# Number of labels in batch: 16
#
# Batch 149:
# Data shape: torch.Size([16, 764])
# Labels: tensor([ 13, 184,  64, 135,  82,  66,  71,  38,  55, 226,  59, 125,  50, 236,
#         112, 168])
# Label Names: ['Russula', 'Scleroderma', 'Arthroderma', 'Capronia', 'Wickerhamomyces', 'Suhomyces', 'Tremella', 'Sporothrix', 'Pseudosperma', 'Phaeoclavulina', 'Sugiyamaella', 'Fuscoporia', 'Sarocladium', 'Oxydothis', 'Hymenochaete', 'Phialemonium']
# Number of labels in batch: 16
#
# Batch 150:
# Data shape: torch.Size([16, 847])
# Labels: tensor([ 10,   3,  11,  12, 101, 112,  56,   0,  84,  60,  12,  10, 129,   6,
#          32, 155])
# Label Names: ['Amanita', 'Inocybe', 'Entoloma', 'Orbilia', 'Cutaneotrichosporon', 'Hymenochaete', 'Boletus', 'Cortinarius', 'Tricholoma', 'Wickerhamiella', 'Orbilia', 'Amanita', 'Ascosphaera', 'Phlegmacium', 'Scolecobasidium', 'Tropicoporus']
# Number of labels in batch: 16
#
# Batch 151:
# Data shape: torch.Size([16, 760])
# Labels: tensor([187,  58, 166,  33,  13,  39,  87, 154,  12,  97,   0,  55, 107,  30,
#          13,  86])
# Label Names: ['Peroneutypa', 'Absidia', 'Ceramothyrium', 'Lactifluus', 'Russula', 'Gymnopus', 'Blastobotrys', 'Mollisia', 'Orbilia', 'Phylloporus', 'Cortinarius', 'Pseudosperma', 'Hydnellum', 'Tuber', 'Russula', 'Lepiota']
# Number of labels in batch: 16
#
# Batch 152:
# Data shape: torch.Size([16, 1156])
# Labels: tensor([ 13,  11,  30,   3, 128, 107, 172, 240,   3,  23,  13, 136,   3,  45,
#         177, 124])
# Label Names: ['Russula', 'Entoloma', 'Tuber', 'Inocybe', 'Gyromitra', 'Hydnellum', 'Polyporus', 'Buellia', 'Inocybe', 'Hydnum', 'Russula', 'Rhodocybe', 'Inocybe', 'Derxomyces', 'Lindgomyces', 'Clavaria']
# Number of labels in batch: 16
#
# Batch 153:
# Data shape: torch.Size([16, 934])
# Labels: tensor([ 30, 173,   3,  98,  28,  51,  57,  94,  58, 167,  46,  11,  42,  72,
#         140,   3])
# Label Names: ['Tuber', 'Phellinus', 'Inocybe', 'Kondoa', 'Ogataea', 'Lipomyces', 'Cyberlindnera', 'Clavulina', 'Absidia', 'Rhinocladiella', 'Otidea', 'Entoloma', 'Distoseptispora', 'Xylaria', 'Backusella', 'Inocybe']
# Number of labels in batch: 16
#
# Batch 154:
# Data shape: torch.Size([16, 827])
# Labels: tensor([ 13,  47, 223,  34, 240,  11,  68,   3, 184, 107,  47,   3,  10,  21,
#         148, 118])
# Label Names: ['Russula', 'Kazachstania', 'Sidera', 'Metschnikowia', 'Buellia', 'Entoloma', 'Malbranchea', 'Inocybe', 'Scleroderma', 'Hydnellum', 'Kazachstania', 'Inocybe', 'Amanita', 'Candida', 'Cantharellus', 'Chrysosporium']
# Number of labels in batch: 16
#
# Batch 155:
# Data shape: torch.Size([16, 894])
# Labels: tensor([134, 101, 162,  27, 104,  75, 147, 207, 101,  64, 184, 175,   2, 187,
#         109,  80])
# Label Names: ['Nannizzia', 'Cutaneotrichosporon', 'Raffaelea', 'Hypoxylon', 'Saccharomycopsis', 'Papiliotrema', 'Genea', 'Barnettozyma', 'Cutaneotrichosporon', 'Arthroderma', 'Scleroderma', 'Pachyphlodes', 'Aspergillus', 'Peroneutypa', 'Spathaspora', 'Mycena']
# Number of labels in batch: 16
#
# Batch 156:
# Data shape: torch.Size([16, 780])
# Labels: tensor([ 14,  38,  60,  12,  12,  26,  21,  52,  27, 154,  46,  12,  11, 190,
#           3,  25])
# Label Names: ['Lactarius', 'Sporothrix', 'Wickerhamiella', 'Orbilia', 'Orbilia', 'Zasmidium', 'Candida', 'Hygrophorus', 'Hypoxylon', 'Mollisia', 'Otidea', 'Orbilia', 'Entoloma', 'Murispora', 'Inocybe', 'Marasmius']
# Number of labels in batch: 16
#
# Batch 157:
# Data shape: torch.Size([4, 759])
# Labels: tensor([55, 79, 12, 97])
# Label Names: ['Pseudosperma', 'Cyphellophora', 'Orbilia', 'Phylloporus']
# Number of labels in batch: 4

# %% [markdown]
# # RRCNN-LSTM

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

class RRCNN_LSTM(nn.Module):
    def __init__(self, num_classes, embedding_dim=4):
        super(RRCNN_LSTM, self).__init__()
        
        self.embedding = nn.Embedding(num_embeddings=5, embedding_dim=embedding_dim, padding_idx=0)
        
        self.conv1 = nn.Conv1d(in_channels=embedding_dim, out_channels=32, kernel_size=5, padding=2)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, padding=2)
        
        self.lstm = nn.LSTM(input_size=64, hidden_size=128, num_layers=2, batch_first=True, bidirectional=True)
        
        self.fc1 = nn.Linear(128 * 2, 128) 
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.embedding(x)  
        x = x.permute(0, 2, 1)

        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
    
        x = x.permute(0, 2, 1)  
        x, _ = self.lstm(x)
        
        x = x[:, -1, :]  
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        
        return x
    
embedding_dim = 4  
num_classes = len(train_dataset.label_mapping)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Model, Loss, and Optimizer
model = RRCNN_LSTM(num_classes=num_classes, embedding_dim=embedding_dim)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3)

# Training loop with testing
num_epochs = 100
train_accuracies = []
test_accuracies = []

for epoch in range(num_epochs):
    # Training
    model.train()
    total_train_loss = 0
    total_correct_train = 0
    total_train_samples = 0

    for batch_idx, (data, labels) in enumerate(train_loader):
        data, labels = data.to(device).long(), labels.to(device)  # Explicitly convert data to LongTensor

        # Forward pass
        outputs = model(data)
        loss = criterion(outputs, labels)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Compute training metrics
        total_train_loss += loss.item()
        _, predicted_train = torch.max(outputs, 1)
        total_correct_train += (predicted_train == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = total_correct_train / total_train_samples * 100
    train_accuracies.append(train_accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%')

    # Evaluate on test dataset
    model.eval()
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device).long(), labels.to(device)  # Explicitly convert data to LongTensor
            outputs = model(data)
            _, predicted = torch.max(outputs, 1)
            total_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)

    accuracy = total_correct / total_samples * 100
    test_accuracies.append(accuracy)
    print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {accuracy:.2f}%')

    # Adjust learning rate if needed
    scheduler.step(avg_train_loss)
# Out:
# Epoch [1/100], Training Loss: 5.2629, Training Accuracy: 7.44%
# Epoch [1/100], Test Accuracy: 0.40%
# Epoch [2/100], Training Loss: 5.1314, Training Accuracy: 7.96%
# Epoch [2/100], Test Accuracy: 0.40%
# Epoch [3/100], Training Loss: 5.1235, Training Accuracy: 7.96%
# Epoch [3/100], Test Accuracy: 0.40%
# Epoch [4/100], Training Loss: 5.1129, Training Accuracy: 7.88%
# Epoch [4/100], Test Accuracy: 0.40%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 80
#      78 # Backward pass
#      79 optimizer.zero_grad()
# ---> 80 loss.backward()
#      81 optimizer.step()
#      83 # Compute training metrics
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:
